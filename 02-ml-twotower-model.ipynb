# %% [markdown]
# ## Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# %cd rapidsai-csp-utils
# !git checkout 22.12-patch
# %cd ..
# !python rapidsai-csp-utils/colab/env-check.py
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 390 (delta 89), reused 51 (delta 51), pack-reused 269
# Receiving objects: 100% (390/390), 107.11 KiB | 2.23 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# /content/rapidsai-csp-utils
# Branch '22.12-patch' set up to track remote branch '22.12-patch' from 'origin'.
# Switched to a new branch '22.12-patch'
# /content
# Collecting pynvml
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pynvml
# Successfully installed pynvml-11.5.0
# Traceback (most recent call last):
#   File "/content/rapidsai-csp-utils/colab/env-check.py", line 26, in <module>
#     gpu_name = pynvml.nvmlDeviceGetName(pynvml.nvmlDeviceGetHandleByIndex(0)).decode('UTF-8')
# AttributeError: 'str' object has no attribute 'decode'. Did you mean: 'encode'?
# Traceback (most recent call last):
#   File "/content/rapidsai-csp-utils/colab/pip-install.py", line 26, in <module>
#     gpu_name = pynvml.nvmlDeviceGetName(pynvml.nvmlDeviceGetHandleByIndex(0)).decode('UTF-8')
# AttributeError: 'str' object has no attribute 'decode'. Did you mean: 'encode'?

# %%
# Install the Merlin Framework
# !pip install -U git+https://github.com/NVIDIA-Merlin/models.git@release-23.04
# !pip install -U git+https://github.com/NVIDIA-Merlin/nvtabular.git@release-23.04
# !pip install -U git+https://github.com/NVIDIA-Merlin/core.git@release-23.04
# !pip install -U git+https://github.com/NVIDIA-Merlin/system.git@release-23.04
# !pip install -U git+https://github.com/NVIDIA-Merlin/dataloader.git@release-23.04
# !pip install -U git+https://github.com/NVIDIA-Merlin/Transformers4Rec.git@release-23.04
# !pip install -U xgboost lightfm implicit
# Out:
# Collecting git+https://github.com/NVIDIA-Merlin/models.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/models.git (to revision release-23.04) to /tmp/pip-req-build-zhdyun6n
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/models.git /tmp/pip-req-build-zhdyun6n
#   Running command git checkout -b release-23.04 --track origin/release-23.04
#   Switched to a new branch 'release-23.04'
#   Branch 'release-23.04' set up to track remote branch 'release-23.04' from 'origin'.
#   Resolved https://github.com/NVIDIA-Merlin/models.git to commit 56c7d6a4b2ec003472bdd176e972125632d070de
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting merlin-core>=23.4.0 (from merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading merlin-core-23.6.0.tar.gz (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting merlin-dataloader>=23.4.0 (from merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading merlin-dataloader-23.6.0.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2022.12.1)
# Collecting dask-cuda>=22.12.0 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading dask_cuda-23.6.0-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: distributed>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2022.12.1)
# Requirement already satisfied: fsspec>=2022.7.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2023.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.22.4)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.5.3)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (0.56.4)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (9.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (3.20.3)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (4.65.0)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.13.1)
# Collecting betterproto<2.0.0 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading betterproto-1.2.5.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (23.1)
# Collecting npy-append-array (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading npy_append_array-0.9.16-py3-none-any.whl (9.0 kB)
# Collecting pynvml<11.5,>=11.0.0 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 6.2 MB/s eta 0:00:00
# Collecting grpclib (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading grpclib-0.4.5.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting stringcase (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2.2.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (6.0.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (0.12.0)
# Collecting dask>=2022.11.1 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading dask-2023.3.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.1 MB/s eta 0:00:00
# Collecting distributed>=2022.11.1 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading distributed-2023.3.2.1-py3-none-any.whl (957 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 957.1/957.1 kB 15.2 MB/s eta 0:00:00
# Collecting numba>=0.54 (from merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-cuda>=22.12.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (3.0.0)
# Collecting importlib-metadata>=4.13.0 (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.0.5)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (6.3.1)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.26.16)
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba>=0.54->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2022.7.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.59.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (1.16.0)
# Collecting h2<5,>=3.1.0 (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4) (6.0.4)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models==23.4.0+3.g56c7d6a4)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Building wheels for collected packages: merlin-models, merlin-core, merlin-dataloader, betterproto, grpclib, stringcase
#   Building wheel for merlin-models (pyproject.toml) ... done
#   Created wheel for merlin-models: filename=merlin_models-23.4.0+3.g56c7d6a4-py3-none-any.whl size=384352 sha256=04be57b0f02ceea88517e3d37384a000b486b962e0c3b1a52571ee14b6d7a52e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pb64dnqy/wheels/e2/8a/01/7961d279c8aa191d52723b3fe3feee37d1c3e4449251c53e60
#   Building wheel for merlin-core (pyproject.toml) ... done
#   Created wheel for merlin-core: filename=merlin_core-23.6.0-py3-none-any.whl size=172622 sha256=30c5d71eb0c679012e2849c2a2d69902e18e5a6336ca4c2b3ddd0276e13e0f91
#   Stored in directory: /root/.cache/pip/wheels/03/1f/ad/25d705ed1540c427bdbb8c2b2a609c4cdeb12da8d517752123
#   Building wheel for merlin-dataloader (pyproject.toml) ... done
#   Created wheel for merlin-dataloader: filename=merlin_dataloader-23.6.0-py3-none-any.whl size=35490 sha256=0d3032464fc960ce4341ea4b6d210f947479960ba9c915da13af3db870bc4ff0
#   Stored in directory: /root/.cache/pip/wheels/ff/f8/ef/5c1a6a824d563be30aa6adcaf625683fc4213fc6870ce5045f
#   Building wheel for betterproto (pyproject.toml) ... done
#   Created wheel for betterproto: filename=betterproto-1.2.5-py3-none-any.whl size=21998 sha256=198cf4dcda0bc0321ad9adad9ea7530ec0028f5d697dec6589e096522e33002f
#   Stored in directory: /root/.cache/pip/wheels/d3/8b/bf/097193de631f010236664202ef3c05c62636abc9d2b172b458
#   Building wheel for grpclib (pyproject.toml) ... done
#   Created wheel for grpclib: filename=grpclib-0.4.5-py3-none-any.whl size=77152 sha256=b8559451cc0c9f55c56e90fa425fead36001859d76b4b5766ad465fe52a89c19
#   Stored in directory: /root/.cache/pip/wheels/b6/87/f1/90fa08bcc6d35bd8dcb72e2a5383a6630584aae6b407239ee3
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3568 sha256=53f2aa3bc23fa1d50d02d66ca0183be66492e39361d069c569f6eb03c0a50f3f
#   Stored in directory: /root/.cache/pip/wheels/31/ba/22/1a2d952a9ce8aa86e42fda41e2c87fdaf20e238c88bf8df013
# Successfully built merlin-models merlin-core merlin-dataloader betterproto grpclib stringcase
# Installing collected packages: stringcase, pynvml, npy-append-array, llvmlite, importlib-metadata, hyperframe, hpack, numba, h2, dask, grpclib, distributed, dask-cuda, betterproto, merlin-core, merlin-dataloader, merlin-models
#   Attempting uninstall: pynvml
#     Found existing installation: pynvml 11.5.0
#     Uninstalling pynvml-11.5.0:
#       Successfully uninstalled pynvml-11.5.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.12.1
#     Uninstalling dask-2022.12.1:
#       Successfully uninstalled dask-2022.12.1
#   Attempting uninstall: distributed
#     Found existing installation: distributed 2022.12.1
#     Uninstalling distributed-2022.12.1:
#       Successfully uninstalled distributed-2022.12.1
# Successfully installed betterproto-1.2.5 dask-2023.3.2 dask-cuda-23.6.0 distributed-2023.3.2.1 grpclib-0.4.5 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 importlib-metadata-6.8.0 llvmlite-0.40.1 merlin-core-23.6.0 merlin-dataloader-23.6.0 merlin-models-23.4.0+3.g56c7d6a4 npy-append-array-0.9.16 numba-0.57.1 pynvml-11.4.1 stringcase-1.2.0
# Collecting git+https://github.com/NVIDIA-Merlin/nvtabular.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/nvtabular.git (to revision release-23.04) to /tmp/pip-req-build-3ctyl5jl
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/nvtabular.git /tmp/pip-req-build-3ctyl5jl
#   Running command git checkout -b release-23.04 --track origin/release-23.04
#   Switched to a new branch 'release-23.04'
#   Branch 'release-23.04' set up to track remote branch 'release-23.04' from 'origin'.
#   Resolved https://github.com/NVIDIA-Merlin/nvtabular.git to commit 90489194cb14001464cbb2f48287306e86253aa7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: merlin-core>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from nvtabular==23.4.0+2.g90489194) (23.6.0)
# Requirement already satisfied: merlin-dataloader>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from nvtabular==23.4.0+2.g90489194) (23.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nvtabular==23.4.0+2.g90489194) (1.10.1)
# Requirement already satisfied: dask>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2023.3.2)
# Requirement already satisfied: dask-cuda>=22.12.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (23.6.0)
# Requirement already satisfied: distributed>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2023.3.2.1)
# Requirement already satisfied: fsspec>=2022.7.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2023.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.22.4)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.5.3)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (0.57.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (9.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (3.20.3)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (4.65.0)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.13.1)
# Requirement already satisfied: betterproto<2.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (23.1)
# Requirement already satisfied: npy-append-array in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (0.9.16)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (11.4.1)
# Requirement already satisfied: grpclib in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (0.4.5)
# Requirement already satisfied: stringcase in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (6.0.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (6.8.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-cuda>=22.12.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.0.5)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (6.3.1)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.26.16)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2022.7.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.59.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.11.1->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (1.16.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (4.1.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (6.0.4)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->nvtabular==23.4.0+2.g90489194) (4.0.0)
# Building wheels for collected packages: nvtabular
#   Building wheel for nvtabular (pyproject.toml) ... done
#   Created wheel for nvtabular: filename=nvtabular-23.4.0+2.g90489194-cp310-cp310-linux_x86_64.whl size=267128 sha256=64dba0aa6abc1a376aad6644cab948ce8da65e02e375b96b266042508d395c1d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eqdhv4hl/wheels/dd/0c/c3/d1c73a036ab48858faa136adecef31dcc43ba86a5bfdcc982f
# Successfully built nvtabular
# Installing collected packages: nvtabular
# Successfully installed nvtabular-23.4.0+2.g90489194
# Collecting git+https://github.com/NVIDIA-Merlin/core.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/core.git (to revision release-23.04) to /tmp/pip-req-build-umb06s_y
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/core.git /tmp/pip-req-build-umb06s_y
#   Running command git checkout -b release-23.04 --track origin/release-23.04
#   Switched to a new branch 'release-23.04'
#   Branch 'release-23.04' set up to track remote branch 'release-23.04' from 'origin'.
#   Resolved https://github.com/NVIDIA-Merlin/core.git to commit c5c9bc25034bfd8f432711ee5711ad629e79d2c3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (2023.3.2)
# Requirement already satisfied: dask-cuda>=22.12.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (23.6.0)
# Requirement already satisfied: distributed>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (2023.3.2.1)
# Requirement already satisfied: fsspec>=2022.7.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (2023.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (1.22.4)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (1.5.3)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (0.57.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (9.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (3.20.3)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (4.65.0)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (1.13.1)
# Requirement already satisfied: betterproto<2.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (1.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (23.1)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core==23.4.0+4.gc5c9bc2) (11.4.1)
# Requirement already satisfied: grpclib in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (0.4.5)
# Requirement already satisfied: stringcase in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (1.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (6.0.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (6.8.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-cuda>=22.12.0->merlin-core==23.4.0+4.gc5c9bc2) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (1.0.5)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (6.3.1)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (1.26.16)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->merlin-core==23.4.0+4.gc5c9bc2) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core==23.4.0+4.gc5c9bc2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core==23.4.0+4.gc5c9bc2) (2022.7.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core==23.4.0+4.gc5c9bc2) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core==23.4.0+4.gc5c9bc2) (1.59.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.11.1->merlin-core==23.4.0+4.gc5c9bc2) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.2.0->merlin-core==23.4.0+4.gc5c9bc2) (1.16.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (4.1.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (6.0.4)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core==23.4.0+4.gc5c9bc2) (4.0.0)
# Building wheels for collected packages: merlin-core
#   Building wheel for merlin-core (pyproject.toml) ... done
#   Created wheel for merlin-core: filename=merlin_core-23.4.0+4.gc5c9bc2-py3-none-any.whl size=159691 sha256=1efa07374d0db7305596706c018ac4a9f47421405be3c7b98df13769e7c68c52
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zhj51vqi/wheels/fa/da/d9/57c66826656218d976f8a90e1d2ad0a0159e3990e6019ea92b
# Successfully built merlin-core
# Installing collected packages: merlin-core
#   Attempting uninstall: merlin-core
#     Found existing installation: merlin-core 23.6.0
#     Uninstalling merlin-core-23.6.0:
#       Successfully uninstalled merlin-core-23.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# merlin-dataloader 23.6.0 requires merlin-core<23.07,>=23.06, but you have merlin-core 23.4.0+4.gc5c9bc2 which is incompatible.
# Successfully installed merlin-core-23.4.0+4.gc5c9bc2
# Collecting git+https://github.com/NVIDIA-Merlin/system.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/system.git (to revision release-23.04) to /tmp/pip-req-build-umfwohz3
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/system.git /tmp/pip-req-build-umfwohz3
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/system.git /tmp/pip-req-build-umfwohz3 did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/system.git /tmp/pip-req-build-umfwohz3 did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting git+https://github.com/NVIDIA-Merlin/dataloader.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/dataloader.git (to revision release-23.04) to /tmp/pip-req-build-lilwadmu
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/dataloader.git /tmp/pip-req-build-lilwadmu
#   Running command git checkout -b release-23.04 --track origin/release-23.04
#   Switched to a new branch 'release-23.04'
#   Branch 'release-23.04' set up to track remote branch 'release-23.04' from 'origin'.
#   Resolved https://github.com/NVIDIA-Merlin/dataloader.git to commit a00df71b5edd2a2894c99ad38363eb21d46e0ebf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: merlin-core>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-dataloader==23.4.0) (23.4.0+4.gc5c9bc2)
# Requirement already satisfied: dask>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2023.3.2)
# Requirement already satisfied: dask-cuda>=22.12.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (23.6.0)
# Requirement already satisfied: distributed>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2023.3.2.1)
# Requirement already satisfied: fsspec>=2022.7.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2023.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.22.4)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.5.3)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (0.57.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (9.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (3.20.3)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (4.65.0)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.13.1)
# Requirement already satisfied: betterproto<2.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (23.1)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-dataloader==23.4.0) (11.4.1)
# Requirement already satisfied: grpclib in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (0.4.5)
# Requirement already satisfied: stringcase in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (6.0.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (6.8.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-cuda>=22.12.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.0.5)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (6.3.1)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.26.16)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2022.7.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.59.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.11.1->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (1.16.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (4.1.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (6.0.4)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-dataloader==23.4.0) (4.0.0)
# Building wheels for collected packages: merlin-dataloader
#   Building wheel for merlin-dataloader (pyproject.toml) ... done
#   Created wheel for merlin-dataloader: filename=merlin_dataloader-23.4.0-py3-none-any.whl size=34724 sha256=e0b1cec400f01a2f1330cfe10fd2a6850415127227665d8cd83586359a233ffd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sc8azk12/wheels/cb/6b/41/7f6896eb798c030966325ef9b2e9d981f228b726d85367e5b4
# Successfully built merlin-dataloader
# Installing collected packages: merlin-dataloader
#   Attempting uninstall: merlin-dataloader
#     Found existing installation: merlin-dataloader 23.6.0
#     Uninstalling merlin-dataloader-23.6.0:
#       Successfully uninstalled merlin-dataloader-23.6.0
# Successfully installed merlin-dataloader-23.4.0
# Collecting git+https://github.com/NVIDIA-Merlin/Transformers4Rec.git@release-23.04
#   Cloning https://github.com/NVIDIA-Merlin/Transformers4Rec.git (to revision release-23.04) to /tmp/pip-req-build-uwg2okp1
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA-Merlin/Transformers4Rec.git /tmp/pip-req-build-uwg2okp1
#   Running command git checkout -b release-23.04 --track origin/release-23.04
#   Switched to a new branch 'release-23.04'
#   Branch 'release-23.04' set up to track remote branch 'release-23.04' from 'origin'.
#   Resolved https://github.com/NVIDIA-Merlin/Transformers4Rec.git to commit 911355f46531a914be1b25800a11f8023c3c380e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers<5,>=4.12 (from transformers4rec==23.4.0+3.g911355f4)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers4rec==23.4.0+3.g911355f4) (4.65.0)
# Requirement already satisfied: pyarrow>=1.0 in /usr/local/lib/python3.10/dist-packages (from transformers4rec==23.4.0+3.g911355f4) (9.0.0)
# Requirement already satisfied: merlin-models>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from transformers4rec==23.4.0+3.g911355f4) (23.4.0+3.g56c7d6a4)
# Requirement already satisfied: merlin-core>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (23.4.0+4.gc5c9bc2)
# Requirement already satisfied: merlin-dataloader>=23.4.0 in /usr/local/lib/python3.10/dist-packages (from merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (23.4.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow>=1.0->transformers4rec==23.4.0+3.g911355f4) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (4.7.1)
# Requirement already satisfied: dask>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2023.3.2)
# Requirement already satisfied: dask-cuda>=22.12.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (23.6.0)
# Requirement already satisfied: distributed>=2022.11.1 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2023.3.2.1)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.5.3)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (0.57.1)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (3.20.3)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.13.1)
# Requirement already satisfied: betterproto<2.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.2.5)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (11.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.12->transformers4rec==23.4.0+3.g911355f4) (3.4)
# Requirement already satisfied: grpclib in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (0.4.5)
# Requirement already satisfied: stringcase in /usr/local/lib/python3.10/dist-packages (from betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.4.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (6.8.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-cuda>=22.12.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (3.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.0.5)
# Requirement already satisfied: psutil>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (6.3.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2022.7.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata>=1.2.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.59.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2022.11.1->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.2.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (1.16.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (4.1.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (6.0.4)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib->betterproto<2.0.0->merlin-core>=23.4.0->merlin-models>=23.4.0->transformers4rec==23.4.0+3.g911355f4) (4.0.0)
# Building wheels for collected packages: transformers4rec
#   Building wheel for transformers4rec (pyproject.toml) ... done
#   Created wheel for transformers4rec: filename=transformers4rec-23.4.0+3.g911355f4-py3-none-any.whl size=480911 sha256=958244af3f6b09cb92f39148a41ed296092af6ae505fde9bc88fd8714ef4d4df
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d0apqz80/wheels/63/a2/0e/3af84cae1646222b5895dcfdae5b896e54c0ab47b78f665a2e
# Successfully built transformers4rec
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers, transformers4rec
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0 transformers4rec-23.4.0+3.g911355f4
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (1.7.6)
# Collecting lightfm
#   Downloading lightfm-1.17.tar.gz (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting implicit
#   Downloading implicit-0.7.0-cp310-cp310-manylinux2014_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from lightfm) (2.27.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lightfm) (1.2.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from implicit) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lightfm) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lightfm) (3.2.0)
# Building wheels for collected packages: lightfm
#   Building wheel for lightfm (setup.py) ... done
#   Created wheel for lightfm: filename=lightfm-1.17-cp310-cp310-linux_x86_64.whl size=808182 sha256=a66a9e1f43491fd1298c778558ceffb5eff0b2acf9442c99b36689989ba82397
#   Stored in directory: /root/.cache/pip/wheels/4f/9b/7e/0b256f2168511d8fa4dae4fae0200fdbd729eb424a912ad636
# Successfully built lightfm
# Installing collected packages: implicit, lightfm
# Successfully installed implicit-0.7.0 lightfm-1.17

# %% [markdown]
# ## Load Data
# Reference
# - https://github.com/NVIDIA-Merlin/models/blob/main/examples/02-Merlin-Models-and-NVTabular-integration.ipynb

# %%
import os
import shutil
import numpy as np
from nvtabular import ops
from merlin.schema.tags import Tags
import merlin.io
import merlin.models.tf as mm

import nvtabular as nvt

from os import path

# Get dataframe library - cudf or pandas
from merlin.core.dispatch import get_lib
pd = get_lib()
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
DATA_DIR = os.environ.get(
    "DATA_DIR", os.path.expanduser("/content/drive/MyDrive/ml-twotower-model/data/")
)

# %%
import glob

TRAIN_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, "train", "*.parquet")))
VALID_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, "valid", "*.parquet")))
TEST_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, "test", "*.parquet")))
TRAIN_PATHS, VALID_PATHS, TEST_PATHS
# Out:
# (['/content/drive/MyDrive/ml-twotower-model/data/train/part_0.parquet'],
#  ['/content/drive/MyDrive/ml-twotower-model/data/valid/part_0.parquet'],
#  ['/content/drive/MyDrive/ml-twotower-model/data/test/part_0.parquet'])

# %%
train = merlin.io.Dataset(
    os.path.join(DATA_DIR, "train"), engine="parquet"
)
valid = merlin.io.Dataset(
    os.path.join(DATA_DIR, "valid"), engine="parquet"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:264: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.USER_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.USER: 'user'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:264: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.USER_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.USER: 'user'>, <Tags.ID: 'id'>].
#   warnings.warn(

# %%
schema = train.schema.select_by_tag([Tags.ITEM_ID, Tags.USER_ID, Tags.ITEM, Tags.USER])
schema
# Out:
# [{'name': 'movie_id', 'tags': {<Tags.ITEM_ID: 'item_id'>, <Tags.ID: 'id'>, <Tags.ITEM: 'item'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'num_buckets': None, 'max_size': 0.0, 'start_index': 0.0, 'cat_path': './/categories/unique.movie_id.parquet', 'embedding_sizes': {'cardinality': 1617.0, 'dimension': 100.0}, 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 1616, 'name': 'movie_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'user_id', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ID: 'id'>, <Tags.USER_ID: 'user_id'>, <Tags.USER: 'user'>}, 'properties': {'cat_path': './/categories/unique.user_id.parquet', 'freq_threshold': 0.0, 'num_buckets': None, 'start_index': 0.0, 'max_size': 0.0, 'embedding_sizes': {'cardinality': 752.0, 'dimension': 65.0}, 'domain': {'min': 0, 'max': 751, 'name': 'user_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'gender', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM: 'item'>}, 'properties': {'embedding_sizes': {'cardinality': 3.0, 'dimension': 16.0}, 'cat_path': './/categories/unique.gender.parquet', 'num_buckets': None, 'max_size': 0.0, 'start_index': 0.0, 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 2, 'name': 'gender'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'occupation', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM: 'item'>}, 'properties': {'freq_threshold': 0.0, 'cat_path': './/categories/unique.occupation.parquet', 'embedding_sizes': {'dimension': 16.0, 'cardinality': 22.0}, 'start_index': 0.0, 'num_buckets': None, 'max_size': 0.0, 'domain': {'min': 0, 'max': 21, 'name': 'occupation'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'genres', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM: 'item'>}, 'properties': {'num_buckets': None, 'freq_threshold': 0.0, 'embedding_sizes': {'dimension': 16.0, 'cardinality': 20.0}, 'start_index': 0.0, 'max_size': 0.0, 'cat_path': './/categories/unique.genres.parquet', 'domain': {'min': 0, 'max': 19, 'name': 'genres'}, 'value_count': {'min': 0, 'max': None}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None), Dimension(min=0, max=None)))), 'is_list': True, 'is_ragged': True}]

# %%
# select only trainable features and exclude the target
train.schema = schema
valid.schema = schema

# %%
assert len(schema.select_by_tag(Tags.TARGET).column_names) == 0

# %% [markdown]
# ## Build Model
# Reference
# - https://github.com/NVIDIA-Merlin/models/blob/main/examples/05-Retrieval-Model.ipynb

# %%
tower_dim = 64

# create user schema using USER tag
user_schema = schema.select_by_tag(Tags.USER)
# create user (query) tower input block
user_inputs = mm.InputBlockV2(user_schema)
# create user (query) encoder block
query = mm.Encoder(user_inputs, mm.MLPBlock([128, tower_dim], no_activation_last_layer=True))

# create item schema using ITEM tag
item_schema = schema.select_by_tag(Tags.ITEM)
# create item (candidate) tower input block
item_inputs = mm.InputBlockV2(item_schema)
# create item (candidate) encoder block
candidate = mm.Encoder(item_inputs, mm.MLPBlock([128, tower_dim], no_activation_last_layer=True))

# %%
model = mm.TwoTowerModelV2(query, candidate)

# %%
model.compile(optimizer="adam", run_eagerly=False, metrics=[mm.RecallAt(10), mm.NDCGAt(10)])
model.fit(train, validation_data=valid, batch_size=64, epochs=5)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.USER_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.USER: 'user'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.USER_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.USER: 'user'>, <Tags.ID: 'id'>].
#   warnings.warn(
# Epoch 1/5
# 1250/1250 [==============================] - 27s 19ms/step - loss: 1.2433 - recall_at_10: 0.9880 - ndcg_at_10: 0.7334 - regularization_loss: 0.0000e+00 - loss_batch: 1.2432 - val_loss: 36.8280 - val_recall_at_10: 0.2958 - val_ndcg_at_10: 0.1603 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 14.6857
# Epoch 2/5
# 1250/1250 [==============================] - 23s 17ms/step - loss: 1.2314 - recall_at_10: 0.9882 - ndcg_at_10: 0.7380 - regularization_loss: 0.0000e+00 - loss_batch: 1.2313 - val_loss: 35.4536 - val_recall_at_10: 0.2929 - val_ndcg_at_10: 0.1581 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 16.1756
# Epoch 3/5
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.2228 - recall_at_10: 0.9903 - ndcg_at_10: 0.7441 - regularization_loss: 0.0000e+00 - loss_batch: 1.2228 - val_loss: 33.8036 - val_recall_at_10: 0.2947 - val_ndcg_at_10: 0.1601 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 12.5559
# Epoch 4/5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.2079 - recall_at_10: 0.9896 - ndcg_at_10: 0.7453 - regularization_loss: 0.0000e+00 - loss_batch: 1.2079 - val_loss: 32.8395 - val_recall_at_10: 0.2920 - val_ndcg_at_10: 0.1620 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 14.5175
# Epoch 5/5
# 1250/1250 [==============================] - 24s 18ms/step - loss: 1.1989 - recall_at_10: 0.9893 - ndcg_at_10: 0.7496 - regularization_loss: 0.0000e+00 - loss_batch: 1.1988 - val_loss: 30.6640 - val_recall_at_10: 0.2961 - val_ndcg_at_10: 0.1651 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 13.3974

# %% [markdown]
# ## Evaluate the Model top-k results

# %%
# Top-K evaluation
from merlin.models.utils.dataset import unique_rows_by_features

candidate_features = unique_rows_by_features(train, Tags.ITEM, Tags.ITEM_ID)
candidate_features.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:264: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
#    movie_id  gender  occupation           genres
# 0         1       1           1  [6, 3, 8, 5, 7]
# 1        45       1           3           [2, 5]
# 2       357       1           1           [1, 5]
# 3       270       1           2              [1]
# 4       336       1          15              [4]

# %%
topk = 20
topk_model = model.to_top_k_encoder(candidate_features, k=topk, batch_size=128)

# we can set `metrics` param in the `compile(), if we want
topk_model.compile(run_eagerly=False)
# Out:
# WARNING:absl:Found untraced functions such as prepare_list_features_1_layer_call_fn, prepare_list_features_1_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_1_layer_call_fn while saving (showing 5 of 32). These functions will not be directly callable after loading.
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:264: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/schema/tags.py:149: UserWarning: Compound tags like Tags.ITEM_ID have been deprecated and will be removed in a future version. Please use the atomic versions of these tags, like [<Tags.ITEM: 'item'>, <Tags.ID: 'id'>].
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/utils.py in raise_on_meta_error(funcname, udf)
#     192     try:
# --> 193         yield
#     194     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in _emulate(func, udf, *args, **kwargs)
#    6792     with raise_on_meta_error(funcname(func), udf=udf), check_numeric_only_deprecation():
# -> 6793         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    6794
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py in __call__(self, df, filter_input_columns, filter_output_columns)
#      50         # Iterate over batches of df and collect predictions
# ---> 51         outputs = concat_func([encode_func(self.model, batch) for batch in iterator_func(df)])
#      52         output_names = self.output_names or [str(i) for i in range(outputs.shape[1])]
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py in <listcomp>(.0)
#      50         # Iterate over batches of df and collect predictions
# ---> 51         outputs = concat_func([encode_func(self.model, batch) for batch in iterator_func(df)])
#      52         output_names = self.output_names or [str(i) for i in range(outputs.shape[1])]
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py in model_encode(model, batch)
#     154
# --> 155     model_outputs = model(batch[0])
#     156
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in __call__(self, inputs, **kwargs)
#     188
# --> 189         return super().__call__(inputs, **kwargs)
#     190
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in call(self, inputs, targets, training, testing, **kwargs)
#     172             inputs, targets = inputs
# --> 173         return combinators.call_sequentially(
#     174             list(self.to_call),
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call_sequentially(layers, inputs, **kwargs)
#     839     for layer in layers:
# --> 840         outputs = call_layer(layer, outputs, **kwargs)
#     841
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/tabular.py in _tabular_call(self, inputs, pre, post, merge_with, aggregation, *args, **kwargs)
#     479     # This will call the `call` method implemented by the super class.
# --> 480     outputs = self.super().__call__(inputs, *args, **kwargs)  # type: ignore
#     481
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py in __call__(self, *args, **kwargs)
#      57
# ---> 58         return super().__call__(*args, **kwargs)
#      59
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call(self, inputs, **kwargs)
#     565             layer_inputs = self._maybe_filter_layer_inputs_using_schema(name, layer, inputs)
# --> 566             out = call_layer(layer, layer_inputs, **kwargs)
#     567             if not isinstance(out, dict):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/tabular.py in _tabular_call(self, inputs, pre, post, merge_with, aggregation, *args, **kwargs)
#     479     # This will call the `call` method implemented by the super class.
# --> 480     outputs = self.super().__call__(inputs, *args, **kwargs)  # type: ignore
#     481
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py in __call__(self, *args, **kwargs)
#      57
# ---> 58         return super().__call__(*args, **kwargs)
#      59
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call(self, inputs, **kwargs)
#     565             layer_inputs = self._maybe_filter_layer_inputs_using_schema(name, layer, inputs)
# --> 566             out = call_layer(layer, layer_inputs, **kwargs)
#     567             if not isinstance(out, dict):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py in __call__(self, *args, **kwargs)
#      57
# ---> 58         return super().__call__(*args, **kwargs)
#      59
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/inputs/embedding.py in call(self, inputs, **kwargs)
#     389                 if feature_name in inputs:
# --> 390                     out[feature_name] = self._call_table(inputs[feature_name], **kwargs)
#     391         else:
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/inputs/embedding.py in _call_table(self, inputs, **kwargs)
#     424                 inputs = tf.squeeze(inputs, axis=-1)
# --> 425             out = call_layer(self.table, inputs, **kwargs)
#     426             if len(out.get_shape()) > 2 and self.sequence_combiner is not None:
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#
# UnimplementedError: Exception encountered when calling layer 'genres' (type Embedding).
#
# {{function_node __wrapped__Cast_device_/job:localhost/replica:0/task:0/device:CPU:0}} Cast string to int32 is not supported [Op:Cast]
#
# Call arguments received by layer 'genres' (type Embedding):
#   • inputs=tf.Tensor(shape=(2,), dtype=string)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5554053d4147> in <cell line: 2>()
#       1 topk = 20
# ----> 2 topk_model = model.to_top_k_encoder(candidate_features, k=topk, batch_size=128)
#       3
#       4 # we can set `metrics` param in the `compile(), if we want
#       5 topk_model.compile(run_eagerly=False)
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/models/base.py in to_top_k_encoder(self, candidates, candidate_id, strategy, k, **kwargs)
#    2497             a given query, by default brute-force-topk
#    2498         """
# -> 2499         candidates_embeddings = self.candidate_embeddings(candidates, index=candidate_id, **kwargs)
#    2500         topk_model = TopKEncoder(
#    2501             self.query_encoder,
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/models/base.py in candidate_embeddings(self, dataset, index, **kwargs)
#    2388
#    2389             if dataset is not None and hasattr(candidate, "encode"):
# -> 2390                 return candidate.encode(dataset, index=index, **kwargs)
#    2391
#    2392             if hasattr(candidate, "to_dataset"):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in encode(self, dataset, index, batch_size, **kwargs)
#     101             raise ValueError(f"Invalid index: {index}")
#     102
# --> 103         return self.batch_predict(
#     104             dataset,
#     105             batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in batch_predict(self, dataset, batch_size, output_schema, index, **kwargs)
#     161         if output_schema:
#     162             encode_kwargs["filter_input_columns"] = output_schema.column_names
# --> 163         predictions = dataset.map_partitions(model_encode, **encode_kwargs)
#     164         if index:
#     165             predictions = predictions.set_index(index)
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in map_partitions(self, func, *args, **kwargs)
#     996         None as the division.
#     997         """
# --> 998         return map_partitions(func, self, *args, **kwargs)
#     999
#    1000     @insert_meta_param_description(pad=12)
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in map_partitions(func, meta, enforce_metadata, transform_divisions, align_dataframes, *args, **kwargs)
#    6861     dfs = [df for df in args if isinstance(df, _Frame)]
#    6862
# -> 6863     meta = _get_meta_map_partitions(args, dfs, func, kwargs, meta, parent_meta)
#    6864     if all(isinstance(arg, Scalar) for arg in args):
#    6865         layer = {
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in _get_meta_map_partitions(args, dfs, func, kwargs, meta, parent_meta)
#    6972         # Use non-normalized kwargs here, as we want the real values (not
#    6973         # delayed values)
# -> 6974         meta = _emulate(func, *args, udf=True, **kwargs)
#    6975         meta_is_emulated = True
#    6976     else:
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py in _emulate(func, udf, *args, **kwargs)
#    6790     dd.Series, using internal cache (``_meta``) for calculation
#    6791     """
# -> 6792     with raise_on_meta_error(funcname(func), udf=udf), check_numeric_only_deprecation():
#    6793         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    6794
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     151                 value = typ()
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#     155                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/utils.py in raise_on_meta_error(funcname, udf)
#     212         )
#     213         msg = msg.format(f" in `{funcname}`" if funcname else "", repr(e), tb)
# --> 214         raise ValueError(msg) from e
#     215
#     216
#
# ValueError: Metadata inference failed in `<merlin.models.tf.utils.batch_utils.TFModelEncode `.
#
# You have supplied a custom function and Dask is unable to
# determine the type of output that that function returns.
#
# To resolve this please provide a meta= keyword.
# The docstring of the Dask function you ran should have more information.
#
# Original error is below:
# ------------------------
# UnimplementedError()
#
# Traceback:
# ---------
#   File "/usr/local/lib/python3.10/dist-packages/dask/dataframe/utils.py", line 193, in raise_on_meta_error
#     yield
#   File "/usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py", line 6793, in _emulate
#     return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py", line 51, in __call__
#     outputs = concat_func([encode_func(self.model, batch) for batch in iterator_func(df)])
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py", line 51, in <listcomp>
#     outputs = concat_func([encode_func(self.model, batch) for batch in iterator_func(df)])
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/batch_utils.py", line 155, in model_encode
#     model_outputs = model(batch[0])
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py", line 189, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py", line 173, in call
#     return combinators.call_sequentially(
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py", line 840, in call_sequentially
#     outputs = call_layer(layer, outputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py", line 449, in call_layer
#     return layer(inputs, *args, **filtered_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/tabular.py", line 480, in _tabular_call
#     outputs = self.super().__call__(inputs, *args, **kwargs)  # type: ignore
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py", line 58, in __call__
#     return super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py", line 566, in call
#     out = call_layer(layer, layer_inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py", line 449, in call_layer
#     return layer(inputs, *args, **filtered_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/tabular.py", line 480, in _tabular_call
#     outputs = self.super().__call__(inputs, *args, **kwargs)  # type: ignore
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py", line 58, in __call__
#     return super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py", line 566, in call
#     out = call_layer(layer, layer_inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py", line 449, in call_layer
#     return layer(inputs, *args, **filtered_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py", line 58, in __call__
#     return super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/inputs/embedding.py", line 390, in call
#     out[feature_name] = self._call_table(inputs[feature_name], **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/inputs/embedding.py", line 425, in _call_table
#     out = call_layer(self.table, inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py", line 449, in call_layer
#     return layer(inputs, *args, **filtered_kwargs)

# %% [markdown]
# ## TMP

# %%
# model = mm.DLRMModel(
#     train.schema,
#     embedding_dim=64,
#     bottom_block=mm.MLPBlock([128, 64]),
#     top_block=mm.MLPBlock([128, 64, 32]),
#     prediction_tasks=mm.BinaryOutput(
#         train.schema.select_by_tag(Tags.TARGET).column_names[0]
#     ),
# )
# model.compile(optimizer="adam")
# model.fit(train, batch_size=1024)

# %%
metrics = model.evaluate(valid, batch_size=1024, return_dict=True)

metrics
