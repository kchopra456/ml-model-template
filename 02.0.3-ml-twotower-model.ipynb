# %% [markdown]
# ## Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# %cd rapidsai-csp-utils
# !git checkout 22.12-patch
# %cd ..
# !python rapidsai-csp-utils/colab/env-check.py
# !python rapidsai-csp-utils/colab/pip-install.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 390 (delta 89), reused 51 (delta 51), pack-reused 269
# Receiving objects: 100% (390/390), 107.11 KiB | 1.98 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# /content/rapidsai-csp-utils
# Branch '22.12-patch' set up to track remote branch '22.12-patch' from 'origin'.
# Switched to a new branch '22.12-patch'
# /content
# Collecting pynvml
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 945.3 kB/s eta 0:00:00
# Installing collected packages: pynvml
# Successfully installed pynvml-11.5.0
# Traceback (most recent call last):
#   File "/content/rapidsai-csp-utils/colab/env-check.py", line 26, in <module>
#     gpu_name = pynvml.nvmlDeviceGetName(pynvml.nvmlDeviceGetHandleByIndex(0)).decode('UTF-8')
# AttributeError: 'str' object has no attribute 'decode'. Did you mean: 'encode'?
# Traceback (most recent call last):
#   File "/content/rapidsai-csp-utils/colab/pip-install.py", line 26, in <module>
#     gpu_name = pynvml.nvmlDeviceGetName(pynvml.nvmlDeviceGetHandleByIndex(0)).decode('UTF-8')
# AttributeError: 'str' object has no attribute 'decode'. Did you mean: 'encode'?

# %%
# %%bash
# # Install the Merlin Framework
# pip install -Uq git+https://github.com/NVIDIA-Merlin/models.git@release-23.04
# pip install -Uq git+https://github.com/NVIDIA-Merlin/nvtabular.git@release-23.04
# pip install -Uq git+https://github.com/NVIDIA-Merlin/core.git@release-23.04
# # pip install -Uq git+https://github.com/NVIDIA-Merlin/system.git@release-23.04
# # pip install -Uq git+https://github.com/NVIDIA-Merlin/dataloader.git@release-23.04
# pip install -Uq git+https://github.com/NVIDIA-Merlin/Transformers4Rec.git@release-23.04
# # pip install -Uq xgboost lightfm implicit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.5/985.5 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# merlin-dataloader 23.6.0 requires merlin-core<23.07,>=23.06, but you have merlin-core 23.4.0+4.gc5c9bc2 which is incompatible.

# %%
# %%bash
# pip install -q tensorflow-recommenders
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 1.4 MB/s eta 0:00:00

# %% [markdown]
# ## Load Data
# Reference
# - https://github.com/NVIDIA-Merlin/models/blob/main/examples/02-Merlin-Models-and-NVTabular-integration.ipynb

# %%
import os
import shutil
import numpy as np
from nvtabular import ops
from merlin.schema.tags import Tags
import merlin.io
import merlin.models.tf as mm

import nvtabular as nvt
import tensorflow as tf


from os import path

# Get dataframe library - cudf or pandas
from merlin.core.dispatch import get_lib
pd = get_lib()
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/dtypes/mappings/triton.py:53: UserWarning: Triton dtype mappings did not load successfully due to an error: No module named 'tritonclient'
#   warn(f"Triton dtype mappings did not load successfully due to an error: {exc.msg}")
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
DATA_DIR = os.environ.get(
    "DATA_DIR", os.path.expanduser("/content/drive/MyDrive/ml-twotower-model/data/")
)

# %%
import glob

USE_AUGMENTED_DATASET= False
DATA_VERSION = 'v4'

_TRAIN,_VALID,_TEST = ('train_aug', 'valid_aug', 'test_aug') if USE_AUGMENTED_DATASET else ('train', 'valid', 'test')

TRAIN_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _TRAIN + f'_{DATA_VERSION}', "*.parquet")))
VALID_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _VALID + f'_{DATA_VERSION}', "*.parquet")))
TEST_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _TEST + f'_{DATA_VERSION}', "*.parquet")))

# TRAIN_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _TRAIN , "*.parquet")))
# VALID_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _VALID , "*.parquet")))
# TEST_PATHS = sorted(glob.glob(os.path.join(DATA_DIR, _TEST , "*.parquet")))
TRAIN_PATHS, VALID_PATHS, TEST_PATHS
# Out:
# (['/content/drive/MyDrive/ml-twotower-model/data/train_v4/part_0.parquet'],
#  ['/content/drive/MyDrive/ml-twotower-model/data/valid_v4/part_0.parquet'],
#  ['/content/drive/MyDrive/ml-twotower-model/data/test_v4/part_0.parquet'])

# %%
train = merlin.io.Dataset(
    TRAIN_PATHS, engine="parquet"
)
valid = merlin.io.Dataset(
    VALID_PATHS, engine="parquet"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(

# %%
schema = train.schema.select_by_tag([
    Tags.ITEM_ID,
    Tags.USER_ID,
    Tags.ITEM,
    Tags.USER,
    # Tags.TARGET,
    ])
schema
# Out:
# [{'name': 'movie_id', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ID: 'id'>, <Tags.ITEM: 'item'>}, 'properties': {'freq_threshold': 0.0, 'num_buckets': None, 'start_index': 0.0, 'cat_path': './/categories/unique.movie_id.parquet', 'embedding_sizes': {'dimension': 102.0, 'cardinality': 1665.0}, 'max_size': 0.0, 'domain': {'min': 0, 'max': 1664, 'name': 'movie_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'user_id', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ID: 'id'>, <Tags.USER: 'user'>}, 'properties': {'cat_path': './/categories/unique.user_id.parquet', 'embedding_sizes': {'dimension': 74.0, 'cardinality': 944.0}, 'max_size': 0.0, 'num_buckets': None, 'start_index': 0.0, 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 943, 'name': 'user_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'gender', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'num_buckets': None, 'embedding_sizes': {'dimension': 16.0, 'cardinality': 3.0}, 'start_index': 0.0, 'freq_threshold': 0.0, 'max_size': 0.0, 'cat_path': './/categories/unique.gender.parquet', 'domain': {'min': 0, 'max': 2, 'name': 'gender'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'occupation', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'embedding_sizes': {'cardinality': 22.0, 'dimension': 16.0}, 'freq_threshold': 0.0, 'max_size': 0.0, 'start_index': 0.0, 'cat_path': './/categories/unique.occupation.parquet', 'num_buckets': None, 'domain': {'min': 0, 'max': 21, 'name': 'occupation'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'genres', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM: 'item'>}, 'properties': {'num_buckets': None, 'start_index': 0.0, 'embedding_sizes': {'cardinality': 20.0, 'dimension': 16.0}, 'freq_threshold': 0.0, 'cat_path': './/categories/unique.genres.parquet', 'max_size': 0.0, 'domain': {'min': 0, 'max': 19, 'name': 'genres'}, 'value_count': {'min': 0, 'max': None}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None), Dimension(min=0, max=None)))), 'is_list': True, 'is_ragged': True}]

# %%
# schema = schema.excluding_by_name('genres')

# %%
train.head()
# Out:
#    movie_id  user_id  gender  occupation     genres  rating  movie_id_raw
# 0       121       13       1           1        [1]     1.0           134
# 1       196       33       1          18  [1, 4, 8]     1.0            31
# 2       451      901       1           1     [2, 5]     1.0           354
# 3        48       88       2           8     [2, 5]     0.0           202
# 4       330       30       1           4        [1]     0.0           708

# %%
# missing from load
schema['movie_id'].tags._tags.add(Tags.ITEM_ID)
schema['user_id'].tags._tags.add(Tags.USER_ID)

# %%
# train = merlin.io.Dataset(train.to_ddf().compute().drop('rating', axis=1))
# valid = merlin.io.Dataset(valid.to_ddf().compute().drop('rating', axis=1))

# %%
# select only trainable features and exclude the target
train.schema = schema
valid.schema = schema

# %%
train.schema
# Out:
# [{'name': 'movie_id', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM_ID: 'item_id'>, <Tags.ID: 'id'>, <Tags.ITEM: 'item'>}, 'properties': {'freq_threshold': 0.0, 'num_buckets': None, 'start_index': 0.0, 'cat_path': './/categories/unique.movie_id.parquet', 'embedding_sizes': {'dimension': 102.0, 'cardinality': 1665.0}, 'max_size': 0.0, 'domain': {'min': 0, 'max': 1664, 'name': 'movie_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'user_id', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER_ID: 'user_id'>, <Tags.ID: 'id'>, <Tags.USER: 'user'>}, 'properties': {'cat_path': './/categories/unique.user_id.parquet', 'embedding_sizes': {'dimension': 74.0, 'cardinality': 944.0}, 'max_size': 0.0, 'num_buckets': None, 'start_index': 0.0, 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 943, 'name': 'user_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'gender', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'num_buckets': None, 'embedding_sizes': {'dimension': 16.0, 'cardinality': 3.0}, 'start_index': 0.0, 'freq_threshold': 0.0, 'max_size': 0.0, 'cat_path': './/categories/unique.gender.parquet', 'domain': {'min': 0, 'max': 2, 'name': 'gender'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'occupation', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'embedding_sizes': {'cardinality': 22.0, 'dimension': 16.0}, 'freq_threshold': 0.0, 'max_size': 0.0, 'start_index': 0.0, 'cat_path': './/categories/unique.occupation.parquet', 'num_buckets': None, 'domain': {'min': 0, 'max': 21, 'name': 'occupation'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'genres', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.ITEM: 'item'>}, 'properties': {'num_buckets': None, 'start_index': 0.0, 'embedding_sizes': {'cardinality': 20.0, 'dimension': 16.0}, 'freq_threshold': 0.0, 'cat_path': './/categories/unique.genres.parquet', 'max_size': 0.0, 'domain': {'min': 0, 'max': 19, 'name': 'genres'}, 'value_count': {'min': 0, 'max': None}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None), Dimension(min=0, max=None)))), 'is_list': True, 'is_ragged': True}]

# %%
assert len(train.schema.select_by_tag(Tags.TARGET).column_names) == 0

# %% [markdown]
# ## Build Model
# Reference
# - https://github.com/NVIDIA-Merlin/models/blob/main/examples/05-Retrieval-Model.ipynb

# %% [markdown]
# ### Model definition

# %%
def build_towers(schema=schema, tower_dim = (128, 64)):
    # create user schema using USER tag
    user_schema = schema.select_by_tag(Tags.USER)
    # create user (query) tower input block
    user_inputs = mm.InputBlockV2(user_schema)
    # create user (query) encoder block
    query = mm.Encoder(user_inputs, mm.MLPBlock(tower_dim, no_activation_last_layer=True))

    # create item schema using ITEM tag
    item_schema = schema.select_by_tag(Tags.ITEM)
    # create item (candidate) tower input block
    item_inputs = mm.InputBlockV2(item_schema)
    # create item (candidate) encoder block
    candidate = mm.Encoder(item_inputs, mm.MLPBlock(tower_dim, no_activation_last_layer=True))

    return mm.TwoTowerModelV2(query, candidate)

# %%
import matplotlib.pyplot as plt
import numpy as np

default_plot_metrics = {
    'Loss': 'loss',
    'Recall@10': 'recall_at_10',
    'Ndcg@10': 'ndcg_at_10',
    'AUC': 'auc'
}

def plot_metrics(train_history, val_history, metrics=default_plot_metrics, figsize=(18, 6)):
    # Create a figure and axis
    fig, ax = plt.subplots(1, len(metrics), figsize=figsize)
    metric_map = {}

    for i, (k, m) in enumerate(metrics.items()):
        train_metric = train_history[m]
        val_metric = val_history[m]
        epochs = np.arange(1, len(train_metric) + 1)

        # Plot metric
        ax[i].plot(epochs, train_metric, label=f'Train {k}', marker='o')
        ax[i].plot(epochs, val_metric, label=f'Validation {k}', marker='o')
        ax[i].set_xlabel('Epochs')
        ax[i].set_ylabel(k)
        ax[i].set_title(f'{k} Over Epochs')
        ax[i].legend()

    # Adjust layout
    plt.tight_layout()

    # Show the plot
    plt.show()

# %%
from collections import defaultdict
def merge_model_history(*history):
    _history = defaultdict(list)
    for _h in history:
        h = _h.history
        for k,v in h.items():
            _history[k].extend(v)
    return _history

# %%
# hack block, as Merlin top_k_encoder is broken
from merlin.models.tf.loader import Loader
from merlin.schema import ColumnSchema, Schema, Tags
def batch_predict(
        self,
        dataset: merlin.io.Dataset,
        batch_size: int,
        output_schema = None,
        index = None,
        **kwargs,
    ) -> merlin.io.Dataset:
        """Batched prediction using Dask.
        Parameters
        ----------
        dataset: merlin.io.Dataset
            Dataset to predict on.
        batch_size: int
            Batch size to use for prediction.
        Returns
        -------
        merlin.io.Dataset
        """

        if index:
            if isinstance(index, ColumnSchema):
                index = Schema([index])
            elif isinstance(index, str):
                index = Schema([self.schema[index]])
            elif isinstance(index, Tags):
                index = self.schema.select_by_tag(index)
            elif not isinstance(index, Schema):
                raise ValueError(f"Invalid index: {index}")

            if len(index) != 1:
                raise ValueError("Only one column can be used as index")
            index = index.first.name

        if hasattr(dataset, "schema"):
            if not set(self.schema.column_names).issubset(set(dataset.schema.column_names)):
                raise ValueError(
                    f"Model schema {self.schema.column_names} does not match dataset schema"
                    + f" {dataset.schema.column_names}"
                )

        # Check if merlin-dataset is passed
        if hasattr(dataset, "to_ddf"):
            # hack
            dataset = dataset.to_ddf().compute()

        from merlin.models.tf.utils.batch_utils import TFModelEncode

        model_encode = TFModelEncode(self, batch_size=batch_size, **kwargs)
        encode_kwargs = {}
        if output_schema:
            encode_kwargs["filter_input_columns"] = output_schema.column_names
        # hack
        predictions = model_encode(dataset, **encode_kwargs)
        if index:
            predictions = predictions.set_index(index)

        return merlin.io.Dataset(predictions)

from merlin.models.tf.core.encoder import TopKEncoder
def to_top_k_encoder(
        model,
        candidates: merlin.io.Dataset = None,
        candidate_id=Tags.ITEM_ID,
        strategy = "brute-force-topk",
        k: int = 10,
        batch_size = 512
):
    output_schema = model.schema.select_by_tag(candidate_id)
    if candidate_id == Tags.ITEM_ID:
        candidate_encoder = model.candidate_encoder
        target_encoder =  model.query_encoder
    else:
        target_encoder = model.candidate_encoder
        candidate_encoder =  model.query_encoder

    # https://github.com/NVIDIA-Merlin/models/blob/stable/merlin/models/tf/models/base.py#L2479
    candidates_embeddings = batch_predict(
                candidate_encoder,
                candidates,
                batch_size=batch_size,
                output_schema=output_schema,
                index=candidate_id,
                output_concat_func=np.concatenate,
            )
    return TopKEncoder(
            target_encoder,
            topk_layer=strategy,
            k=k,
            candidates=candidates_embeddings,
            target=model.encoder._schema.select_by_tag(candidate_id).first.name,
        )

# %%
# Top-K evaluation
from merlin.models.utils.dataset import unique_rows_by_features
# from functools import cache


def get_candidates(data, candidate_id = Tags.ITEM):
    candidate_features = unique_rows_by_features(data, candidate_id)
    print(f'Candidate set rows:', candidate_features.num_rows)
    return candidate_features


def evaluate_model(model, ds, topk=10, batch_size=1024, target_id='movie_id', candidate_id = Tags.ITEM):
    candidate_features = get_candidates(ds, candidate_id)

    topk_model = to_top_k_encoder(model, candidate_features, k=topk, batch_size=batch_size, candidate_id=candidate_id)
    topk_model.compile(run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=[topk])
                                            ])
    eval_loader = mm.Loader(ds, batch_size=batch_size).map(mm.ToTarget(schema, target_id))
    return topk_model.evaluate(eval_loader, return_dict=True)

# %% [markdown]
# ### model_v3

# %%
# _tower_dim = (64, 128) # @param
_tower_dim = (64, 32) # @param
_learning_rate = 0.01 # @param
_batch_size = 128 # @param
_epochs = 50 # @param
_validation_batch_size = 256 # @param

# %%
model_v3 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [10]
model_v3.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True,
                                                            #  reduction=tf.keras.losses.Reduction.SUM # https://github.com/tensorflow/recommenders/blob/v0.7.3/tensorflow_recommenders/tasks/retrieval.py#L84
                                                             ),
)
history_v3 = []

# %% [markdown]
# #### model

# %%
history_v3.append(model_v3.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size))
# Out:
# Epoch 1/50
# 549/549 [==============================] - 15s 26ms/step - loss: 4.2726 - auc_11: 0.6753 - recall_at_10: 0.3111 - mrr_at_10: 0.1197 - ndcg_at_10: 0.1639 - map_at_10: 0.1197 - precision_at_10: 0.0311 - regularization_loss: 0.0000e+00 - loss_batch: 4.2699 - val_loss: 4.7052 - val_auc_11: 0.5861 - val_recall_at_10: 0.2048 - val_mrr_at_10: 0.0704 - val_ndcg_at_10: 0.1013 - val_map_at_10: 0.0704 - val_precision_at_10: 0.0205 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.9812
# Epoch 2/50
# 549/549 [==============================] - 17s 28ms/step - loss: 4.2721 - auc_11: 0.6697 - recall_at_10: 0.3053 - mrr_at_10: 0.1176 - ndcg_at_10: 0.1610 - map_at_10: 0.1176 - precision_at_10: 0.0305 - regularization_loss: 0.0000e+00 - loss_batch: 4.2692 - val_loss: 4.6999 - val_auc_11: 0.5908 - val_recall_at_10: 0.2188 - val_mrr_at_10: 0.0722 - val_ndcg_at_10: 0.1059 - val_map_at_10: 0.0722 - val_precision_at_10: 0.0219 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0556
# Epoch 3/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2680 - auc_11: 0.6762 - recall_at_10: 0.3118 - mrr_at_10: 0.1213 - ndcg_at_10: 0.1654 - map_at_10: 0.1213 - precision_at_10: 0.0312 - regularization_loss: 0.0000e+00 - loss_batch: 4.2650 - val_loss: 4.6676 - val_auc_11: 0.6040 - val_recall_at_10: 0.2240 - val_mrr_at_10: 0.0746 - val_ndcg_at_10: 0.1090 - val_map_at_10: 0.0746 - val_precision_at_10: 0.0224 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1707
# Epoch 4/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2686 - auc_11: 0.6682 - recall_at_10: 0.3123 - mrr_at_10: 0.1235 - ndcg_at_10: 0.1672 - map_at_10: 0.1235 - precision_at_10: 0.0312 - regularization_loss: 0.0000e+00 - loss_batch: 4.2658 - val_loss: 4.7155 - val_auc_11: 0.5938 - val_recall_at_10: 0.2119 - val_mrr_at_10: 0.0721 - val_ndcg_at_10: 0.1042 - val_map_at_10: 0.0721 - val_precision_at_10: 0.0212 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1722
# Epoch 5/50
# 549/549 [==============================] - 13s 22ms/step - loss: 4.2661 - auc_11: 0.6665 - recall_at_10: 0.3126 - mrr_at_10: 0.1216 - ndcg_at_10: 0.1658 - map_at_10: 0.1216 - precision_at_10: 0.0313 - regularization_loss: 0.0000e+00 - loss_batch: 4.2630 - val_loss: 4.7135 - val_auc_11: 0.5957 - val_recall_at_10: 0.2106 - val_mrr_at_10: 0.0719 - val_ndcg_at_10: 0.1039 - val_map_at_10: 0.0719 - val_precision_at_10: 0.0211 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2307
# Epoch 6/50
# 549/549 [==============================] - 13s 22ms/step - loss: 4.2638 - auc_11: 0.6663 - recall_at_10: 0.3160 - mrr_at_10: 0.1226 - ndcg_at_10: 0.1674 - map_at_10: 0.1226 - precision_at_10: 0.0316 - regularization_loss: 0.0000e+00 - loss_batch: 4.2608 - val_loss: 4.7504 - val_auc_11: 0.5849 - val_recall_at_10: 0.2090 - val_mrr_at_10: 0.0687 - val_ndcg_at_10: 0.1010 - val_map_at_10: 0.0687 - val_precision_at_10: 0.0209 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3120
# Epoch 7/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2636 - auc_11: 0.6658 - recall_at_10: 0.3158 - mrr_at_10: 0.1224 - ndcg_at_10: 0.1672 - map_at_10: 0.1224 - precision_at_10: 0.0316 - regularization_loss: 0.0000e+00 - loss_batch: 4.2608 - val_loss: 4.7019 - val_auc_11: 0.5858 - val_recall_at_10: 0.2071 - val_mrr_at_10: 0.0690 - val_ndcg_at_10: 0.1007 - val_map_at_10: 0.0690 - val_precision_at_10: 0.0207 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7633
# Epoch 8/50
# 549/549 [==============================] - 15s 27ms/step - loss: 4.2611 - auc_11: 0.6646 - recall_at_10: 0.3158 - mrr_at_10: 0.1239 - ndcg_at_10: 0.1683 - map_at_10: 0.1239 - precision_at_10: 0.0316 - regularization_loss: 0.0000e+00 - loss_batch: 4.2580 - val_loss: 4.7447 - val_auc_11: 0.5907 - val_recall_at_10: 0.2133 - val_mrr_at_10: 0.0709 - val_ndcg_at_10: 0.1036 - val_map_at_10: 0.0709 - val_precision_at_10: 0.0213 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2712
# Epoch 9/50
# 549/549 [==============================] - 13s 24ms/step - loss: 4.2583 - auc_11: 0.6624 - recall_at_10: 0.3147 - mrr_at_10: 0.1236 - ndcg_at_10: 0.1679 - map_at_10: 0.1236 - precision_at_10: 0.0315 - regularization_loss: 0.0000e+00 - loss_batch: 4.2556 - val_loss: 4.7252 - val_auc_11: 0.5865 - val_recall_at_10: 0.2071 - val_mrr_at_10: 0.0689 - val_ndcg_at_10: 0.1007 - val_map_at_10: 0.0689 - val_precision_at_10: 0.0207 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0221
# Epoch 10/50
# 549/549 [==============================] - 12s 21ms/step - loss: 4.2593 - auc_11: 0.6658 - recall_at_10: 0.3174 - mrr_at_10: 0.1243 - ndcg_at_10: 0.1690 - map_at_10: 0.1243 - precision_at_10: 0.0317 - regularization_loss: 0.0000e+00 - loss_batch: 4.2563 - val_loss: 4.7043 - val_auc_11: 0.5899 - val_recall_at_10: 0.2088 - val_mrr_at_10: 0.0702 - val_ndcg_at_10: 0.1021 - val_map_at_10: 0.0702 - val_precision_at_10: 0.0209 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1979
# Epoch 11/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2567 - auc_11: 0.6692 - recall_at_10: 0.3174 - mrr_at_10: 0.1228 - ndcg_at_10: 0.1678 - map_at_10: 0.1228 - precision_at_10: 0.0317 - regularization_loss: 0.0000e+00 - loss_batch: 4.2539 - val_loss: 4.6952 - val_auc_11: 0.6001 - val_recall_at_10: 0.2169 - val_mrr_at_10: 0.0692 - val_ndcg_at_10: 0.1032 - val_map_at_10: 0.0692 - val_precision_at_10: 0.0217 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2093
# Epoch 12/50
# 549/549 [==============================] - 13s 24ms/step - loss: 4.2572 - auc_11: 0.6658 - recall_at_10: 0.3179 - mrr_at_10: 0.1242 - ndcg_at_10: 0.1690 - map_at_10: 0.1242 - precision_at_10: 0.0318 - regularization_loss: 0.0000e+00 - loss_batch: 4.2542 - val_loss: 4.7896 - val_auc_11: 0.5917 - val_recall_at_10: 0.2096 - val_mrr_at_10: 0.0715 - val_ndcg_at_10: 0.1033 - val_map_at_10: 0.0715 - val_precision_at_10: 0.0210 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2555
# Epoch 13/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2528 - auc_11: 0.6695 - recall_at_10: 0.3165 - mrr_at_10: 0.1234 - ndcg_at_10: 0.1681 - map_at_10: 0.1234 - precision_at_10: 0.0316 - regularization_loss: 0.0000e+00 - loss_batch: 4.2499 - val_loss: 4.7323 - val_auc_11: 0.5868 - val_recall_at_10: 0.2109 - val_mrr_at_10: 0.0704 - val_ndcg_at_10: 0.1027 - val_map_at_10: 0.0704 - val_precision_at_10: 0.0211 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.5431
# Epoch 14/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2522 - auc_11: 0.6662 - recall_at_10: 0.3178 - mrr_at_10: 0.1235 - ndcg_at_10: 0.1685 - map_at_10: 0.1235 - precision_at_10: 0.0318 - regularization_loss: 0.0000e+00 - loss_batch: 4.2494 - val_loss: 4.7129 - val_auc_11: 0.5803 - val_recall_at_10: 0.2043 - val_mrr_at_10: 0.0695 - val_ndcg_at_10: 0.1005 - val_map_at_10: 0.0695 - val_precision_at_10: 0.0204 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2321
# Epoch 15/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2503 - auc_11: 0.6642 - recall_at_10: 0.3166 - mrr_at_10: 0.1244 - ndcg_at_10: 0.1689 - map_at_10: 0.1244 - precision_at_10: 0.0317 - regularization_loss: 0.0000e+00 - loss_batch: 4.2473 - val_loss: 4.7088 - val_auc_11: 0.5980 - val_recall_at_10: 0.2252 - val_mrr_at_10: 0.0750 - val_ndcg_at_10: 0.1095 - val_map_at_10: 0.0750 - val_precision_at_10: 0.0225 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.5218
# Epoch 16/50
# 549/549 [==============================] - 15s 26ms/step - loss: 4.2495 - auc_11: 0.6639 - recall_at_10: 0.3198 - mrr_at_10: 0.1261 - ndcg_at_10: 0.1709 - map_at_10: 0.1261 - precision_at_10: 0.0320 - regularization_loss: 0.0000e+00 - loss_batch: 4.2466 - val_loss: 4.7709 - val_auc_11: 0.5794 - val_recall_at_10: 0.2074 - val_mrr_at_10: 0.0692 - val_ndcg_at_10: 0.1011 - val_map_at_10: 0.0692 - val_precision_at_10: 0.0207 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1906
# Epoch 17/50
# 549/549 [==============================] - 13s 23ms/step - loss: 4.2487 - auc_11: 0.6597 - recall_at_10: 0.3186 - mrr_at_10: 0.1250 - ndcg_at_10: 0.1698 - map_at_10: 0.1250 - precision_at_10: 0.0319 - regularization_loss: 0.0000e+00 - loss_batch: 4.2459 - val_loss: 4.7389 - val_auc_11: 0.5924 - val_recall_at_10: 0.2142 - val_mrr_at_10: 0.0698 - val_ndcg_at_10: 0.1030 - val_map_at_10: 0.0698 - val_precision_at_10: 0.0214 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1143
# Epoch 18/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2474 - auc_11: 0.6643 - recall_at_10: 0.3225 - mrr_at_10: 0.1258 - ndcg_at_10: 0.1714 - map_at_10: 0.1258 - precision_at_10: 0.0323 - regularization_loss: 0.0000e+00 - loss_batch: 4.2446 - val_loss: 4.7711 - val_auc_11: 0.5908 - val_recall_at_10: 0.2102 - val_mrr_at_10: 0.0693 - val_ndcg_at_10: 0.1017 - val_map_at_10: 0.0693 - val_precision_at_10: 0.0210 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1135
# Epoch 19/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2457 - auc_11: 0.6610 - recall_at_10: 0.3195 - mrr_at_10: 0.1251 - ndcg_at_10: 0.1700 - map_at_10: 0.1251 - precision_at_10: 0.0319 - regularization_loss: 0.0000e+00 - loss_batch: 4.2429 - val_loss: 4.6651 - val_auc_11: 0.6005 - val_recall_at_10: 0.2272 - val_mrr_at_10: 0.0762 - val_ndcg_at_10: 0.1110 - val_map_at_10: 0.0762 - val_precision_at_10: 0.0227 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0438
# Epoch 20/50
# 549/549 [==============================] - 12s 21ms/step - loss: 4.2464 - auc_11: 0.6585 - recall_at_10: 0.3193 - mrr_at_10: 0.1270 - ndcg_at_10: 0.1716 - map_at_10: 0.1270 - precision_at_10: 0.0319 - regularization_loss: 0.0000e+00 - loss_batch: 4.2435 - val_loss: 4.6809 - val_auc_11: 0.6001 - val_recall_at_10: 0.2209 - val_mrr_at_10: 0.0733 - val_ndcg_at_10: 0.1072 - val_map_at_10: 0.0733 - val_precision_at_10: 0.0221 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2345
# Epoch 21/50
# 549/549 [==============================] - 14s 24ms/step - loss: 4.2446 - auc_11: 0.6568 - recall_at_10: 0.3209 - mrr_at_10: 0.1251 - ndcg_at_10: 0.1705 - map_at_10: 0.1251 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 4.2416 - val_loss: 4.7159 - val_auc_11: 0.5931 - val_recall_at_10: 0.2149 - val_mrr_at_10: 0.0727 - val_ndcg_at_10: 0.1054 - val_map_at_10: 0.0727 - val_precision_at_10: 0.0215 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3449
# Epoch 22/50
# 549/549 [==============================] - 16s 29ms/step - loss: 4.2427 - auc_11: 0.6499 - recall_at_10: 0.3222 - mrr_at_10: 0.1274 - ndcg_at_10: 0.1725 - map_at_10: 0.1274 - precision_at_10: 0.0322 - regularization_loss: 0.0000e+00 - loss_batch: 4.2397 - val_loss: 4.6919 - val_auc_11: 0.5997 - val_recall_at_10: 0.2279 - val_mrr_at_10: 0.0764 - val_ndcg_at_10: 0.1113 - val_map_at_10: 0.0764 - val_precision_at_10: 0.0228 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2299
# Epoch 23/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2432 - auc_11: 0.6512 - recall_at_10: 0.3230 - mrr_at_10: 0.1278 - ndcg_at_10: 0.1730 - map_at_10: 0.1278 - precision_at_10: 0.0323 - regularization_loss: 0.0000e+00 - loss_batch: 4.2404 - val_loss: 4.7326 - val_auc_11: 0.5883 - val_recall_at_10: 0.2144 - val_mrr_at_10: 0.0712 - val_ndcg_at_10: 0.1042 - val_map_at_10: 0.0712 - val_precision_at_10: 0.0214 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0811
# Epoch 24/50
# 549/549 [==============================] - 13s 22ms/step - loss: 4.2401 - auc_11: 0.6492 - recall_at_10: 0.3246 - mrr_at_10: 0.1273 - ndcg_at_10: 0.1730 - map_at_10: 0.1273 - precision_at_10: 0.0325 - regularization_loss: 0.0000e+00 - loss_batch: 4.2371 - val_loss: 4.7025 - val_auc_11: 0.5908 - val_recall_at_10: 0.2127 - val_mrr_at_10: 0.0719 - val_ndcg_at_10: 0.1044 - val_map_at_10: 0.0719 - val_precision_at_10: 0.0213 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2459
# Epoch 25/50
# 549/549 [==============================] - 12s 21ms/step - loss: 4.2418 - auc_11: 0.6489 - recall_at_10: 0.3196 - mrr_at_10: 0.1258 - ndcg_at_10: 0.1707 - map_at_10: 0.1258 - precision_at_10: 0.0320 - regularization_loss: 0.0000e+00 - loss_batch: 4.2387 - val_loss: 4.7504 - val_auc_11: 0.5802 - val_recall_at_10: 0.2074 - val_mrr_at_10: 0.0687 - val_ndcg_at_10: 0.1006 - val_map_at_10: 0.0687 - val_precision_at_10: 0.0207 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1442
# Epoch 26/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2422 - auc_11: 0.6453 - recall_at_10: 0.3214 - mrr_at_10: 0.1265 - ndcg_at_10: 0.1716 - map_at_10: 0.1265 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 4.2392 - val_loss: 4.7820 - val_auc_11: 0.5864 - val_recall_at_10: 0.2110 - val_mrr_at_10: 0.0706 - val_ndcg_at_10: 0.1029 - val_map_at_10: 0.0706 - val_precision_at_10: 0.0211 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3819
# Epoch 27/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2384 - auc_11: 0.6425 - recall_at_10: 0.3203 - mrr_at_10: 0.1267 - ndcg_at_10: 0.1715 - map_at_10: 0.1267 - precision_at_10: 0.0320 - regularization_loss: 0.0000e+00 - loss_batch: 4.2356 - val_loss: 4.7625 - val_auc_11: 0.5912 - val_recall_at_10: 0.2221 - val_mrr_at_10: 0.0722 - val_ndcg_at_10: 0.1067 - val_map_at_10: 0.0722 - val_precision_at_10: 0.0222 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4207
# Epoch 28/50
# 549/549 [==============================] - 15s 26ms/step - loss: 4.2387 - auc_11: 0.6459 - recall_at_10: 0.3227 - mrr_at_10: 0.1270 - ndcg_at_10: 0.1723 - map_at_10: 0.1270 - precision_at_10: 0.0323 - regularization_loss: 0.0000e+00 - loss_batch: 4.2356 - val_loss: 4.7315 - val_auc_11: 0.5831 - val_recall_at_10: 0.2152 - val_mrr_at_10: 0.0727 - val_ndcg_at_10: 0.1055 - val_map_at_10: 0.0727 - val_precision_at_10: 0.0215 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4992
# Epoch 29/50
# 549/549 [==============================] - 16s 28ms/step - loss: 4.2373 - auc_11: 0.6467 - recall_at_10: 0.3258 - mrr_at_10: 0.1294 - ndcg_at_10: 0.1750 - map_at_10: 0.1294 - precision_at_10: 0.0326 - regularization_loss: 0.0000e+00 - loss_batch: 4.2345 - val_loss: 4.7017 - val_auc_11: 0.5892 - val_recall_at_10: 0.2218 - val_mrr_at_10: 0.0753 - val_ndcg_at_10: 0.1091 - val_map_at_10: 0.0753 - val_precision_at_10: 0.0222 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2102
# Epoch 30/50
# 549/549 [==============================] - 13s 23ms/step - loss: 4.2375 - auc_11: 0.6453 - recall_at_10: 0.3245 - mrr_at_10: 0.1293 - ndcg_at_10: 0.1745 - map_at_10: 0.1293 - precision_at_10: 0.0324 - regularization_loss: 0.0000e+00 - loss_batch: 4.2346 - val_loss: 4.6746 - val_auc_11: 0.5983 - val_recall_at_10: 0.2285 - val_mrr_at_10: 0.0772 - val_ndcg_at_10: 0.1121 - val_map_at_10: 0.0772 - val_precision_at_10: 0.0229 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1224
# Epoch 31/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2371 - auc_11: 0.6474 - recall_at_10: 0.3235 - mrr_at_10: 0.1295 - ndcg_at_10: 0.1745 - map_at_10: 0.1295 - precision_at_10: 0.0324 - regularization_loss: 0.0000e+00 - loss_batch: 4.2344 - val_loss: 4.7275 - val_auc_11: 0.5972 - val_recall_at_10: 0.2168 - val_mrr_at_10: 0.0722 - val_ndcg_at_10: 0.1055 - val_map_at_10: 0.0722 - val_precision_at_10: 0.0217 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.8236
# Epoch 32/50
# 549/549 [==============================] - 17s 29ms/step - loss: 4.2350 - auc_11: 0.6454 - recall_at_10: 0.3214 - mrr_at_10: 0.1272 - ndcg_at_10: 0.1722 - map_at_10: 0.1272 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 4.2322 - val_loss: 4.7399 - val_auc_11: 0.5853 - val_recall_at_10: 0.2175 - val_mrr_at_10: 0.0725 - val_ndcg_at_10: 0.1059 - val_map_at_10: 0.0725 - val_precision_at_10: 0.0218 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4821
# Epoch 33/50
# 549/549 [==============================] - 16s 29ms/step - loss: 4.2332 - auc_11: 0.6465 - recall_at_10: 0.3219 - mrr_at_10: 0.1278 - ndcg_at_10: 0.1728 - map_at_10: 0.1278 - precision_at_10: 0.0322 - regularization_loss: 0.0000e+00 - loss_batch: 4.2303 - val_loss: 4.7011 - val_auc_11: 0.5843 - val_recall_at_10: 0.2242 - val_mrr_at_10: 0.0753 - val_ndcg_at_10: 0.1096 - val_map_at_10: 0.0753 - val_precision_at_10: 0.0224 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1491
# Epoch 34/50
# 549/549 [==============================] - 16s 28ms/step - loss: 4.2357 - auc_11: 0.6485 - recall_at_10: 0.3230 - mrr_at_10: 0.1278 - ndcg_at_10: 0.1731 - map_at_10: 0.1278 - precision_at_10: 0.0323 - regularization_loss: 0.0000e+00 - loss_batch: 4.2329 - val_loss: 4.8002 - val_auc_11: 0.5813 - val_recall_at_10: 0.2058 - val_mrr_at_10: 0.0690 - val_ndcg_at_10: 0.1004 - val_map_at_10: 0.0690 - val_precision_at_10: 0.0206 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3000
# Epoch 35/50
# 549/549 [==============================] - 13s 23ms/step - loss: 4.2359 - auc_11: 0.6498 - recall_at_10: 0.3212 - mrr_at_10: 0.1261 - ndcg_at_10: 0.1713 - map_at_10: 0.1261 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 4.2332 - val_loss: 4.7794 - val_auc_11: 0.5954 - val_recall_at_10: 0.2186 - val_mrr_at_10: 0.0710 - val_ndcg_at_10: 0.1050 - val_map_at_10: 0.0710 - val_precision_at_10: 0.0219 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3316
# Epoch 36/50
# 549/549 [==============================] - 15s 27ms/step - loss: 4.2338 - auc_11: 0.6502 - recall_at_10: 0.3217 - mrr_at_10: 0.1278 - ndcg_at_10: 0.1728 - map_at_10: 0.1278 - precision_at_10: 0.0322 - regularization_loss: 0.0000e+00 - loss_batch: 4.2309 - val_loss: 4.7433 - val_auc_11: 0.5831 - val_recall_at_10: 0.2141 - val_mrr_at_10: 0.0700 - val_ndcg_at_10: 0.1031 - val_map_at_10: 0.0700 - val_precision_at_10: 0.0214 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0222
# Epoch 37/50
# 549/549 [==============================] - 17s 29ms/step - loss: 4.2313 - auc_11: 0.6464 - recall_at_10: 0.3242 - mrr_at_10: 0.1284 - ndcg_at_10: 0.1738 - map_at_10: 0.1284 - precision_at_10: 0.0324 - regularization_loss: 0.0000e+00 - loss_batch: 4.2283 - val_loss: 4.7358 - val_auc_11: 0.5903 - val_recall_at_10: 0.2205 - val_mrr_at_10: 0.0722 - val_ndcg_at_10: 0.1063 - val_map_at_10: 0.0722 - val_precision_at_10: 0.0220 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1487
# Epoch 38/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2320 - auc_11: 0.6444 - recall_at_10: 0.3234 - mrr_at_10: 0.1279 - ndcg_at_10: 0.1732 - map_at_10: 0.1279 - precision_at_10: 0.0323 - regularization_loss: 0.0000e+00 - loss_batch: 4.2291 - val_loss: 4.7757 - val_auc_11: 0.5810 - val_recall_at_10: 0.2073 - val_mrr_at_10: 0.0668 - val_ndcg_at_10: 0.0991 - val_map_at_10: 0.0668 - val_precision_at_10: 0.0207 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3012
# Epoch 39/50
# 549/549 [==============================] - 13s 23ms/step - loss: 4.2290 - auc_11: 0.6451 - recall_at_10: 0.3264 - mrr_at_10: 0.1295 - ndcg_at_10: 0.1751 - map_at_10: 0.1295 - precision_at_10: 0.0326 - regularization_loss: 0.0000e+00 - loss_batch: 4.2260 - val_loss: 4.7213 - val_auc_11: 0.5755 - val_recall_at_10: 0.2117 - val_mrr_at_10: 0.0691 - val_ndcg_at_10: 0.1018 - val_map_at_10: 0.0691 - val_precision_at_10: 0.0212 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0350
# Epoch 40/50
# 549/549 [==============================] - 15s 27ms/step - loss: 4.2306 - auc_11: 0.6424 - recall_at_10: 0.3236 - mrr_at_10: 0.1286 - ndcg_at_10: 0.1737 - map_at_10: 0.1286 - precision_at_10: 0.0324 - regularization_loss: 0.0000e+00 - loss_batch: 4.2277 - val_loss: 4.8220 - val_auc_11: 0.5758 - val_recall_at_10: 0.2028 - val_mrr_at_10: 0.0654 - val_ndcg_at_10: 0.0969 - val_map_at_10: 0.0654 - val_precision_at_10: 0.0203 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1585
# Epoch 41/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2327 - auc_11: 0.6389 - recall_at_10: 0.3291 - mrr_at_10: 0.1310 - ndcg_at_10: 0.1769 - map_at_10: 0.1310 - precision_at_10: 0.0329 - regularization_loss: 0.0000e+00 - loss_batch: 4.2296 - val_loss: 4.7368 - val_auc_11: 0.5786 - val_recall_at_10: 0.2185 - val_mrr_at_10: 0.0730 - val_ndcg_at_10: 0.1064 - val_map_at_10: 0.0730 - val_precision_at_10: 0.0218 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.9940
# Epoch 42/50
# 549/549 [==============================] - 13s 22ms/step - loss: 4.2286 - auc_11: 0.6424 - recall_at_10: 0.3266 - mrr_at_10: 0.1303 - ndcg_at_10: 0.1758 - map_at_10: 0.1303 - precision_at_10: 0.0327 - regularization_loss: 0.0000e+00 - loss_batch: 4.2256 - val_loss: 4.7467 - val_auc_11: 0.5828 - val_recall_at_10: 0.2112 - val_mrr_at_10: 0.0698 - val_ndcg_at_10: 0.1024 - val_map_at_10: 0.0698 - val_precision_at_10: 0.0211 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2044
# Epoch 43/50
# 549/549 [==============================] - 13s 22ms/step - loss: 4.2289 - auc_11: 0.6397 - recall_at_10: 0.3253 - mrr_at_10: 0.1292 - ndcg_at_10: 0.1746 - map_at_10: 0.1292 - precision_at_10: 0.0325 - regularization_loss: 0.0000e+00 - loss_batch: 4.2259 - val_loss: 4.7803 - val_auc_11: 0.5746 - val_recall_at_10: 0.2086 - val_mrr_at_10: 0.0696 - val_ndcg_at_10: 0.1017 - val_map_at_10: 0.0696 - val_precision_at_10: 0.0209 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4101
# Epoch 44/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2339 - auc_11: 0.6390 - recall_at_10: 0.3239 - mrr_at_10: 0.1283 - ndcg_at_10: 0.1736 - map_at_10: 0.1283 - precision_at_10: 0.0324 - regularization_loss: 0.0000e+00 - loss_batch: 4.2310 - val_loss: 4.7564 - val_auc_11: 0.5829 - val_recall_at_10: 0.2154 - val_mrr_at_10: 0.0718 - val_ndcg_at_10: 0.1048 - val_map_at_10: 0.0718 - val_precision_at_10: 0.0215 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2794
# Epoch 45/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2273 - auc_11: 0.6370 - recall_at_10: 0.3295 - mrr_at_10: 0.1302 - ndcg_at_10: 0.1763 - map_at_10: 0.1302 - precision_at_10: 0.0330 - regularization_loss: 0.0000e+00 - loss_batch: 4.2243 - val_loss: 4.7303 - val_auc_11: 0.5761 - val_recall_at_10: 0.2093 - val_mrr_at_10: 0.0689 - val_ndcg_at_10: 0.1012 - val_map_at_10: 0.0689 - val_precision_at_10: 0.0209 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.1958
# Epoch 46/50
# 549/549 [==============================] - 15s 26ms/step - loss: 4.2269 - auc_11: 0.6308 - recall_at_10: 0.3282 - mrr_at_10: 0.1297 - ndcg_at_10: 0.1757 - map_at_10: 0.1297 - precision_at_10: 0.0328 - regularization_loss: 0.0000e+00 - loss_batch: 4.2239 - val_loss: 4.7766 - val_auc_11: 0.5751 - val_recall_at_10: 0.2144 - val_mrr_at_10: 0.0688 - val_ndcg_at_10: 0.1023 - val_map_at_10: 0.0688 - val_precision_at_10: 0.0214 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3851
# Epoch 47/50
# 549/549 [==============================] - 13s 23ms/step - loss: 4.2275 - auc_11: 0.6281 - recall_at_10: 0.3260 - mrr_at_10: 0.1293 - ndcg_at_10: 0.1749 - map_at_10: 0.1293 - precision_at_10: 0.0326 - regularization_loss: 0.0000e+00 - loss_batch: 4.2245 - val_loss: 4.7346 - val_auc_11: 0.5744 - val_recall_at_10: 0.2181 - val_mrr_at_10: 0.0717 - val_ndcg_at_10: 0.1054 - val_map_at_10: 0.0717 - val_precision_at_10: 0.0218 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.3797
# Epoch 48/50
# 549/549 [==============================] - 12s 21ms/step - loss: 4.2256 - auc_11: 0.6302 - recall_at_10: 0.3299 - mrr_at_10: 0.1304 - ndcg_at_10: 0.1766 - map_at_10: 0.1304 - precision_at_10: 0.0330 - regularization_loss: 0.0000e+00 - loss_batch: 4.2225 - val_loss: 4.7719 - val_auc_11: 0.5750 - val_recall_at_10: 0.2181 - val_mrr_at_10: 0.0718 - val_ndcg_at_10: 0.1054 - val_map_at_10: 0.0718 - val_precision_at_10: 0.0218 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4477
# Epoch 49/50
# 549/549 [==============================] - 15s 26ms/step - loss: 4.2246 - auc_11: 0.6284 - recall_at_10: 0.3272 - mrr_at_10: 0.1304 - ndcg_at_10: 0.1760 - map_at_10: 0.1304 - precision_at_10: 0.0327 - regularization_loss: 0.0000e+00 - loss_batch: 4.2216 - val_loss: 4.6995 - val_auc_11: 0.5783 - val_recall_at_10: 0.2223 - val_mrr_at_10: 0.0739 - val_ndcg_at_10: 0.1081 - val_map_at_10: 0.0739 - val_precision_at_10: 0.0222 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.9205
# Epoch 50/50
# 549/549 [==============================] - 14s 25ms/step - loss: 4.2262 - auc_11: 0.6249 - recall_at_10: 0.3249 - mrr_at_10: 0.1301 - ndcg_at_10: 0.1752 - map_at_10: 0.1301 - precision_at_10: 0.0325 - regularization_loss: 0.0000e+00 - loss_batch: 4.2232 - val_loss: 4.7292 - val_auc_11: 0.5759 - val_recall_at_10: 0.2160 - val_mrr_at_10: 0.0717 - val_ndcg_at_10: 0.1048 - val_map_at_10: 0.0717 - val_precision_at_10: 0.0216 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.2025

# %% [markdown]
# #### eval

# %%
(model_v3.evaluate(train, batch_size=2048, return_dict=True),
 model_v3.evaluate(valid, batch_size=2048, return_dict=True))
# Out:
# 35/35 [==============================] - 2s 29ms/step - loss: 6.9484 - auc_11: 0.6300 - recall_at_10: 0.0562 - mrr_at_10: 0.0234 - ndcg_at_10: 0.0310 - map_at_10: 0.0234 - precision_at_10: 0.0056 - regularization_loss: 0.0000e+00 - loss_batch: 6.8868
# 8/8 [==============================] - 0s 27ms/step - loss: 7.4825 - auc_11: 0.5666 - recall_at_10: 0.0272 - mrr_at_10: 0.0195 - ndcg_at_10: 0.0212 - map_at_10: 0.0195 - precision_at_10: 0.0027 - regularization_loss: 0.0000e+00 - loss_batch: 7.3267
# ({'loss': 6.948401927947998,
#   'auc_11': 0.6300323605537415,
#   'recall_at_10': 0.05685023218393326,
#   'mrr_at_10': 0.02361108735203743,
#   'ndcg_at_10': 0.031310249119997025,
#   'map_at_10': 0.02361108735203743,
#   'precision_at_10': 0.0056850239634513855,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.659359931945801},
#  {'loss': 7.4824700355529785,
#   'auc_11': 0.5665577054023743,
#   'recall_at_10': 0.027484284713864326,
#   'mrr_at_10': 0.017612211406230927,
#   'ndcg_at_10': 0.019846687093377113,
#   'map_at_10': 0.017612211406230927,
#   'precision_at_10': 0.002748428611084819,
#   'regularization_loss': 0.0,
#   'loss_batch': 6.656989574432373})

# %%
evaluate_model(model_v3, train, topk=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1561
# WARNING:absl:Found untraced functions such as prepare_list_features_34_layer_call_fn, prepare_list_features_34_layer_call_and_return_conditional_losses, model_context_2_layer_call_fn, model_context_2_layer_call_and_return_conditional_losses, concat_features_5_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 69/69 [==============================] - 5s 16ms/step - loss: 1.4384 - auc_44: 0.4153 - recall_at_100: 0.3081 - mrr_at_100: 0.0179 - ndcg_at_100: 0.0670 - map_at_100: 0.0179 - precision_at_100: 0.0031 - regularization_loss: 0.0000e+00 - loss_batch: 1.4375
# {'loss': 1.4384310245513916,
#  'auc_44': 0.41533172130584717,
#  'recall_at_100': 0.3061736226081848,
#  'mrr_at_100': 0.01771610602736473,
#  'ndcg_at_100': 0.06640614569187164,
#  'map_at_100': 0.01771610602736473,
#  'precision_at_100': 0.003061736235395074,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.3916001319885254}

# %%
evaluate_model(model_v3, valid, topk=100)
# Out:
# Candidate set rows: 1338
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:absl:Found untraced functions such as prepare_list_features_34_layer_call_fn, prepare_list_features_34_layer_call_and_return_conditional_losses, model_context_2_layer_call_fn, model_context_2_layer_call_and_return_conditional_losses, concat_features_5_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 15/15 [==============================] - 3s 27ms/step - loss: 0.9730 - auc_45: 0.4295 - recall_at_100: 0.2024 - mrr_at_100: 0.0082 - ndcg_at_100: 0.0402 - map_at_100: 0.0082 - precision_at_100: 0.0020 - regularization_loss: 0.0000e+00 - loss_batch: 1.0311
# {'loss': 0.9729880094528198,
#  'auc_45': 0.42949050664901733,
#  'recall_at_100': 0.2028219848871231,
#  'mrr_at_100': 0.00839446485042572,
#  'ndcg_at_100': 0.04044663533568382,
#  'map_at_100': 0.00839446485042572,
#  'precision_at_100': 0.002028219634667039,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.6384577751159668}

# %% [markdown]
# #### analysis

# %%
_history = merge_model_history(*history_v3)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM})

# %% [markdown]
# ### model_v4

# %%
# _tower_dim = (64, 128) # @param
# _tower_dim = (128, 64) # @param
_tower_dim = (512, 256) # @param

_learning_rate = 0.01 # @param
# _batch_size = 4096 # @param
_batch_size = 1024 # @param
_epochs = 150 # @param
_validation_batch_size = 256 # @param

# %%
model_v4 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [10]
model_v4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True,
                                                            #  reduction=tf.keras.losses.Reduction.SUM # https://github.com/tensorflow/recommenders/blob/v0.7.3/tensorflow_recommenders/tasks/retrieval.py#L84
                                                             ),
)
history_v4 = []

# %% [markdown]
# #### model

# %%
history_v4.append(
    model_v4.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size)
)
# Out:
# Epoch 1/150
# 69/69 [==============================] - 23s 223ms/step - loss: 6.8231 - auc_52: 0.5737 - recall_at_10: 0.0147 - mrr_at_10: 0.0052 - ndcg_at_10: 0.0074 - map_at_10: 0.0052 - precision_at_10: 0.0015 - regularization_loss: 0.0000e+00 - loss_batch: 6.8079 - val_loss: 6.7749 - val_auc_52: 0.5912 - val_recall_at_10: 0.0276 - val_mrr_at_10: 0.0092 - val_ndcg_at_10: 0.0134 - val_map_at_10: 0.0092 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.3473
# Epoch 2/150
# 69/69 [==============================] - 4s 58ms/step - loss: 6.5573 - auc_52: 0.6250 - recall_at_10: 0.0367 - mrr_at_10: 0.0124 - ndcg_at_10: 0.0180 - map_at_10: 0.0124 - precision_at_10: 0.0037 - regularization_loss: 0.0000e+00 - loss_batch: 6.5442 - val_loss: 6.6853 - val_auc_52: 0.5727 - val_recall_at_10: 0.0314 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0154 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.2551
# Epoch 3/150
# 69/69 [==============================] - 5s 59ms/step - loss: 6.4706 - auc_52: 0.6273 - recall_at_10: 0.0489 - mrr_at_10: 0.0168 - ndcg_at_10: 0.0242 - map_at_10: 0.0168 - precision_at_10: 0.0049 - regularization_loss: 0.0000e+00 - loss_batch: 6.4578 - val_loss: 6.6700 - val_auc_52: 0.5668 - val_recall_at_10: 0.0344 - val_mrr_at_10: 0.0118 - val_ndcg_at_10: 0.0169 - val_map_at_10: 0.0118 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.2488
# Epoch 4/150
# 69/69 [==============================] - 5s 55ms/step - loss: 6.4188 - auc_52: 0.6351 - recall_at_10: 0.0612 - mrr_at_10: 0.0213 - ndcg_at_10: 0.0305 - map_at_10: 0.0213 - precision_at_10: 0.0061 - regularization_loss: 0.0000e+00 - loss_batch: 6.4058 - val_loss: 6.7328 - val_auc_52: 0.5794 - val_recall_at_10: 0.0348 - val_mrr_at_10: 0.0117 - val_ndcg_at_10: 0.0170 - val_map_at_10: 0.0117 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4336
# Epoch 5/150
# 69/69 [==============================] - 4s 41ms/step - loss: 6.3823 - auc_52: 0.6526 - recall_at_10: 0.0682 - mrr_at_10: 0.0254 - ndcg_at_10: 0.0352 - map_at_10: 0.0254 - precision_at_10: 0.0068 - regularization_loss: 0.0000e+00 - loss_batch: 6.3696 - val_loss: 6.7770 - val_auc_52: 0.5718 - val_recall_at_10: 0.0308 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0153 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4174
# Epoch 6/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.3536 - auc_52: 0.6535 - recall_at_10: 0.0706 - mrr_at_10: 0.0266 - ndcg_at_10: 0.0367 - map_at_10: 0.0266 - precision_at_10: 0.0071 - regularization_loss: 0.0000e+00 - loss_batch: 6.3407 - val_loss: 6.7386 - val_auc_52: 0.5758 - val_recall_at_10: 0.0372 - val_mrr_at_10: 0.0124 - val_ndcg_at_10: 0.0181 - val_map_at_10: 0.0124 - val_precision_at_10: 0.0037 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4289
# Epoch 7/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.3327 - auc_52: 0.6494 - recall_at_10: 0.0751 - mrr_at_10: 0.0294 - ndcg_at_10: 0.0400 - map_at_10: 0.0294 - precision_at_10: 0.0075 - regularization_loss: 0.0000e+00 - loss_batch: 6.3200 - val_loss: 6.7382 - val_auc_52: 0.5725 - val_recall_at_10: 0.0366 - val_mrr_at_10: 0.0127 - val_ndcg_at_10: 0.0182 - val_map_at_10: 0.0127 - val_precision_at_10: 0.0037 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4179
# Epoch 8/150
# 69/69 [==============================] - 3s 40ms/step - loss: 6.3138 - auc_52: 0.6564 - recall_at_10: 0.0822 - mrr_at_10: 0.0320 - ndcg_at_10: 0.0436 - map_at_10: 0.0320 - precision_at_10: 0.0082 - regularization_loss: 0.0000e+00 - loss_batch: 6.3008 - val_loss: 6.7371 - val_auc_52: 0.5769 - val_recall_at_10: 0.0352 - val_mrr_at_10: 0.0115 - val_ndcg_at_10: 0.0169 - val_map_at_10: 0.0115 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4525
# Epoch 9/150
# 69/69 [==============================] - 4s 50ms/step - loss: 6.2983 - auc_52: 0.6545 - recall_at_10: 0.0834 - mrr_at_10: 0.0326 - ndcg_at_10: 0.0443 - map_at_10: 0.0326 - precision_at_10: 0.0083 - regularization_loss: 0.0000e+00 - loss_batch: 6.2852 - val_loss: 6.7730 - val_auc_52: 0.5707 - val_recall_at_10: 0.0354 - val_mrr_at_10: 0.0116 - val_ndcg_at_10: 0.0170 - val_map_at_10: 0.0116 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5262
# Epoch 10/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.2841 - auc_52: 0.6613 - recall_at_10: 0.0868 - mrr_at_10: 0.0347 - ndcg_at_10: 0.0467 - map_at_10: 0.0347 - precision_at_10: 0.0087 - regularization_loss: 0.0000e+00 - loss_batch: 6.2710 - val_loss: 6.8239 - val_auc_52: 0.5770 - val_recall_at_10: 0.0360 - val_mrr_at_10: 0.0119 - val_ndcg_at_10: 0.0174 - val_map_at_10: 0.0119 - val_precision_at_10: 0.0036 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5783
# Epoch 11/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.2718 - auc_52: 0.6617 - recall_at_10: 0.0901 - mrr_at_10: 0.0369 - ndcg_at_10: 0.0492 - map_at_10: 0.0369 - precision_at_10: 0.0090 - regularization_loss: 0.0000e+00 - loss_batch: 6.2583 - val_loss: 6.8195 - val_auc_52: 0.5799 - val_recall_at_10: 0.0352 - val_mrr_at_10: 0.0119 - val_ndcg_at_10: 0.0173 - val_map_at_10: 0.0119 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5970
# Epoch 12/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.2597 - auc_52: 0.6535 - recall_at_10: 0.0902 - mrr_at_10: 0.0365 - ndcg_at_10: 0.0489 - map_at_10: 0.0365 - precision_at_10: 0.0090 - regularization_loss: 0.0000e+00 - loss_batch: 6.2467 - val_loss: 6.8056 - val_auc_52: 0.5808 - val_recall_at_10: 0.0330 - val_mrr_at_10: 0.0114 - val_ndcg_at_10: 0.0163 - val_map_at_10: 0.0114 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7001
# Epoch 13/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.2498 - auc_52: 0.6648 - recall_at_10: 0.0926 - mrr_at_10: 0.0376 - ndcg_at_10: 0.0503 - map_at_10: 0.0376 - precision_at_10: 0.0093 - regularization_loss: 0.0000e+00 - loss_batch: 6.2368 - val_loss: 6.7731 - val_auc_52: 0.5939 - val_recall_at_10: 0.0354 - val_mrr_at_10: 0.0110 - val_ndcg_at_10: 0.0166 - val_map_at_10: 0.0110 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5883
# Epoch 14/150
# 69/69 [==============================] - 3s 40ms/step - loss: 6.2405 - auc_52: 0.6694 - recall_at_10: 0.0927 - mrr_at_10: 0.0389 - ndcg_at_10: 0.0513 - map_at_10: 0.0389 - precision_at_10: 0.0093 - regularization_loss: 0.0000e+00 - loss_batch: 6.2274 - val_loss: 6.8159 - val_auc_52: 0.5758 - val_recall_at_10: 0.0342 - val_mrr_at_10: 0.0111 - val_ndcg_at_10: 0.0164 - val_map_at_10: 0.0111 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.6278
# Epoch 15/150
# 69/69 [==============================] - 3s 35ms/step - loss: 6.2282 - auc_52: 0.6634 - recall_at_10: 0.0940 - mrr_at_10: 0.0398 - ndcg_at_10: 0.0523 - map_at_10: 0.0398 - precision_at_10: 0.0094 - regularization_loss: 0.0000e+00 - loss_batch: 6.2147 - val_loss: 6.8386 - val_auc_52: 0.5868 - val_recall_at_10: 0.0332 - val_mrr_at_10: 0.0109 - val_ndcg_at_10: 0.0160 - val_map_at_10: 0.0109 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7718
# Epoch 16/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.2203 - auc_52: 0.6651 - recall_at_10: 0.0981 - mrr_at_10: 0.0409 - ndcg_at_10: 0.0541 - map_at_10: 0.0409 - precision_at_10: 0.0098 - regularization_loss: 0.0000e+00 - loss_batch: 6.2071 - val_loss: 6.8171 - val_auc_52: 0.5822 - val_recall_at_10: 0.0358 - val_mrr_at_10: 0.0113 - val_ndcg_at_10: 0.0169 - val_map_at_10: 0.0113 - val_precision_at_10: 0.0036 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7621
# Epoch 17/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.2151 - auc_52: 0.6621 - recall_at_10: 0.0993 - mrr_at_10: 0.0422 - ndcg_at_10: 0.0554 - map_at_10: 0.0422 - precision_at_10: 0.0099 - regularization_loss: 0.0000e+00 - loss_batch: 6.2013 - val_loss: 6.8512 - val_auc_52: 0.5907 - val_recall_at_10: 0.0341 - val_mrr_at_10: 0.0115 - val_ndcg_at_10: 0.0166 - val_map_at_10: 0.0115 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7016
# Epoch 18/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.2083 - auc_52: 0.6554 - recall_at_10: 0.0997 - mrr_at_10: 0.0419 - ndcg_at_10: 0.0552 - map_at_10: 0.0419 - precision_at_10: 0.0100 - regularization_loss: 0.0000e+00 - loss_batch: 6.1948 - val_loss: 6.8776 - val_auc_52: 0.5805 - val_recall_at_10: 0.0337 - val_mrr_at_10: 0.0111 - val_ndcg_at_10: 0.0163 - val_map_at_10: 0.0111 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7822
# Epoch 19/150
# 69/69 [==============================] - 3s 40ms/step - loss: 6.1991 - auc_52: 0.6559 - recall_at_10: 0.1022 - mrr_at_10: 0.0435 - ndcg_at_10: 0.0571 - map_at_10: 0.0435 - precision_at_10: 0.0102 - regularization_loss: 0.0000e+00 - loss_batch: 6.1858 - val_loss: 6.8932 - val_auc_52: 0.5849 - val_recall_at_10: 0.0308 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0152 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8387
# Epoch 20/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.1920 - auc_52: 0.6542 - recall_at_10: 0.1020 - mrr_at_10: 0.0435 - ndcg_at_10: 0.0571 - map_at_10: 0.0435 - precision_at_10: 0.0102 - regularization_loss: 0.0000e+00 - loss_batch: 6.1781 - val_loss: 6.9059 - val_auc_52: 0.5803 - val_recall_at_10: 0.0335 - val_mrr_at_10: 0.0109 - val_ndcg_at_10: 0.0161 - val_map_at_10: 0.0109 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8352
# Epoch 21/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.1862 - auc_52: 0.6514 - recall_at_10: 0.1013 - mrr_at_10: 0.0440 - ndcg_at_10: 0.0574 - map_at_10: 0.0440 - precision_at_10: 0.0101 - regularization_loss: 0.0000e+00 - loss_batch: 6.1724 - val_loss: 6.8697 - val_auc_52: 0.5739 - val_recall_at_10: 0.0343 - val_mrr_at_10: 0.0108 - val_ndcg_at_10: 0.0162 - val_map_at_10: 0.0108 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7619
# Epoch 22/150
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1804 - auc_52: 0.6522 - recall_at_10: 0.1073 - mrr_at_10: 0.0460 - ndcg_at_10: 0.0602 - map_at_10: 0.0460 - precision_at_10: 0.0107 - regularization_loss: 0.0000e+00 - loss_batch: 6.1667 - val_loss: 6.9356 - val_auc_52: 0.5839 - val_recall_at_10: 0.0334 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0158 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9746
# Epoch 23/150
# 69/69 [==============================] - 4s 41ms/step - loss: 6.1726 - auc_52: 0.6517 - recall_at_10: 0.1060 - mrr_at_10: 0.0466 - ndcg_at_10: 0.0604 - map_at_10: 0.0466 - precision_at_10: 0.0106 - regularization_loss: 0.0000e+00 - loss_batch: 6.1588 - val_loss: 6.9088 - val_auc_52: 0.5731 - val_recall_at_10: 0.0334 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0158 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8724
# Epoch 24/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.1685 - auc_52: 0.6599 - recall_at_10: 0.1045 - mrr_at_10: 0.0443 - ndcg_at_10: 0.0582 - map_at_10: 0.0443 - precision_at_10: 0.0104 - regularization_loss: 0.0000e+00 - loss_batch: 6.1545 - val_loss: 6.9219 - val_auc_52: 0.5746 - val_recall_at_10: 0.0308 - val_mrr_at_10: 0.0100 - val_ndcg_at_10: 0.0147 - val_map_at_10: 0.0100 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8519
# Epoch 25/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.1676 - auc_52: 0.6559 - recall_at_10: 0.1058 - mrr_at_10: 0.0465 - ndcg_at_10: 0.0602 - map_at_10: 0.0465 - precision_at_10: 0.0106 - regularization_loss: 0.0000e+00 - loss_batch: 6.1531 - val_loss: 6.9329 - val_auc_52: 0.5962 - val_recall_at_10: 0.0310 - val_mrr_at_10: 0.0101 - val_ndcg_at_10: 0.0149 - val_map_at_10: 0.0101 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8793
# Epoch 26/150
# 69/69 [==============================] - 3s 38ms/step - loss: 6.1623 - auc_52: 0.6594 - recall_at_10: 0.1083 - mrr_at_10: 0.0468 - ndcg_at_10: 0.0611 - map_at_10: 0.0468 - precision_at_10: 0.0108 - regularization_loss: 0.0000e+00 - loss_batch: 6.1485 - val_loss: 6.8911 - val_auc_52: 0.5970 - val_recall_at_10: 0.0339 - val_mrr_at_10: 0.0106 - val_ndcg_at_10: 0.0159 - val_map_at_10: 0.0106 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8835
# Epoch 27/150
# 69/69 [==============================] - 4s 49ms/step - loss: 6.1575 - auc_52: 0.6572 - recall_at_10: 0.1096 - mrr_at_10: 0.0477 - ndcg_at_10: 0.0620 - map_at_10: 0.0477 - precision_at_10: 0.0110 - regularization_loss: 0.0000e+00 - loss_batch: 6.1430 - val_loss: 6.9281 - val_auc_52: 0.5869 - val_recall_at_10: 0.0314 - val_mrr_at_10: 0.0098 - val_ndcg_at_10: 0.0148 - val_map_at_10: 0.0098 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9010
# Epoch 28/150
# 69/69 [==============================] - 4s 49ms/step - loss: 6.1536 - auc_52: 0.6652 - recall_at_10: 0.1098 - mrr_at_10: 0.0484 - ndcg_at_10: 0.0626 - map_at_10: 0.0484 - precision_at_10: 0.0110 - regularization_loss: 0.0000e+00 - loss_batch: 6.1393 - val_loss: 6.9319 - val_auc_52: 0.5892 - val_recall_at_10: 0.0324 - val_mrr_at_10: 0.0100 - val_ndcg_at_10: 0.0151 - val_map_at_10: 0.0100 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0002
# Epoch 29/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.1508 - auc_52: 0.6583 - recall_at_10: 0.1120 - mrr_at_10: 0.0488 - ndcg_at_10: 0.0635 - map_at_10: 0.0488 - precision_at_10: 0.0112 - regularization_loss: 0.0000e+00 - loss_batch: 6.1366 - val_loss: 6.9534 - val_auc_52: 0.5857 - val_recall_at_10: 0.0299 - val_mrr_at_10: 0.0091 - val_ndcg_at_10: 0.0139 - val_map_at_10: 0.0091 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9434
# Epoch 30/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.1454 - auc_52: 0.6647 - recall_at_10: 0.1108 - mrr_at_10: 0.0473 - ndcg_at_10: 0.0620 - map_at_10: 0.0473 - precision_at_10: 0.0111 - regularization_loss: 0.0000e+00 - loss_batch: 6.1312 - val_loss: 7.0045 - val_auc_52: 0.5858 - val_recall_at_10: 0.0292 - val_mrr_at_10: 0.0091 - val_ndcg_at_10: 0.0137 - val_map_at_10: 0.0091 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0260
# Epoch 31/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1369 - auc_52: 0.6603 - recall_at_10: 0.1108 - mrr_at_10: 0.0478 - ndcg_at_10: 0.0625 - map_at_10: 0.0478 - precision_at_10: 0.0111 - regularization_loss: 0.0000e+00 - loss_batch: 6.1218 - val_loss: 6.9980 - val_auc_52: 0.5865 - val_recall_at_10: 0.0304 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0137 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0560
# Epoch 32/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.1364 - auc_52: 0.6675 - recall_at_10: 0.1117 - mrr_at_10: 0.0486 - ndcg_at_10: 0.0633 - map_at_10: 0.0486 - precision_at_10: 0.0112 - regularization_loss: 0.0000e+00 - loss_batch: 6.1222 - val_loss: 7.0087 - val_auc_52: 0.5866 - val_recall_at_10: 0.0269 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0129 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0926
# Epoch 33/150
# 69/69 [==============================] - 5s 61ms/step - loss: 6.1350 - auc_52: 0.6611 - recall_at_10: 0.1148 - mrr_at_10: 0.0508 - ndcg_at_10: 0.0657 - map_at_10: 0.0508 - precision_at_10: 0.0115 - regularization_loss: 0.0000e+00 - loss_batch: 6.1205 - val_loss: 6.9968 - val_auc_52: 0.5826 - val_recall_at_10: 0.0299 - val_mrr_at_10: 0.0095 - val_ndcg_at_10: 0.0142 - val_map_at_10: 0.0095 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9636
# Epoch 34/150
# 69/69 [==============================] - 3s 37ms/step - loss: 6.1314 - auc_52: 0.6644 - recall_at_10: 0.1120 - mrr_at_10: 0.0496 - ndcg_at_10: 0.0641 - map_at_10: 0.0496 - precision_at_10: 0.0112 - regularization_loss: 0.0000e+00 - loss_batch: 6.1166 - val_loss: 6.9907 - val_auc_52: 0.5926 - val_recall_at_10: 0.0306 - val_mrr_at_10: 0.0090 - val_ndcg_at_10: 0.0139 - val_map_at_10: 0.0090 - val_precision_at_10: 0.0031 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0467
# Epoch 35/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.1264 - auc_52: 0.6654 - recall_at_10: 0.1126 - mrr_at_10: 0.0506 - ndcg_at_10: 0.0650 - map_at_10: 0.0506 - precision_at_10: 0.0113 - regularization_loss: 0.0000e+00 - loss_batch: 6.1116 - val_loss: 6.9917 - val_auc_52: 0.5882 - val_recall_at_10: 0.0288 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0133 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0532
# Epoch 36/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.1281 - auc_52: 0.6685 - recall_at_10: 0.1151 - mrr_at_10: 0.0505 - ndcg_at_10: 0.0655 - map_at_10: 0.0505 - precision_at_10: 0.0115 - regularization_loss: 0.0000e+00 - loss_batch: 6.1132 - val_loss: 7.0146 - val_auc_52: 0.5836 - val_recall_at_10: 0.0283 - val_mrr_at_10: 0.0089 - val_ndcg_at_10: 0.0133 - val_map_at_10: 0.0089 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0185
# Epoch 37/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1256 - auc_52: 0.6725 - recall_at_10: 0.1144 - mrr_at_10: 0.0506 - ndcg_at_10: 0.0654 - map_at_10: 0.0506 - precision_at_10: 0.0114 - regularization_loss: 0.0000e+00 - loss_batch: 6.1112 - val_loss: 6.9712 - val_auc_52: 0.5953 - val_recall_at_10: 0.0302 - val_mrr_at_10: 0.0093 - val_ndcg_at_10: 0.0141 - val_map_at_10: 0.0093 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9648
# Epoch 38/150
# 69/69 [==============================] - 3s 34ms/step - loss: 6.1227 - auc_52: 0.6752 - recall_at_10: 0.1161 - mrr_at_10: 0.0506 - ndcg_at_10: 0.0659 - map_at_10: 0.0506 - precision_at_10: 0.0116 - regularization_loss: 0.0000e+00 - loss_batch: 6.1085 - val_loss: 7.0768 - val_auc_52: 0.5892 - val_recall_at_10: 0.0296 - val_mrr_at_10: 0.0087 - val_ndcg_at_10: 0.0135 - val_map_at_10: 0.0087 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0246
# Epoch 39/150
# 69/69 [==============================] - 3s 34ms/step - loss: 6.1203 - auc_52: 0.6735 - recall_at_10: 0.1204 - mrr_at_10: 0.0526 - ndcg_at_10: 0.0683 - map_at_10: 0.0526 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.1050 - val_loss: 7.0350 - val_auc_52: 0.5855 - val_recall_at_10: 0.0277 - val_mrr_at_10: 0.0083 - val_ndcg_at_10: 0.0127 - val_map_at_10: 0.0083 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1014
# Epoch 40/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.1169 - auc_52: 0.6792 - recall_at_10: 0.1167 - mrr_at_10: 0.0517 - ndcg_at_10: 0.0669 - map_at_10: 0.0517 - precision_at_10: 0.0117 - regularization_loss: 0.0000e+00 - loss_batch: 6.1023 - val_loss: 7.0389 - val_auc_52: 0.5942 - val_recall_at_10: 0.0271 - val_mrr_at_10: 0.0085 - val_ndcg_at_10: 0.0128 - val_map_at_10: 0.0085 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1582
# Epoch 41/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1125 - auc_52: 0.6770 - recall_at_10: 0.1193 - mrr_at_10: 0.0520 - ndcg_at_10: 0.0676 - map_at_10: 0.0520 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0979 - val_loss: 7.0317 - val_auc_52: 0.5978 - val_recall_at_10: 0.0298 - val_mrr_at_10: 0.0085 - val_ndcg_at_10: 0.0134 - val_map_at_10: 0.0085 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0787
# Epoch 42/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.1105 - auc_52: 0.6782 - recall_at_10: 0.1172 - mrr_at_10: 0.0527 - ndcg_at_10: 0.0676 - map_at_10: 0.0527 - precision_at_10: 0.0117 - regularization_loss: 0.0000e+00 - loss_batch: 6.0950 - val_loss: 7.0743 - val_auc_52: 0.5925 - val_recall_at_10: 0.0283 - val_mrr_at_10: 0.0084 - val_ndcg_at_10: 0.0129 - val_map_at_10: 0.0084 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1097
# Epoch 43/150
# 69/69 [==============================] - 3s 34ms/step - loss: 6.1080 - auc_52: 0.6830 - recall_at_10: 0.1222 - mrr_at_10: 0.0535 - ndcg_at_10: 0.0694 - map_at_10: 0.0535 - precision_at_10: 0.0122 - regularization_loss: 0.0000e+00 - loss_batch: 6.0931 - val_loss: 7.0621 - val_auc_52: 0.6022 - val_recall_at_10: 0.0268 - val_mrr_at_10: 0.0080 - val_ndcg_at_10: 0.0123 - val_map_at_10: 0.0080 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1984
# Epoch 44/150
# 69/69 [==============================] - 4s 44ms/step - loss: 6.1054 - auc_52: 0.6789 - recall_at_10: 0.1190 - mrr_at_10: 0.0524 - ndcg_at_10: 0.0678 - map_at_10: 0.0524 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0904 - val_loss: 7.0618 - val_auc_52: 0.5935 - val_recall_at_10: 0.0279 - val_mrr_at_10: 0.0074 - val_ndcg_at_10: 0.0121 - val_map_at_10: 0.0074 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1799
# Epoch 45/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1062 - auc_52: 0.6812 - recall_at_10: 0.1210 - mrr_at_10: 0.0526 - ndcg_at_10: 0.0684 - map_at_10: 0.0526 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0912 - val_loss: 7.1035 - val_auc_52: 0.5957 - val_recall_at_10: 0.0275 - val_mrr_at_10: 0.0082 - val_ndcg_at_10: 0.0126 - val_map_at_10: 0.0082 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2493
# Epoch 46/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.1016 - auc_52: 0.6767 - recall_at_10: 0.1209 - mrr_at_10: 0.0543 - ndcg_at_10: 0.0697 - map_at_10: 0.0543 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0862 - val_loss: 7.1031 - val_auc_52: 0.6081 - val_recall_at_10: 0.0272 - val_mrr_at_10: 0.0082 - val_ndcg_at_10: 0.0126 - val_map_at_10: 0.0082 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2861
# Epoch 47/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.1004 - auc_52: 0.6819 - recall_at_10: 0.1205 - mrr_at_10: 0.0540 - ndcg_at_10: 0.0694 - map_at_10: 0.0540 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0851 - val_loss: 7.0700 - val_auc_52: 0.6028 - val_recall_at_10: 0.0274 - val_mrr_at_10: 0.0081 - val_ndcg_at_10: 0.0125 - val_map_at_10: 0.0081 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1350
# Epoch 48/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0993 - auc_52: 0.6783 - recall_at_10: 0.1212 - mrr_at_10: 0.0533 - ndcg_at_10: 0.0690 - map_at_10: 0.0533 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0839 - val_loss: 7.0855 - val_auc_52: 0.6001 - val_recall_at_10: 0.0291 - val_mrr_at_10: 0.0086 - val_ndcg_at_10: 0.0133 - val_map_at_10: 0.0086 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2067
# Epoch 49/150
# 69/69 [==============================] - 3s 41ms/step - loss: 6.0984 - auc_52: 0.6794 - recall_at_10: 0.1230 - mrr_at_10: 0.0553 - ndcg_at_10: 0.0710 - map_at_10: 0.0553 - precision_at_10: 0.0123 - regularization_loss: 0.0000e+00 - loss_batch: 6.0829 - val_loss: 7.0918 - val_auc_52: 0.6020 - val_recall_at_10: 0.0277 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0131 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1795
# Epoch 50/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0951 - auc_52: 0.6767 - recall_at_10: 0.1206 - mrr_at_10: 0.0536 - ndcg_at_10: 0.0692 - map_at_10: 0.0536 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0800 - val_loss: 7.1008 - val_auc_52: 0.5968 - val_recall_at_10: 0.0274 - val_mrr_at_10: 0.0081 - val_ndcg_at_10: 0.0125 - val_map_at_10: 0.0081 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2359
# Epoch 51/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0947 - auc_52: 0.6805 - recall_at_10: 0.1195 - mrr_at_10: 0.0533 - ndcg_at_10: 0.0687 - map_at_10: 0.0533 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0792 - val_loss: 7.1240 - val_auc_52: 0.5932 - val_recall_at_10: 0.0257 - val_mrr_at_10: 0.0080 - val_ndcg_at_10: 0.0121 - val_map_at_10: 0.0080 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2952
# Epoch 52/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0923 - auc_52: 0.6758 - recall_at_10: 0.1207 - mrr_at_10: 0.0542 - ndcg_at_10: 0.0696 - map_at_10: 0.0542 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0769 - val_loss: 7.1218 - val_auc_52: 0.5993 - val_recall_at_10: 0.0286 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0133 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1684
# Epoch 53/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0931 - auc_52: 0.6784 - recall_at_10: 0.1212 - mrr_at_10: 0.0530 - ndcg_at_10: 0.0688 - map_at_10: 0.0530 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0776 - val_loss: 7.0918 - val_auc_52: 0.6002 - val_recall_at_10: 0.0269 - val_mrr_at_10: 0.0081 - val_ndcg_at_10: 0.0124 - val_map_at_10: 0.0081 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2484
# Epoch 54/150
# 69/69 [==============================] - 4s 46ms/step - loss: 6.0893 - auc_52: 0.6779 - recall_at_10: 0.1206 - mrr_at_10: 0.0529 - ndcg_at_10: 0.0686 - map_at_10: 0.0529 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0740 - val_loss: 7.1050 - val_auc_52: 0.6036 - val_recall_at_10: 0.0283 - val_mrr_at_10: 0.0087 - val_ndcg_at_10: 0.0132 - val_map_at_10: 0.0087 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2547
# Epoch 55/150
# 69/69 [==============================] - 4s 49ms/step - loss: 6.0877 - auc_52: 0.6745 - recall_at_10: 0.1210 - mrr_at_10: 0.0535 - ndcg_at_10: 0.0691 - map_at_10: 0.0535 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0725 - val_loss: 7.1053 - val_auc_52: 0.6003 - val_recall_at_10: 0.0253 - val_mrr_at_10: 0.0079 - val_ndcg_at_10: 0.0119 - val_map_at_10: 0.0079 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2616
# Epoch 56/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.0848 - auc_52: 0.6764 - recall_at_10: 0.1212 - mrr_at_10: 0.0539 - ndcg_at_10: 0.0696 - map_at_10: 0.0539 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0691 - val_loss: 7.1012 - val_auc_52: 0.6041 - val_recall_at_10: 0.0269 - val_mrr_at_10: 0.0084 - val_ndcg_at_10: 0.0126 - val_map_at_10: 0.0084 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2486
# Epoch 57/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0853 - auc_52: 0.6768 - recall_at_10: 0.1234 - mrr_at_10: 0.0547 - ndcg_at_10: 0.0707 - map_at_10: 0.0547 - precision_at_10: 0.0123 - regularization_loss: 0.0000e+00 - loss_batch: 6.0703 - val_loss: 7.1298 - val_auc_52: 0.6042 - val_recall_at_10: 0.0251 - val_mrr_at_10: 0.0075 - val_ndcg_at_10: 0.0115 - val_map_at_10: 0.0075 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2828
# Epoch 58/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0842 - auc_52: 0.6743 - recall_at_10: 0.1238 - mrr_at_10: 0.0549 - ndcg_at_10: 0.0709 - map_at_10: 0.0549 - precision_at_10: 0.0124 - regularization_loss: 0.0000e+00 - loss_batch: 6.0688 - val_loss: 7.1228 - val_auc_52: 0.6019 - val_recall_at_10: 0.0263 - val_mrr_at_10: 0.0076 - val_ndcg_at_10: 0.0119 - val_map_at_10: 0.0076 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2373
# Epoch 59/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0799 - auc_52: 0.6696 - recall_at_10: 0.1249 - mrr_at_10: 0.0559 - ndcg_at_10: 0.0719 - map_at_10: 0.0559 - precision_at_10: 0.0125 - regularization_loss: 0.0000e+00 - loss_batch: 6.0639 - val_loss: 7.1696 - val_auc_52: 0.5969 - val_recall_at_10: 0.0239 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0105 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2961
# Epoch 60/150
# 69/69 [==============================] - 3s 34ms/step - loss: 6.0791 - auc_52: 0.6712 - recall_at_10: 0.1244 - mrr_at_10: 0.0556 - ndcg_at_10: 0.0716 - map_at_10: 0.0556 - precision_at_10: 0.0124 - regularization_loss: 0.0000e+00 - loss_batch: 6.0629 - val_loss: 7.1362 - val_auc_52: 0.6065 - val_recall_at_10: 0.0265 - val_mrr_at_10: 0.0083 - val_ndcg_at_10: 0.0124 - val_map_at_10: 0.0083 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2887
# Epoch 61/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0776 - auc_52: 0.6786 - recall_at_10: 0.1237 - mrr_at_10: 0.0542 - ndcg_at_10: 0.0704 - map_at_10: 0.0542 - precision_at_10: 0.0124 - regularization_loss: 0.0000e+00 - loss_batch: 6.0620 - val_loss: 7.1328 - val_auc_52: 0.6049 - val_recall_at_10: 0.0274 - val_mrr_at_10: 0.0079 - val_ndcg_at_10: 0.0123 - val_map_at_10: 0.0079 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2868
# Epoch 62/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0788 - auc_52: 0.6692 - recall_at_10: 0.1238 - mrr_at_10: 0.0554 - ndcg_at_10: 0.0713 - map_at_10: 0.0554 - precision_at_10: 0.0124 - regularization_loss: 0.0000e+00 - loss_batch: 6.0632 - val_loss: 7.1150 - val_auc_52: 0.6082 - val_recall_at_10: 0.0264 - val_mrr_at_10: 0.0082 - val_ndcg_at_10: 0.0124 - val_map_at_10: 0.0082 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2613
# Epoch 63/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0746 - auc_52: 0.6743 - recall_at_10: 0.1241 - mrr_at_10: 0.0551 - ndcg_at_10: 0.0711 - map_at_10: 0.0551 - precision_at_10: 0.0124 - regularization_loss: 0.0000e+00 - loss_batch: 6.0589 - val_loss: 7.1223 - val_auc_52: 0.6053 - val_recall_at_10: 0.0263 - val_mrr_at_10: 0.0078 - val_ndcg_at_10: 0.0120 - val_map_at_10: 0.0078 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2318
# Epoch 64/150
# 69/69 [==============================] - 4s 46ms/step - loss: 6.0736 - auc_52: 0.6704 - recall_at_10: 0.1250 - mrr_at_10: 0.0556 - ndcg_at_10: 0.0717 - map_at_10: 0.0556 - precision_at_10: 0.0125 - regularization_loss: 0.0000e+00 - loss_batch: 6.0576 - val_loss: 7.1402 - val_auc_52: 0.6001 - val_recall_at_10: 0.0233 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0103 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2145
# Epoch 65/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0721 - auc_52: 0.6680 - recall_at_10: 0.1265 - mrr_at_10: 0.0573 - ndcg_at_10: 0.0733 - map_at_10: 0.0573 - precision_at_10: 0.0127 - regularization_loss: 0.0000e+00 - loss_batch: 6.0570 - val_loss: 7.1714 - val_auc_52: 0.6045 - val_recall_at_10: 0.0243 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0115 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3173
# Epoch 66/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0708 - auc_52: 0.6667 - recall_at_10: 0.1252 - mrr_at_10: 0.0566 - ndcg_at_10: 0.0725 - map_at_10: 0.0566 - precision_at_10: 0.0125 - regularization_loss: 0.0000e+00 - loss_batch: 6.0549 - val_loss: 7.1355 - val_auc_52: 0.6069 - val_recall_at_10: 0.0252 - val_mrr_at_10: 0.0071 - val_ndcg_at_10: 0.0113 - val_map_at_10: 0.0071 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4305
# Epoch 67/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.0732 - auc_52: 0.6674 - recall_at_10: 0.1259 - mrr_at_10: 0.0560 - ndcg_at_10: 0.0722 - map_at_10: 0.0560 - precision_at_10: 0.0126 - regularization_loss: 0.0000e+00 - loss_batch: 6.0576 - val_loss: 7.0948 - val_auc_52: 0.5975 - val_recall_at_10: 0.0247 - val_mrr_at_10: 0.0078 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0078 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2437
# Epoch 68/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0707 - auc_52: 0.6657 - recall_at_10: 0.1253 - mrr_at_10: 0.0555 - ndcg_at_10: 0.0717 - map_at_10: 0.0555 - precision_at_10: 0.0125 - regularization_loss: 0.0000e+00 - loss_batch: 6.0549 - val_loss: 7.1679 - val_auc_52: 0.6026 - val_recall_at_10: 0.0259 - val_mrr_at_10: 0.0076 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0076 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3014
# Epoch 69/150
# 69/69 [==============================] - 4s 42ms/step - loss: 6.0686 - auc_52: 0.6646 - recall_at_10: 0.1248 - mrr_at_10: 0.0546 - ndcg_at_10: 0.0710 - map_at_10: 0.0546 - precision_at_10: 0.0125 - regularization_loss: 0.0000e+00 - loss_batch: 6.0534 - val_loss: 7.1931 - val_auc_52: 0.5988 - val_recall_at_10: 0.0257 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0118 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3619
# Epoch 70/150
# 69/69 [==============================] - 3s 27ms/step - loss: 6.0691 - auc_52: 0.6662 - recall_at_10: 0.1273 - mrr_at_10: 0.0563 - ndcg_at_10: 0.0727 - map_at_10: 0.0563 - precision_at_10: 0.0127 - regularization_loss: 0.0000e+00 - loss_batch: 6.0530 - val_loss: 7.1885 - val_auc_52: 0.6020 - val_recall_at_10: 0.0264 - val_mrr_at_10: 0.0073 - val_ndcg_at_10: 0.0116 - val_map_at_10: 0.0073 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3556
# Epoch 71/150
# 69/69 [==============================] - 2s 26ms/step - loss: 6.0680 - auc_52: 0.6610 - recall_at_10: 0.1260 - mrr_at_10: 0.0567 - ndcg_at_10: 0.0728 - map_at_10: 0.0567 - precision_at_10: 0.0126 - regularization_loss: 0.0000e+00 - loss_batch: 6.0525 - val_loss: 7.2010 - val_auc_52: 0.6012 - val_recall_at_10: 0.0240 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0106 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3131
# Epoch 72/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.0655 - auc_52: 0.6604 - recall_at_10: 0.1263 - mrr_at_10: 0.0562 - ndcg_at_10: 0.0725 - map_at_10: 0.0562 - precision_at_10: 0.0126 - regularization_loss: 0.0000e+00 - loss_batch: 6.0493 - val_loss: 7.1900 - val_auc_52: 0.6014 - val_recall_at_10: 0.0247 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0109 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3215
# Epoch 73/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0680 - auc_52: 0.6600 - recall_at_10: 0.1263 - mrr_at_10: 0.0562 - ndcg_at_10: 0.0725 - map_at_10: 0.0562 - precision_at_10: 0.0126 - regularization_loss: 0.0000e+00 - loss_batch: 6.0520 - val_loss: 7.1907 - val_auc_52: 0.6010 - val_recall_at_10: 0.0235 - val_mrr_at_10: 0.0074 - val_ndcg_at_10: 0.0111 - val_map_at_10: 0.0074 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2353
# Epoch 74/150
# 69/69 [==============================] - 4s 41ms/step - loss: 6.0641 - auc_52: 0.6577 - recall_at_10: 0.1268 - mrr_at_10: 0.0569 - ndcg_at_10: 0.0732 - map_at_10: 0.0569 - precision_at_10: 0.0127 - regularization_loss: 0.0000e+00 - loss_batch: 6.0484 - val_loss: 7.1986 - val_auc_52: 0.6003 - val_recall_at_10: 0.0229 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0106 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2762
# Epoch 75/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0645 - auc_52: 0.6577 - recall_at_10: 0.1257 - mrr_at_10: 0.0558 - ndcg_at_10: 0.0720 - map_at_10: 0.0558 - precision_at_10: 0.0126 - regularization_loss: 0.0000e+00 - loss_batch: 6.0483 - val_loss: 7.2075 - val_auc_52: 0.5994 - val_recall_at_10: 0.0241 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0106 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3665
# Epoch 76/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.0636 - auc_52: 0.6544 - recall_at_10: 0.1286 - mrr_at_10: 0.0571 - ndcg_at_10: 0.0737 - map_at_10: 0.0571 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0482 - val_loss: 7.1523 - val_auc_52: 0.6022 - val_recall_at_10: 0.0258 - val_mrr_at_10: 0.0076 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0076 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2781
# Epoch 77/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0606 - auc_52: 0.6531 - recall_at_10: 0.1276 - mrr_at_10: 0.0565 - ndcg_at_10: 0.0730 - map_at_10: 0.0565 - precision_at_10: 0.0128 - regularization_loss: 0.0000e+00 - loss_batch: 6.0443 - val_loss: 7.2133 - val_auc_52: 0.6007 - val_recall_at_10: 0.0238 - val_mrr_at_10: 0.0073 - val_ndcg_at_10: 0.0111 - val_map_at_10: 0.0073 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4341
# Epoch 78/150
# 69/69 [==============================] - 3s 40ms/step - loss: 6.0578 - auc_52: 0.6524 - recall_at_10: 0.1293 - mrr_at_10: 0.0572 - ndcg_at_10: 0.0739 - map_at_10: 0.0572 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0415 - val_loss: 7.2076 - val_auc_52: 0.5951 - val_recall_at_10: 0.0239 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0110 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3779
# Epoch 79/150
# 69/69 [==============================] - 3s 36ms/step - loss: 6.0589 - auc_52: 0.6472 - recall_at_10: 0.1291 - mrr_at_10: 0.0566 - ndcg_at_10: 0.0734 - map_at_10: 0.0566 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0428 - val_loss: 7.1795 - val_auc_52: 0.6023 - val_recall_at_10: 0.0232 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0104 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3556
# Epoch 80/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.0551 - auc_52: 0.6522 - recall_at_10: 0.1282 - mrr_at_10: 0.0582 - ndcg_at_10: 0.0744 - map_at_10: 0.0582 - precision_at_10: 0.0128 - regularization_loss: 0.0000e+00 - loss_batch: 6.0392 - val_loss: 7.2006 - val_auc_52: 0.5963 - val_recall_at_10: 0.0246 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0111 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4378
# Epoch 81/150
# 69/69 [==============================] - 2s 27ms/step - loss: 6.0566 - auc_52: 0.6459 - recall_at_10: 0.1295 - mrr_at_10: 0.0576 - ndcg_at_10: 0.0743 - map_at_10: 0.0576 - precision_at_10: 0.0130 - regularization_loss: 0.0000e+00 - loss_batch: 6.0408 - val_loss: 7.2245 - val_auc_52: 0.5944 - val_recall_at_10: 0.0231 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0105 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4194
# Epoch 82/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.0578 - auc_52: 0.6425 - recall_at_10: 0.1283 - mrr_at_10: 0.0562 - ndcg_at_10: 0.0730 - map_at_10: 0.0562 - precision_at_10: 0.0128 - regularization_loss: 0.0000e+00 - loss_batch: 6.0416 - val_loss: 7.2170 - val_auc_52: 0.5940 - val_recall_at_10: 0.0250 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0110 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4759
# Epoch 83/150
# 69/69 [==============================] - 3s 38ms/step - loss: 6.0546 - auc_52: 0.6414 - recall_at_10: 0.1285 - mrr_at_10: 0.0578 - ndcg_at_10: 0.0742 - map_at_10: 0.0578 - precision_at_10: 0.0128 - regularization_loss: 0.0000e+00 - loss_batch: 6.0387 - val_loss: 7.1946 - val_auc_52: 0.5987 - val_recall_at_10: 0.0245 - val_mrr_at_10: 0.0074 - val_ndcg_at_10: 0.0113 - val_map_at_10: 0.0074 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3798
# Epoch 84/150
# 69/69 [==============================] - 4s 43ms/step - loss: 6.0557 - auc_52: 0.6409 - recall_at_10: 0.1292 - mrr_at_10: 0.0575 - ndcg_at_10: 0.0742 - map_at_10: 0.0575 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0402 - val_loss: 7.2211 - val_auc_52: 0.5962 - val_recall_at_10: 0.0245 - val_mrr_at_10: 0.0070 - val_ndcg_at_10: 0.0109 - val_map_at_10: 0.0070 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3635
# Epoch 85/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0565 - auc_52: 0.6424 - recall_at_10: 0.1288 - mrr_at_10: 0.0567 - ndcg_at_10: 0.0734 - map_at_10: 0.0567 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0399 - val_loss: 7.2427 - val_auc_52: 0.5958 - val_recall_at_10: 0.0236 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0107 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4858
# Epoch 86/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.0547 - auc_52: 0.6392 - recall_at_10: 0.1292 - mrr_at_10: 0.0578 - ndcg_at_10: 0.0744 - map_at_10: 0.0578 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0384 - val_loss: 7.2046 - val_auc_52: 0.5945 - val_recall_at_10: 0.0243 - val_mrr_at_10: 0.0071 - val_ndcg_at_10: 0.0110 - val_map_at_10: 0.0071 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3548
# Epoch 87/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0524 - auc_52: 0.6372 - recall_at_10: 0.1311 - mrr_at_10: 0.0577 - ndcg_at_10: 0.0747 - map_at_10: 0.0577 - precision_at_10: 0.0131 - regularization_loss: 0.0000e+00 - loss_batch: 6.0359 - val_loss: 7.2160 - val_auc_52: 0.5965 - val_recall_at_10: 0.0235 - val_mrr_at_10: 0.0070 - val_ndcg_at_10: 0.0107 - val_map_at_10: 0.0070 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4276
# Epoch 88/150
# 69/69 [==============================] - 4s 44ms/step - loss: 6.0521 - auc_52: 0.6371 - recall_at_10: 0.1288 - mrr_at_10: 0.0570 - ndcg_at_10: 0.0737 - map_at_10: 0.0570 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0358 - val_loss: 7.2004 - val_auc_52: 0.5873 - val_recall_at_10: 0.0240 - val_mrr_at_10: 0.0068 - val_ndcg_at_10: 0.0107 - val_map_at_10: 0.0068 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4070
# Epoch 89/150
# 69/69 [==============================] - 3s 36ms/step - loss: 6.0520 - auc_52: 0.6358 - recall_at_10: 0.1294 - mrr_at_10: 0.0569 - ndcg_at_10: 0.0737 - map_at_10: 0.0569 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0359 - val_loss: 7.3038 - val_auc_52: 0.5890 - val_recall_at_10: 0.0229 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0102 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6207
# Epoch 90/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.0479 - auc_52: 0.6312 - recall_at_10: 0.1307 - mrr_at_10: 0.0580 - ndcg_at_10: 0.0749 - map_at_10: 0.0580 - precision_at_10: 0.0131 - regularization_loss: 0.0000e+00 - loss_batch: 6.0315 - val_loss: 7.2590 - val_auc_52: 0.5910 - val_recall_at_10: 0.0225 - val_mrr_at_10: 0.0062 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0062 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5313
# Epoch 91/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0465 - auc_52: 0.6313 - recall_at_10: 0.1293 - mrr_at_10: 0.0578 - ndcg_at_10: 0.0745 - map_at_10: 0.0578 - precision_at_10: 0.0129 - regularization_loss: 0.0000e+00 - loss_batch: 6.0302 - val_loss: 7.2244 - val_auc_52: 0.5910 - val_recall_at_10: 0.0245 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0109 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5012
# Epoch 92/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0494 - auc_52: 0.6287 - recall_at_10: 0.1304 - mrr_at_10: 0.0586 - ndcg_at_10: 0.0752 - map_at_10: 0.0586 - precision_at_10: 0.0130 - regularization_loss: 0.0000e+00 - loss_batch: 6.0338 - val_loss: 7.1754 - val_auc_52: 0.5891 - val_recall_at_10: 0.0253 - val_mrr_at_10: 0.0079 - val_ndcg_at_10: 0.0118 - val_map_at_10: 0.0079 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5053
# Epoch 93/150
# 69/69 [==============================] - 4s 54ms/step - loss: 6.0477 - auc_52: 0.6286 - recall_at_10: 0.1314 - mrr_at_10: 0.0592 - ndcg_at_10: 0.0759 - map_at_10: 0.0592 - precision_at_10: 0.0131 - regularization_loss: 0.0000e+00 - loss_batch: 6.0318 - val_loss: 7.2263 - val_auc_52: 0.5850 - val_recall_at_10: 0.0239 - val_mrr_at_10: 0.0071 - val_ndcg_at_10: 0.0110 - val_map_at_10: 0.0071 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4520
# Epoch 94/150
# 69/69 [==============================] - 4s 40ms/step - loss: 6.0471 - auc_52: 0.6260 - recall_at_10: 0.1298 - mrr_at_10: 0.0580 - ndcg_at_10: 0.0747 - map_at_10: 0.0580 - precision_at_10: 0.0130 - regularization_loss: 0.0000e+00 - loss_batch: 6.0304 - val_loss: 7.2651 - val_auc_52: 0.5882 - val_recall_at_10: 0.0253 - val_mrr_at_10: 0.0075 - val_ndcg_at_10: 0.0116 - val_map_at_10: 0.0075 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5653
# Epoch 95/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0450 - auc_52: 0.6264 - recall_at_10: 0.1319 - mrr_at_10: 0.0584 - ndcg_at_10: 0.0755 - map_at_10: 0.0584 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0286 - val_loss: 7.2263 - val_auc_52: 0.5889 - val_recall_at_10: 0.0226 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0103 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.4940
# Epoch 96/150
# 69/69 [==============================] - 3s 42ms/step - loss: 6.0490 - auc_52: 0.6207 - recall_at_10: 0.1321 - mrr_at_10: 0.0590 - ndcg_at_10: 0.0760 - map_at_10: 0.0590 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0325 - val_loss: 7.2325 - val_auc_52: 0.5834 - val_recall_at_10: 0.0233 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0104 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5298
# Epoch 97/150
# ...
# Epoch 119/150
# 69/69 [==============================] - 2s 28ms/step - loss: 6.0353 - auc_52: 0.5949 - recall_at_10: 0.1329 - mrr_at_10: 0.0596 - ndcg_at_10: 0.0766 - map_at_10: 0.0596 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0186 - val_loss: 7.2934 - val_auc_52: 0.5707 - val_recall_at_10: 0.0224 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0100 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5293
# Epoch 120/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0353 - auc_52: 0.5920 - recall_at_10: 0.1315 - mrr_at_10: 0.0593 - ndcg_at_10: 0.0761 - map_at_10: 0.0593 - precision_at_10: 0.0131 - regularization_loss: 0.0000e+00 - loss_batch: 6.0187 - val_loss: 7.2739 - val_auc_52: 0.5646 - val_recall_at_10: 0.0244 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0111 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6303
# Epoch 121/150
# 69/69 [==============================] - 3s 36ms/step - loss: 6.0373 - auc_52: 0.5910 - recall_at_10: 0.1339 - mrr_at_10: 0.0596 - ndcg_at_10: 0.0768 - map_at_10: 0.0596 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0208 - val_loss: 7.2425 - val_auc_52: 0.5712 - val_recall_at_10: 0.0241 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0110 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5306
# Epoch 122/150
# 69/69 [==============================] - 4s 39ms/step - loss: 6.0345 - auc_52: 0.5898 - recall_at_10: 0.1350 - mrr_at_10: 0.0610 - ndcg_at_10: 0.0782 - map_at_10: 0.0610 - precision_at_10: 0.0135 - regularization_loss: 0.0000e+00 - loss_batch: 6.0187 - val_loss: 7.3252 - val_auc_52: 0.5671 - val_recall_at_10: 0.0207 - val_mrr_at_10: 0.0057 - val_ndcg_at_10: 0.0091 - val_map_at_10: 0.0057 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6084
# Epoch 123/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.0295 - auc_52: 0.5888 - recall_at_10: 0.1333 - mrr_at_10: 0.0599 - ndcg_at_10: 0.0769 - map_at_10: 0.0599 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0129 - val_loss: 7.3049 - val_auc_52: 0.5655 - val_recall_at_10: 0.0211 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0097 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6078
# Epoch 124/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0364 - auc_52: 0.5868 - recall_at_10: 0.1319 - mrr_at_10: 0.0591 - ndcg_at_10: 0.0760 - map_at_10: 0.0591 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0199 - val_loss: 7.2835 - val_auc_52: 0.5632 - val_recall_at_10: 0.0213 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5688
# Epoch 125/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0295 - auc_52: 0.5867 - recall_at_10: 0.1329 - mrr_at_10: 0.0595 - ndcg_at_10: 0.0766 - map_at_10: 0.0595 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0129 - val_loss: 7.2910 - val_auc_52: 0.5616 - val_recall_at_10: 0.0223 - val_mrr_at_10: 0.0062 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0062 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5527
# Epoch 126/150
# 69/69 [==============================] - 3s 39ms/step - loss: 6.0313 - auc_52: 0.5852 - recall_at_10: 0.1337 - mrr_at_10: 0.0601 - ndcg_at_10: 0.0772 - map_at_10: 0.0601 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0145 - val_loss: 7.3241 - val_auc_52: 0.5597 - val_recall_at_10: 0.0233 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0105 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.7797
# Epoch 127/150
# 69/69 [==============================] - 4s 39ms/step - loss: 6.0301 - auc_52: 0.5824 - recall_at_10: 0.1324 - mrr_at_10: 0.0591 - ndcg_at_10: 0.0761 - map_at_10: 0.0591 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0137 - val_loss: 7.2997 - val_auc_52: 0.5653 - val_recall_at_10: 0.0227 - val_mrr_at_10: 0.0068 - val_ndcg_at_10: 0.0105 - val_map_at_10: 0.0068 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5910
# Epoch 128/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0319 - auc_52: 0.5835 - recall_at_10: 0.1333 - mrr_at_10: 0.0598 - ndcg_at_10: 0.0769 - map_at_10: 0.0598 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0155 - val_loss: 7.2828 - val_auc_52: 0.5581 - val_recall_at_10: 0.0217 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0098 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6386
# Epoch 129/150
# 69/69 [==============================] - 3s 33ms/step - loss: 6.0336 - auc_52: 0.5796 - recall_at_10: 0.1317 - mrr_at_10: 0.0587 - ndcg_at_10: 0.0757 - map_at_10: 0.0587 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0171 - val_loss: 7.2952 - val_auc_52: 0.5586 - val_recall_at_10: 0.0237 - val_mrr_at_10: 0.0067 - val_ndcg_at_10: 0.0106 - val_map_at_10: 0.0067 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6747
# Epoch 130/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0327 - auc_52: 0.5787 - recall_at_10: 0.1315 - mrr_at_10: 0.0597 - ndcg_at_10: 0.0764 - map_at_10: 0.0597 - precision_at_10: 0.0131 - regularization_loss: 0.0000e+00 - loss_batch: 6.0168 - val_loss: 7.2827 - val_auc_52: 0.5627 - val_recall_at_10: 0.0230 - val_mrr_at_10: 0.0071 - val_ndcg_at_10: 0.0107 - val_map_at_10: 0.0071 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5856
# Epoch 131/150
# 69/69 [==============================] - 4s 44ms/step - loss: 6.0302 - auc_52: 0.5799 - recall_at_10: 0.1344 - mrr_at_10: 0.0598 - ndcg_at_10: 0.0771 - map_at_10: 0.0598 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0136 - val_loss: 7.3000 - val_auc_52: 0.5600 - val_recall_at_10: 0.0225 - val_mrr_at_10: 0.0058 - val_ndcg_at_10: 0.0096 - val_map_at_10: 0.0058 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5127
# Epoch 132/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0307 - auc_52: 0.5784 - recall_at_10: 0.1324 - mrr_at_10: 0.0582 - ndcg_at_10: 0.0754 - map_at_10: 0.0582 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0138 - val_loss: 7.3199 - val_auc_52: 0.5599 - val_recall_at_10: 0.0228 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0103 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6832
# Epoch 133/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0304 - auc_52: 0.5765 - recall_at_10: 0.1348 - mrr_at_10: 0.0603 - ndcg_at_10: 0.0776 - map_at_10: 0.0603 - precision_at_10: 0.0135 - regularization_loss: 0.0000e+00 - loss_batch: 6.0135 - val_loss: 7.2718 - val_auc_52: 0.5605 - val_recall_at_10: 0.0216 - val_mrr_at_10: 0.0071 - val_ndcg_at_10: 0.0104 - val_map_at_10: 0.0071 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6053
# Epoch 134/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0313 - auc_52: 0.5745 - recall_at_10: 0.1353 - mrr_at_10: 0.0603 - ndcg_at_10: 0.0777 - map_at_10: 0.0603 - precision_at_10: 0.0135 - regularization_loss: 0.0000e+00 - loss_batch: 6.0149 - val_loss: 7.3142 - val_auc_52: 0.5589 - val_recall_at_10: 0.0209 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0096 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5583
# Epoch 135/150
# 69/69 [==============================] - 3s 38ms/step - loss: 6.0300 - auc_52: 0.5756 - recall_at_10: 0.1324 - mrr_at_10: 0.0595 - ndcg_at_10: 0.0764 - map_at_10: 0.0595 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0133 - val_loss: 7.2845 - val_auc_52: 0.5554 - val_recall_at_10: 0.0220 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0101 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5406
# Epoch 136/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0279 - auc_52: 0.5733 - recall_at_10: 0.1354 - mrr_at_10: 0.0600 - ndcg_at_10: 0.0775 - map_at_10: 0.0600 - precision_at_10: 0.0135 - regularization_loss: 0.0000e+00 - loss_batch: 6.0113 - val_loss: 7.3713 - val_auc_52: 0.5560 - val_recall_at_10: 0.0189 - val_mrr_at_10: 0.0052 - val_ndcg_at_10: 0.0083 - val_map_at_10: 0.0052 - val_precision_at_10: 0.0019 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5959
# Epoch 137/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0291 - auc_52: 0.5709 - recall_at_10: 0.1327 - mrr_at_10: 0.0581 - ndcg_at_10: 0.0754 - map_at_10: 0.0581 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0130 - val_loss: 7.2736 - val_auc_52: 0.5540 - val_recall_at_10: 0.0199 - val_mrr_at_10: 0.0058 - val_ndcg_at_10: 0.0090 - val_map_at_10: 0.0058 - val_precision_at_10: 0.0020 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5152
# Epoch 138/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0290 - auc_52: 0.5732 - recall_at_10: 0.1344 - mrr_at_10: 0.0612 - ndcg_at_10: 0.0782 - map_at_10: 0.0612 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0123 - val_loss: 7.2454 - val_auc_52: 0.5477 - val_recall_at_10: 0.0229 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0108 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5162
# Epoch 139/150
# 69/69 [==============================] - 3s 38ms/step - loss: 6.0263 - auc_52: 0.5715 - recall_at_10: 0.1323 - mrr_at_10: 0.0588 - ndcg_at_10: 0.0759 - map_at_10: 0.0588 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0099 - val_loss: 7.2692 - val_auc_52: 0.5500 - val_recall_at_10: 0.0238 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0104 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5864
# Epoch 140/150
# 69/69 [==============================] - 4s 45ms/step - loss: 6.0290 - auc_52: 0.5696 - recall_at_10: 0.1339 - mrr_at_10: 0.0599 - ndcg_at_10: 0.0771 - map_at_10: 0.0599 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0122 - val_loss: 7.3590 - val_auc_52: 0.5532 - val_recall_at_10: 0.0230 - val_mrr_at_10: 0.0057 - val_ndcg_at_10: 0.0097 - val_map_at_10: 0.0057 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.7524
# Epoch 141/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0289 - auc_52: 0.5678 - recall_at_10: 0.1345 - mrr_at_10: 0.0614 - ndcg_at_10: 0.0784 - map_at_10: 0.0614 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0117 - val_loss: 7.3103 - val_auc_52: 0.5525 - val_recall_at_10: 0.0236 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0104 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5905
# Epoch 142/150
# 69/69 [==============================] - 3s 31ms/step - loss: 6.0273 - auc_52: 0.5682 - recall_at_10: 0.1325 - mrr_at_10: 0.0579 - ndcg_at_10: 0.0752 - map_at_10: 0.0579 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0108 - val_loss: 7.3216 - val_auc_52: 0.5499 - val_recall_at_10: 0.0230 - val_mrr_at_10: 0.0062 - val_ndcg_at_10: 0.0101 - val_map_at_10: 0.0062 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6970
# Epoch 143/150
# 69/69 [==============================] - 3s 30ms/step - loss: 6.0279 - auc_52: 0.5667 - recall_at_10: 0.1328 - mrr_at_10: 0.0597 - ndcg_at_10: 0.0767 - map_at_10: 0.0597 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0113 - val_loss: 7.2741 - val_auc_52: 0.5494 - val_recall_at_10: 0.0223 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6364
# Epoch 144/150
# 69/69 [==============================] - 3s 42ms/step - loss: 6.0265 - auc_52: 0.5664 - recall_at_10: 0.1331 - mrr_at_10: 0.0597 - ndcg_at_10: 0.0768 - map_at_10: 0.0597 - precision_at_10: 0.0133 - regularization_loss: 0.0000e+00 - loss_batch: 6.0105 - val_loss: 7.3319 - val_auc_52: 0.5511 - val_recall_at_10: 0.0215 - val_mrr_at_10: 0.0061 - val_ndcg_at_10: 0.0096 - val_map_at_10: 0.0061 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6589
# Epoch 145/150
# 69/69 [==============================] - 4s 44ms/step - loss: 6.0265 - auc_52: 0.5665 - recall_at_10: 0.1337 - mrr_at_10: 0.0601 - ndcg_at_10: 0.0772 - map_at_10: 0.0601 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0092 - val_loss: 7.3375 - val_auc_52: 0.5513 - val_recall_at_10: 0.0230 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0103 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6818
# Epoch 146/150
# 69/69 [==============================] - 3s 32ms/step - loss: 6.0279 - auc_52: 0.5629 - recall_at_10: 0.1338 - mrr_at_10: 0.0596 - ndcg_at_10: 0.0768 - map_at_10: 0.0596 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0109 - val_loss: 7.3572 - val_auc_52: 0.5493 - val_recall_at_10: 0.0217 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.7152
# Epoch 147/150
# 69/69 [==============================] - 3s 29ms/step - loss: 6.0268 - auc_52: 0.5619 - recall_at_10: 0.1339 - mrr_at_10: 0.0600 - ndcg_at_10: 0.0772 - map_at_10: 0.0600 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0099 - val_loss: 7.3099 - val_auc_52: 0.5462 - val_recall_at_10: 0.0210 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0096 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0021 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.5665
# Epoch 148/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0227 - auc_52: 0.5632 - recall_at_10: 0.1322 - mrr_at_10: 0.0589 - ndcg_at_10: 0.0759 - map_at_10: 0.0589 - precision_at_10: 0.0132 - regularization_loss: 0.0000e+00 - loss_batch: 6.0059 - val_loss: 7.2934 - val_auc_52: 0.5450 - val_recall_at_10: 0.0226 - val_mrr_at_10: 0.0060 - val_ndcg_at_10: 0.0097 - val_map_at_10: 0.0060 - val_precision_at_10: 0.0023 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6250
# Epoch 149/150
# 69/69 [==============================] - 2s 29ms/step - loss: 6.0238 - auc_52: 0.5607 - recall_at_10: 0.1351 - mrr_at_10: 0.0598 - ndcg_at_10: 0.0773 - map_at_10: 0.0598 - precision_at_10: 0.0135 - regularization_loss: 0.0000e+00 - loss_batch: 6.0072 - val_loss: 7.2978 - val_auc_52: 0.5501 - val_recall_at_10: 0.0239 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0105 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0024 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6702
# Epoch 150/150
# 69/69 [==============================] - 4s 42ms/step - loss: 6.0217 - auc_52: 0.5599 - recall_at_10: 0.1344 - mrr_at_10: 0.0609 - ndcg_at_10: 0.0780 - map_at_10: 0.0609 - precision_at_10: 0.0134 - regularization_loss: 0.0000e+00 - loss_batch: 6.0051 - val_loss: 7.3208 - val_auc_52: 0.5411 - val_recall_at_10: 0.0219 - val_mrr_at_10: 0.0056 - val_ndcg_at_10: 0.0093 - val_map_at_10: 0.0056 - val_precision_at_10: 0.0022 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.6875

# %% [markdown]
# #### eval

# %%
(model_v4.evaluate(train, batch_size=2048, return_dict=True),
 model_v4.evaluate(valid, batch_size=2048, return_dict=True))
# Out:
# 35/35 [==============================] - 2s 42ms/step - loss: 6.6276 - auc_52: 0.5553 - recall_at_10: 0.1026 - mrr_at_10: 0.0487 - ndcg_at_10: 0.0612 - map_at_10: 0.0487 - precision_at_10: 0.0103 - regularization_loss: 0.0000e+00 - loss_batch: 6.5568
# 8/8 [==============================] - 0s 34ms/step - loss: 7.9884 - auc_52: 0.5406 - recall_at_10: 0.0186 - mrr_at_10: 0.0142 - ndcg_at_10: 0.0152 - map_at_10: 0.0142 - precision_at_10: 0.0019 - regularization_loss: 0.0000e+00 - loss_batch: 7.9317
# ({'loss': 6.627641201019287,
#   'auc_52': 0.555304229259491,
#   'recall_at_10': 0.10324492305517197,
#   'mrr_at_10': 0.04888755455613136,
#   'ndcg_at_10': 0.061546050012111664,
#   'map_at_10': 0.04888755455613136,
#   'precision_at_10': 0.010324492119252682,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.146157741546631},
#  {'loss': 7.988430976867676,
#   'auc_52': 0.5405987501144409,
#   'recall_at_10': 0.017319779843091965,
#   'mrr_at_10': 0.01136185321956873,
#   'ndcg_at_10': 0.012676406651735306,
#   'map_at_10': 0.01136185321956873,
#   'precision_at_10': 0.0017319780308753252,
#   'regularization_loss': 0.0,
#   'loss_batch': 7.687519073486328})

# %%
evaluate_model(model_v4, train, topk=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-70f2d7b895a0> in <cell line: 1>()
# ----> 1 evaluate_model(model_v4, train, topk=100)
#
# NameError: name 'model_v4' is not defined

# %%
evaluate_model(model_v4, valid, topk=100)
# Out:
# Candidate set rows: 1338
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:absl:Found untraced functions such as prepare_list_features_157_layer_call_fn, prepare_list_features_157_layer_call_and_return_conditional_losses, model_context_8_layer_call_fn, model_context_8_layer_call_and_return_conditional_losses, concat_features_17_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 15/15 [==============================] - 4s 27ms/step - loss: 1.0925 - auc_54: 0.5072 - recall_at_100: 0.2049 - mrr_at_100: 0.0061 - ndcg_at_100: 0.0383 - map_at_100: 0.0061 - precision_at_100: 0.0020 - regularization_loss: 0.0000e+00 - loss_batch: 1.1328
# {'loss': 1.0925264358520508,
#  'auc_54': 0.5072149038314819,
#  'recall_at_100': 0.20884044468402863,
#  'mrr_at_100': 0.006274878513067961,
#  'ndcg_at_100': 0.03909923881292343,
#  'map_at_100': 0.006274878513067961,
#  'precision_at_100': 0.002088404493406415,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.5543676614761353}

# %% [markdown]
# #### analysis

# %%
_history = merge_model_history(*history_v4)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM})

# %% [markdown]
# ### model_v5

# %%
# _tower_dim = (64, 128) # @param
# _tower_dim = (128, 64) # @param
_tower_dim = (512, 256) # @param

_learning_rate = 0.01 # @param
# _batch_size = 4096 # @param
_batch_size = 1024 # @param
_epochs = 30 # @param
_validation_batch_size = 256 # @param

# %%
model_v5 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [10]
model_v5.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)
history_v5 = []

# %% [markdown]
# #### model

# %%
history_v5.append(
    model_v5.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size)
)
# Out:
# Epoch 1/30
# 69/69 [==============================] - 26s 279ms/step - loss: 6.8447 - auc_4: 0.5744 - recall_at_10: 0.0150 - mrr_at_10: 0.0049 - ndcg_at_10: 0.0072 - map_at_10: 0.0049 - precision_at_10: 0.0015 - regularization_loss: 0.0000e+00 - loss_batch: 6.8296 - val_loss: 6.7845 - val_auc_4: 0.6042 - val_recall_at_10: 0.0262 - val_mrr_at_10: 0.0091 - val_ndcg_at_10: 0.0130 - val_map_at_10: 0.0091 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5229
# Epoch 2/30
# 69/69 [==============================] - 6s 75ms/step - loss: 6.5611 - auc_4: 0.6326 - recall_at_10: 0.0371 - mrr_at_10: 0.0125 - ndcg_at_10: 0.0182 - map_at_10: 0.0125 - precision_at_10: 0.0037 - regularization_loss: 0.0000e+00 - loss_batch: 6.5481 - val_loss: 6.7242 - val_auc_4: 0.5866 - val_recall_at_10: 0.0320 - val_mrr_at_10: 0.0108 - val_ndcg_at_10: 0.0156 - val_map_at_10: 0.0108 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.2339
# Epoch 3/30
# 69/69 [==============================] - 6s 80ms/step - loss: 6.4728 - auc_4: 0.6387 - recall_at_10: 0.0513 - mrr_at_10: 0.0185 - ndcg_at_10: 0.0261 - map_at_10: 0.0185 - precision_at_10: 0.0051 - regularization_loss: 0.0000e+00 - loss_batch: 6.4600 - val_loss: 6.6728 - val_auc_4: 0.5964 - val_recall_at_10: 0.0356 - val_mrr_at_10: 0.0119 - val_ndcg_at_10: 0.0173 - val_map_at_10: 0.0119 - val_precision_at_10: 0.0036 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.2727
# Epoch 4/30
# 69/69 [==============================] - 4s 50ms/step - loss: 6.4181 - auc_4: 0.6481 - recall_at_10: 0.0600 - mrr_at_10: 0.0213 - ndcg_at_10: 0.0302 - map_at_10: 0.0213 - precision_at_10: 0.0060 - regularization_loss: 0.0000e+00 - loss_batch: 6.4052 - val_loss: 6.6972 - val_auc_4: 0.5828 - val_recall_at_10: 0.0366 - val_mrr_at_10: 0.0125 - val_ndcg_at_10: 0.0180 - val_map_at_10: 0.0125 - val_precision_at_10: 0.0037 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.3307
# Epoch 5/30
# 69/69 [==============================] - 3s 40ms/step - loss: 6.3790 - auc_4: 0.6506 - recall_at_10: 0.0690 - mrr_at_10: 0.0257 - ndcg_at_10: 0.0356 - map_at_10: 0.0257 - precision_at_10: 0.0069 - regularization_loss: 0.0000e+00 - loss_batch: 6.3659 - val_loss: 6.7323 - val_auc_4: 0.5956 - val_recall_at_10: 0.0356 - val_mrr_at_10: 0.0119 - val_ndcg_at_10: 0.0173 - val_map_at_10: 0.0119 - val_precision_at_10: 0.0036 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4718
# Epoch 6/30
# 69/69 [==============================] - 5s 57ms/step - loss: 6.3527 - auc_4: 0.6631 - recall_at_10: 0.0742 - mrr_at_10: 0.0284 - ndcg_at_10: 0.0389 - map_at_10: 0.0284 - precision_at_10: 0.0074 - regularization_loss: 0.0000e+00 - loss_batch: 6.3397 - val_loss: 6.7243 - val_auc_4: 0.5736 - val_recall_at_10: 0.0354 - val_mrr_at_10: 0.0122 - val_ndcg_at_10: 0.0175 - val_map_at_10: 0.0122 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4015
# Epoch 7/30
# 69/69 [==============================] - 3s 36ms/step - loss: 6.3297 - auc_4: 0.6617 - recall_at_10: 0.0770 - mrr_at_10: 0.0302 - ndcg_at_10: 0.0410 - map_at_10: 0.0302 - precision_at_10: 0.0077 - regularization_loss: 0.0000e+00 - loss_batch: 6.3164 - val_loss: 6.7277 - val_auc_4: 0.5736 - val_recall_at_10: 0.0368 - val_mrr_at_10: 0.0124 - val_ndcg_at_10: 0.0180 - val_map_at_10: 0.0124 - val_precision_at_10: 0.0037 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4439
# Epoch 8/30
# 69/69 [==============================] - 3s 34ms/step - loss: 6.3137 - auc_4: 0.6631 - recall_at_10: 0.0794 - mrr_at_10: 0.0314 - ndcg_at_10: 0.0425 - map_at_10: 0.0314 - precision_at_10: 0.0079 - regularization_loss: 0.0000e+00 - loss_batch: 6.3009 - val_loss: 6.7531 - val_auc_4: 0.5889 - val_recall_at_10: 0.0374 - val_mrr_at_10: 0.0118 - val_ndcg_at_10: 0.0176 - val_map_at_10: 0.0118 - val_precision_at_10: 0.0037 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.5387
# Epoch 9/30
# 69/69 [==============================] - 3s 32ms/step - loss: 6.2982 - auc_4: 0.6677 - recall_at_10: 0.0821 - mrr_at_10: 0.0333 - ndcg_at_10: 0.0446 - map_at_10: 0.0333 - precision_at_10: 0.0082 - regularization_loss: 0.0000e+00 - loss_batch: 6.2846 - val_loss: 6.7631 - val_auc_4: 0.5852 - val_recall_at_10: 0.0352 - val_mrr_at_10: 0.0120 - val_ndcg_at_10: 0.0173 - val_map_at_10: 0.0120 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.4990
# Epoch 10/30
# 69/69 [==============================] - 4s 47ms/step - loss: 6.2833 - auc_4: 0.6613 - recall_at_10: 0.0843 - mrr_at_10: 0.0342 - ndcg_at_10: 0.0458 - map_at_10: 0.0342 - precision_at_10: 0.0084 - regularization_loss: 0.0000e+00 - loss_batch: 6.2701 - val_loss: 6.7649 - val_auc_4: 0.5907 - val_recall_at_10: 0.0341 - val_mrr_at_10: 0.0115 - val_ndcg_at_10: 0.0166 - val_map_at_10: 0.0115 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.6363
# Epoch 11/30
# 69/69 [==============================] - 4s 42ms/step - loss: 6.2741 - auc_4: 0.6650 - recall_at_10: 0.0867 - mrr_at_10: 0.0346 - ndcg_at_10: 0.0466 - map_at_10: 0.0346 - precision_at_10: 0.0087 - regularization_loss: 0.0000e+00 - loss_batch: 6.2606 - val_loss: 6.7954 - val_auc_4: 0.5705 - val_recall_at_10: 0.0329 - val_mrr_at_10: 0.0109 - val_ndcg_at_10: 0.0159 - val_map_at_10: 0.0109 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.6326
# Epoch 12/30
# 69/69 [==============================] - 3s 37ms/step - loss: 6.2642 - auc_4: 0.6625 - recall_at_10: 0.0893 - mrr_at_10: 0.0365 - ndcg_at_10: 0.0487 - map_at_10: 0.0365 - precision_at_10: 0.0089 - regularization_loss: 0.0000e+00 - loss_batch: 6.2511 - val_loss: 6.8296 - val_auc_4: 0.5842 - val_recall_at_10: 0.0341 - val_mrr_at_10: 0.0109 - val_ndcg_at_10: 0.0162 - val_map_at_10: 0.0109 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7067
# Epoch 13/30
# 69/69 [==============================] - 3s 30ms/step - loss: 6.2511 - auc_4: 0.6609 - recall_at_10: 0.0924 - mrr_at_10: 0.0378 - ndcg_at_10: 0.0504 - map_at_10: 0.0378 - precision_at_10: 0.0092 - regularization_loss: 0.0000e+00 - loss_batch: 6.2374 - val_loss: 6.8696 - val_auc_4: 0.5746 - val_recall_at_10: 0.0341 - val_mrr_at_10: 0.0113 - val_ndcg_at_10: 0.0165 - val_map_at_10: 0.0113 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7597
# Epoch 14/30
# 69/69 [==============================] - 3s 32ms/step - loss: 6.2420 - auc_4: 0.6644 - recall_at_10: 0.0923 - mrr_at_10: 0.0383 - ndcg_at_10: 0.0508 - map_at_10: 0.0383 - precision_at_10: 0.0092 - regularization_loss: 0.0000e+00 - loss_batch: 6.2283 - val_loss: 6.8758 - val_auc_4: 0.5944 - val_recall_at_10: 0.0345 - val_mrr_at_10: 0.0111 - val_ndcg_at_10: 0.0164 - val_map_at_10: 0.0111 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7377
# Epoch 15/30
# 69/69 [==============================] - 5s 54ms/step - loss: 6.2327 - auc_4: 0.6564 - recall_at_10: 0.0970 - mrr_at_10: 0.0408 - ndcg_at_10: 0.0538 - map_at_10: 0.0408 - precision_at_10: 0.0097 - regularization_loss: 0.0000e+00 - loss_batch: 6.2194 - val_loss: 6.8636 - val_auc_4: 0.5882 - val_recall_at_10: 0.0344 - val_mrr_at_10: 0.0120 - val_ndcg_at_10: 0.0172 - val_map_at_10: 0.0120 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.6591
# Epoch 16/30
# 69/69 [==============================] - 3s 32ms/step - loss: 6.2235 - auc_4: 0.6626 - recall_at_10: 0.0958 - mrr_at_10: 0.0405 - ndcg_at_10: 0.0533 - map_at_10: 0.0405 - precision_at_10: 0.0096 - regularization_loss: 0.0000e+00 - loss_batch: 6.2105 - val_loss: 6.8689 - val_auc_4: 0.5895 - val_recall_at_10: 0.0319 - val_mrr_at_10: 0.0100 - val_ndcg_at_10: 0.0150 - val_map_at_10: 0.0100 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7239
# Epoch 17/30
# 69/69 [==============================] - 2s 27ms/step - loss: 6.2191 - auc_4: 0.6563 - recall_at_10: 0.0991 - mrr_at_10: 0.0417 - ndcg_at_10: 0.0550 - map_at_10: 0.0417 - precision_at_10: 0.0099 - regularization_loss: 0.0000e+00 - loss_batch: 6.2058 - val_loss: 6.8875 - val_auc_4: 0.5894 - val_recall_at_10: 0.0336 - val_mrr_at_10: 0.0113 - val_ndcg_at_10: 0.0164 - val_map_at_10: 0.0113 - val_precision_at_10: 0.0034 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8706
# Epoch 18/30
# 69/69 [==============================] - 3s 29ms/step - loss: 6.2132 - auc_4: 0.6538 - recall_at_10: 0.0978 - mrr_at_10: 0.0407 - ndcg_at_10: 0.0539 - map_at_10: 0.0407 - precision_at_10: 0.0098 - regularization_loss: 0.0000e+00 - loss_batch: 6.1992 - val_loss: 6.8817 - val_auc_4: 0.5866 - val_recall_at_10: 0.0349 - val_mrr_at_10: 0.0110 - val_ndcg_at_10: 0.0165 - val_map_at_10: 0.0110 - val_precision_at_10: 0.0035 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8689
# Epoch 19/30
# 69/69 [==============================] - 2s 28ms/step - loss: 6.2051 - auc_4: 0.6578 - recall_at_10: 0.1000 - mrr_at_10: 0.0419 - ndcg_at_10: 0.0554 - map_at_10: 0.0419 - precision_at_10: 0.0100 - regularization_loss: 0.0000e+00 - loss_batch: 6.1909 - val_loss: 6.9027 - val_auc_4: 0.5804 - val_recall_at_10: 0.0325 - val_mrr_at_10: 0.0109 - val_ndcg_at_10: 0.0158 - val_map_at_10: 0.0109 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.7766
# Epoch 20/30
# 69/69 [==============================] - 3s 43ms/step - loss: 6.1980 - auc_4: 0.6614 - recall_at_10: 0.1015 - mrr_at_10: 0.0426 - ndcg_at_10: 0.0562 - map_at_10: 0.0426 - precision_at_10: 0.0102 - regularization_loss: 0.0000e+00 - loss_batch: 6.1836 - val_loss: 6.9184 - val_auc_4: 0.5842 - val_recall_at_10: 0.0324 - val_mrr_at_10: 0.0105 - val_ndcg_at_10: 0.0155 - val_map_at_10: 0.0105 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9007
# Epoch 21/30
# 69/69 [==============================] - 4s 39ms/step - loss: 6.1941 - auc_4: 0.6588 - recall_at_10: 0.1021 - mrr_at_10: 0.0441 - ndcg_at_10: 0.0576 - map_at_10: 0.0441 - precision_at_10: 0.0102 - regularization_loss: 0.0000e+00 - loss_batch: 6.1801 - val_loss: 6.8664 - val_auc_4: 0.5960 - val_recall_at_10: 0.0326 - val_mrr_at_10: 0.0110 - val_ndcg_at_10: 0.0159 - val_map_at_10: 0.0110 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8028
# Epoch 22/30
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1871 - auc_4: 0.6622 - recall_at_10: 0.1045 - mrr_at_10: 0.0449 - ndcg_at_10: 0.0587 - map_at_10: 0.0449 - precision_at_10: 0.0105 - regularization_loss: 0.0000e+00 - loss_batch: 6.1736 - val_loss: 6.8974 - val_auc_4: 0.5869 - val_recall_at_10: 0.0326 - val_mrr_at_10: 0.0105 - val_ndcg_at_10: 0.0156 - val_map_at_10: 0.0105 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.8490
# Epoch 23/30
# 69/69 [==============================] - 3s 33ms/step - loss: 6.1833 - auc_4: 0.6619 - recall_at_10: 0.1050 - mrr_at_10: 0.0449 - ndcg_at_10: 0.0588 - map_at_10: 0.0449 - precision_at_10: 0.0105 - regularization_loss: 0.0000e+00 - loss_batch: 6.1692 - val_loss: 6.9041 - val_auc_4: 0.5968 - val_recall_at_10: 0.0326 - val_mrr_at_10: 0.0112 - val_ndcg_at_10: 0.0162 - val_map_at_10: 0.0112 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9549
# Epoch 24/30
# 69/69 [==============================] - 2s 27ms/step - loss: 6.1784 - auc_4: 0.6558 - recall_at_10: 0.1069 - mrr_at_10: 0.0455 - ndcg_at_10: 0.0597 - map_at_10: 0.0455 - precision_at_10: 0.0107 - regularization_loss: 0.0000e+00 - loss_batch: 6.1646 - val_loss: 6.9072 - val_auc_4: 0.5781 - val_recall_at_10: 0.0329 - val_mrr_at_10: 0.0108 - val_ndcg_at_10: 0.0159 - val_map_at_10: 0.0108 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9297
# Epoch 25/30
# 69/69 [==============================] - 3s 41ms/step - loss: 6.1717 - auc_4: 0.6579 - recall_at_10: 0.1070 - mrr_at_10: 0.0458 - ndcg_at_10: 0.0600 - map_at_10: 0.0458 - precision_at_10: 0.0107 - regularization_loss: 0.0000e+00 - loss_batch: 6.1579 - val_loss: 6.9576 - val_auc_4: 0.5820 - val_recall_at_10: 0.0302 - val_mrr_at_10: 0.0094 - val_ndcg_at_10: 0.0142 - val_map_at_10: 0.0094 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9966
# Epoch 26/30
# 69/69 [==============================] - 3s 31ms/step - loss: 6.1700 - auc_4: 0.6604 - recall_at_10: 0.1065 - mrr_at_10: 0.0462 - ndcg_at_10: 0.0602 - map_at_10: 0.0462 - precision_at_10: 0.0107 - regularization_loss: 0.0000e+00 - loss_batch: 6.1556 - val_loss: 6.9488 - val_auc_4: 0.5871 - val_recall_at_10: 0.0301 - val_mrr_at_10: 0.0094 - val_ndcg_at_10: 0.0141 - val_map_at_10: 0.0094 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 6.9601
# Epoch 27/30
# 69/69 [==============================] - 2s 29ms/step - loss: 6.1639 - auc_4: 0.6621 - recall_at_10: 0.1063 - mrr_at_10: 0.0451 - ndcg_at_10: 0.0593 - map_at_10: 0.0451 - precision_at_10: 0.0106 - regularization_loss: 0.0000e+00 - loss_batch: 6.1496 - val_loss: 6.9596 - val_auc_4: 0.5902 - val_recall_at_10: 0.0322 - val_mrr_at_10: 0.0104 - val_ndcg_at_10: 0.0154 - val_map_at_10: 0.0104 - val_precision_at_10: 0.0032 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0359
# Epoch 28/30
# 69/69 [==============================] - 3s 34ms/step - loss: 6.1683 - auc_4: 0.6615 - recall_at_10: 0.1096 - mrr_at_10: 0.0474 - ndcg_at_10: 0.0618 - map_at_10: 0.0474 - precision_at_10: 0.0110 - regularization_loss: 0.0000e+00 - loss_batch: 6.1535 - val_loss: 6.9650 - val_auc_4: 0.5829 - val_recall_at_10: 0.0280 - val_mrr_at_10: 0.0095 - val_ndcg_at_10: 0.0137 - val_map_at_10: 0.0095 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0731
# Epoch 29/30
# 69/69 [==============================] - 2s 25ms/step - loss: 6.1599 - auc_4: 0.6569 - recall_at_10: 0.1100 - mrr_at_10: 0.0469 - ndcg_at_10: 0.0615 - map_at_10: 0.0469 - precision_at_10: 0.0110 - regularization_loss: 0.0000e+00 - loss_batch: 6.1460 - val_loss: 6.9667 - val_auc_4: 0.5915 - val_recall_at_10: 0.0301 - val_mrr_at_10: 0.0101 - val_ndcg_at_10: 0.0147 - val_map_at_10: 0.0101 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0912
# Epoch 30/30
# 69/69 [==============================] - 3s 42ms/step - loss: 6.1583 - auc_4: 0.6563 - recall_at_10: 0.1082 - mrr_at_10: 0.0474 - ndcg_at_10: 0.0615 - map_at_10: 0.0474 - precision_at_10: 0.0108 - regularization_loss: 0.0000e+00 - loss_batch: 6.1439 - val_loss: 6.9491 - val_auc_4: 0.5853 - val_recall_at_10: 0.0329 - val_mrr_at_10: 0.0101 - val_ndcg_at_10: 0.0153 - val_map_at_10: 0.0101 - val_precision_at_10: 0.0033 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0115

# %% [markdown]
# #### eval

# %%
(model_v5.evaluate(train, batch_size=2048, return_dict=True),
 model_v5.evaluate(valid, batch_size=2048, return_dict=True))
# Out:
# 35/35 [==============================] - 2s 44ms/step - loss: 6.7675 - auc_4: 0.6611 - recall_at_10: 0.0842 - mrr_at_10: 0.0385 - ndcg_at_10: 0.0492 - map_at_10: 0.0385 - precision_at_10: 0.0084 - regularization_loss: 0.0000e+00 - loss_batch: 6.7019
# 8/8 [==============================] - 1s 42ms/step - loss: 7.6214 - auc_4: 0.5804 - recall_at_10: 0.0230 - mrr_at_10: 0.0166 - ndcg_at_10: 0.0181 - map_at_10: 0.0166 - precision_at_10: 0.0023 - regularization_loss: 0.0000e+00 - loss_batch: 7.5063
# ({'loss': 6.76745080947876,
#   'auc_4': 0.6611053943634033,
#   'recall_at_10': 0.08363009244203568,
#   'mrr_at_10': 0.0377124547958374,
#   'ndcg_at_10': 0.048381153494119644,
#   'map_at_10': 0.0377124547958374,
#   'precision_at_10': 0.008363010361790657,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.3958516120910645},
#  {'loss': 7.621395587921143,
#   'auc_4': 0.5803676247596741,
#   'recall_at_10': 0.023672595620155334,
#   'mrr_at_10': 0.014991900883615017,
#   'ndcg_at_10': 0.016968190670013428,
#   'map_at_10': 0.014991900883615017,
#   'precision_at_10': 0.0023672599345445633,
#   'regularization_loss': 0.0,
#   'loss_batch': 7.011460304260254})

# %%
evaluate_model(model_v5, train, topk=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1561
# WARNING:absl:Found untraced functions such as prepare_list_features_13_layer_call_fn, prepare_list_features_13_layer_call_and_return_conditional_losses, model_context_2_layer_call_fn, model_context_2_layer_call_and_return_conditional_losses, concat_features_5_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 69/69 [==============================] - 3s 16ms/step - loss: 1.7575 - auc_7: 0.5122 - recall_at_100: 0.3747 - mrr_at_100: 0.0275 - ndcg_at_100: 0.0872 - map_at_100: 0.0275 - precision_at_100: 0.0037 - regularization_loss: 0.0000e+00 - loss_batch: 1.7606
# {'loss': 1.757527232170105,
#  'auc_7': 0.5121540427207947,
#  'recall_at_100': 0.3728383779525757,
#  'mrr_at_100': 0.02756620943546295,
#  'ndcg_at_100': 0.08687572181224823,
#  'map_at_100': 0.02756620943546295,
#  'precision_at_100': 0.0037283841520547867,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.9061037302017212}

# %%
evaluate_model(model_v5, valid, topk=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1338
# WARNING:absl:Found untraced functions such as prepare_list_features_13_layer_call_fn, prepare_list_features_13_layer_call_and_return_conditional_losses, model_context_2_layer_call_fn, model_context_2_layer_call_and_return_conditional_losses, concat_features_5_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 15/15 [==============================] - 2s 20ms/step - loss: 1.0129 - auc_6: 0.5081 - recall_at_100: 0.1971 - mrr_at_100: 0.0069 - ndcg_at_100: 0.0380 - map_at_100: 0.0069 - precision_at_100: 0.0020 - regularization_loss: 0.0000e+00 - loss_batch: 1.0707
# {'loss': 1.0129497051239014,
#  'auc_6': 0.5081184506416321,
#  'recall_at_100': 0.20462752878665924,
#  'mrr_at_100': 0.007491062395274639,
#  'ndcg_at_100': 0.039819762110710144,
#  'map_at_100': 0.007491062395274639,
#  'precision_at_100': 0.002046275185421109,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.6741816997528076}

# %% [markdown]
# #### analysis

# %%
_history = merge_model_history(*history_v5)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM})

# %% [markdown]
# ### model_v6

# %%
# _tower_dim = (64, 128) # @param
# _tower_dim = (128, 64) # @param
_tower_dim = (64, 64) # @param

_learning_rate = 0.01 # @param
# _batch_size = 4096 # @param
_batch_size = 1024 # @param
_epochs = 30 # @param
_validation_batch_size = 256 # @param

# %%
model_v6 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [100, 10]
model_v6.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)
history_v6 = []

# %% [markdown]
# #### model

# %%
history_v6.append(
    model_v6.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size)
)
# Out:
# Epoch 1/30
# 69/69 [==============================] - 5s 61ms/step - loss: 6.1435 - auc: 0.7201 - recall_at_100: 0.4348 - mrr_at_100: 0.0585 - ndcg_at_100: 0.1248 - map_at_100: 0.0585 - precision_at_100: 0.0043 - recall_at_10: 0.1098 - mrr_at_10: 0.0488 - ndcg_at_10: 0.0630 - map_at_10: 0.0488 - precision_at_10: 0.0110 - regularization_loss: 0.0000e+00 - loss_batch: 6.1285 - val_loss: 7.0127 - val_auc: 0.6117 - val_recall_at_100: 0.2402 - val_mrr_at_100: 0.0145 - val_ndcg_at_100: 0.0527 - val_map_at_100: 0.0145 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0298 - val_mrr_at_10: 0.0088 - val_ndcg_at_10: 0.0136 - val_map_at_10: 0.0088 - val_precision_at_10: 0.0030 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.0699
# Epoch 2/30
# 69/69 [==============================] - 5s 64ms/step - loss: 6.1376 - auc: 0.7165 - recall_at_100: 0.4345 - mrr_at_100: 0.0583 - ndcg_at_100: 0.1248 - map_at_100: 0.0583 - precision_at_100: 0.0043 - recall_at_10: 0.1123 - mrr_at_10: 0.0486 - ndcg_at_10: 0.0634 - map_at_10: 0.0486 - precision_at_10: 0.0112 - regularization_loss: 0.0000e+00 - loss_batch: 6.1227 - val_loss: 6.9930 - val_auc: 0.6161 - val_recall_at_100: 0.2405 - val_mrr_at_100: 0.0150 - val_ndcg_at_100: 0.0531 - val_map_at_100: 0.0150 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0280 - val_mrr_at_10: 0.0093 - val_ndcg_at_10: 0.0136 - val_map_at_10: 0.0093 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1560
# Epoch 3/30
# 69/69 [==============================] - 3s 36ms/step - loss: 6.1353 - auc: 0.7165 - recall_at_100: 0.4362 - mrr_at_100: 0.0589 - ndcg_at_100: 0.1256 - map_at_100: 0.0589 - precision_at_100: 0.0044 - recall_at_10: 0.1105 - mrr_at_10: 0.0490 - ndcg_at_10: 0.0633 - map_at_10: 0.0490 - precision_at_10: 0.0111 - regularization_loss: 0.0000e+00 - loss_batch: 6.1198 - val_loss: 6.9976 - val_auc: 0.6165 - val_recall_at_100: 0.2398 - val_mrr_at_100: 0.0153 - val_ndcg_at_100: 0.0532 - val_map_at_100: 0.0153 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0283 - val_mrr_at_10: 0.0096 - val_ndcg_at_10: 0.0138 - val_map_at_10: 0.0096 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1660
# Epoch 4/30
# 69/69 [==============================] - 3s 39ms/step - loss: 6.1350 - auc: 0.7172 - recall_at_100: 0.4353 - mrr_at_100: 0.0592 - ndcg_at_100: 0.1257 - map_at_100: 0.0592 - precision_at_100: 0.0044 - recall_at_10: 0.1137 - mrr_at_10: 0.0496 - ndcg_at_10: 0.0645 - map_at_10: 0.0496 - precision_at_10: 0.0114 - regularization_loss: 0.0000e+00 - loss_batch: 6.1195 - val_loss: 7.0133 - val_auc: 0.6197 - val_recall_at_100: 0.2365 - val_mrr_at_100: 0.0141 - val_ndcg_at_100: 0.0517 - val_map_at_100: 0.0141 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0278 - val_mrr_at_10: 0.0084 - val_ndcg_at_10: 0.0128 - val_map_at_10: 0.0084 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1351
# Epoch 5/30
# 69/69 [==============================] - 4s 47ms/step - loss: 6.1314 - auc: 0.7178 - recall_at_100: 0.4382 - mrr_at_100: 0.0598 - ndcg_at_100: 0.1266 - map_at_100: 0.0598 - precision_at_100: 0.0044 - recall_at_10: 0.1123 - mrr_at_10: 0.0499 - ndcg_at_10: 0.0644 - map_at_10: 0.0499 - precision_at_10: 0.0112 - regularization_loss: 0.0000e+00 - loss_batch: 6.1161 - val_loss: 7.0597 - val_auc: 0.6119 - val_recall_at_100: 0.2280 - val_mrr_at_100: 0.0145 - val_ndcg_at_100: 0.0507 - val_map_at_100: 0.0145 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0276 - val_mrr_at_10: 0.0090 - val_ndcg_at_10: 0.0132 - val_map_at_10: 0.0090 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1151
# Epoch 6/30
# 69/69 [==============================] - 6s 70ms/step - loss: 6.1301 - auc: 0.7171 - recall_at_100: 0.4406 - mrr_at_100: 0.0599 - ndcg_at_100: 0.1272 - map_at_100: 0.0599 - precision_at_100: 0.0044 - recall_at_10: 0.1128 - mrr_at_10: 0.0500 - ndcg_at_10: 0.0646 - map_at_10: 0.0500 - precision_at_10: 0.0113 - regularization_loss: 0.0000e+00 - loss_batch: 6.1146 - val_loss: 7.0520 - val_auc: 0.6158 - val_recall_at_100: 0.2252 - val_mrr_at_100: 0.0137 - val_ndcg_at_100: 0.0494 - val_map_at_100: 0.0137 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0266 - val_mrr_at_10: 0.0084 - val_ndcg_at_10: 0.0125 - val_map_at_10: 0.0084 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1414
# Epoch 7/30
# 69/69 [==============================] - 3s 39ms/step - loss: 6.1269 - auc: 0.7121 - recall_at_100: 0.4394 - mrr_at_100: 0.0597 - ndcg_at_100: 0.1269 - map_at_100: 0.0597 - precision_at_100: 0.0044 - recall_at_10: 0.1134 - mrr_at_10: 0.0499 - ndcg_at_10: 0.0646 - map_at_10: 0.0499 - precision_at_10: 0.0113 - regularization_loss: 0.0000e+00 - loss_batch: 6.1114 - val_loss: 7.0214 - val_auc: 0.6201 - val_recall_at_100: 0.2332 - val_mrr_at_100: 0.0139 - val_ndcg_at_100: 0.0509 - val_map_at_100: 0.0139 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0262 - val_mrr_at_10: 0.0082 - val_ndcg_at_10: 0.0123 - val_map_at_10: 0.0082 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2374
# Epoch 8/30
# 69/69 [==============================] - 3s 37ms/step - loss: 6.1241 - auc: 0.7116 - recall_at_100: 0.4389 - mrr_at_100: 0.0607 - ndcg_at_100: 0.1278 - map_at_100: 0.0607 - precision_at_100: 0.0044 - recall_at_10: 0.1163 - mrr_at_10: 0.0509 - ndcg_at_10: 0.0661 - map_at_10: 0.0509 - precision_at_10: 0.0116 - regularization_loss: 0.0000e+00 - loss_batch: 6.1089 - val_loss: 7.0526 - val_auc: 0.6207 - val_recall_at_100: 0.2330 - val_mrr_at_100: 0.0143 - val_ndcg_at_100: 0.0513 - val_map_at_100: 0.0143 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0267 - val_mrr_at_10: 0.0085 - val_ndcg_at_10: 0.0127 - val_map_at_10: 0.0085 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1990
# Epoch 9/30
# 69/69 [==============================] - 3s 38ms/step - loss: 6.1217 - auc: 0.7101 - recall_at_100: 0.4400 - mrr_at_100: 0.0599 - ndcg_at_100: 0.1272 - map_at_100: 0.0599 - precision_at_100: 0.0044 - recall_at_10: 0.1140 - mrr_at_10: 0.0501 - ndcg_at_10: 0.0650 - map_at_10: 0.0501 - precision_at_10: 0.0114 - regularization_loss: 0.0000e+00 - loss_batch: 6.1059 - val_loss: 7.0329 - val_auc: 0.6211 - val_recall_at_100: 0.2343 - val_mrr_at_100: 0.0134 - val_ndcg_at_100: 0.0507 - val_map_at_100: 0.0134 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0262 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0119 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1584
# Epoch 10/30
# 69/69 [==============================] - 5s 57ms/step - loss: 6.1192 - auc: 0.7085 - recall_at_100: 0.4447 - mrr_at_100: 0.0607 - ndcg_at_100: 0.1288 - map_at_100: 0.0607 - precision_at_100: 0.0044 - recall_at_10: 0.1174 - mrr_at_10: 0.0508 - ndcg_at_10: 0.0662 - map_at_10: 0.0508 - precision_at_10: 0.0117 - regularization_loss: 0.0000e+00 - loss_batch: 6.1037 - val_loss: 7.0180 - val_auc: 0.6231 - val_recall_at_100: 0.2412 - val_mrr_at_100: 0.0145 - val_ndcg_at_100: 0.0527 - val_map_at_100: 0.0145 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0268 - val_mrr_at_10: 0.0087 - val_ndcg_at_10: 0.0128 - val_map_at_10: 0.0087 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2257
# Epoch 11/30
# 69/69 [==============================] - 4s 46ms/step - loss: 6.1169 - auc: 0.7071 - recall_at_100: 0.4418 - mrr_at_100: 0.0610 - ndcg_at_100: 0.1285 - map_at_100: 0.0610 - precision_at_100: 0.0044 - recall_at_10: 0.1178 - mrr_at_10: 0.0513 - ndcg_at_10: 0.0667 - map_at_10: 0.0513 - precision_at_10: 0.0118 - regularization_loss: 0.0000e+00 - loss_batch: 6.1014 - val_loss: 7.0192 - val_auc: 0.6238 - val_recall_at_100: 0.2429 - val_mrr_at_100: 0.0144 - val_ndcg_at_100: 0.0530 - val_map_at_100: 0.0144 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0278 - val_mrr_at_10: 0.0086 - val_ndcg_at_10: 0.0130 - val_map_at_10: 0.0086 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1378
# Epoch 12/30
# 69/69 [==============================] - 3s 38ms/step - loss: 6.1143 - auc: 0.7011 - recall_at_100: 0.4473 - mrr_at_100: 0.0616 - ndcg_at_100: 0.1299 - map_at_100: 0.0616 - precision_at_100: 0.0045 - recall_at_10: 0.1176 - mrr_at_10: 0.0518 - ndcg_at_10: 0.0670 - map_at_10: 0.0518 - precision_at_10: 0.0118 - regularization_loss: 0.0000e+00 - loss_batch: 6.0986 - val_loss: 7.0220 - val_auc: 0.6231 - val_recall_at_100: 0.2399 - val_mrr_at_100: 0.0143 - val_ndcg_at_100: 0.0524 - val_map_at_100: 0.0143 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0286 - val_mrr_at_10: 0.0085 - val_ndcg_at_10: 0.0131 - val_map_at_10: 0.0085 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1610
# Epoch 13/30
# 69/69 [==============================] - 3s 36ms/step - loss: 6.1141 - auc: 0.7019 - recall_at_100: 0.4425 - mrr_at_100: 0.0618 - ndcg_at_100: 0.1294 - map_at_100: 0.0618 - precision_at_100: 0.0044 - recall_at_10: 0.1186 - mrr_at_10: 0.0521 - ndcg_at_10: 0.0675 - map_at_10: 0.0521 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0983 - val_loss: 7.0399 - val_auc: 0.6210 - val_recall_at_100: 0.2390 - val_mrr_at_100: 0.0135 - val_ndcg_at_100: 0.0515 - val_map_at_100: 0.0135 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0260 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0118 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2405
# Epoch 14/30
# 69/69 [==============================] - 4s 46ms/step - loss: 6.1093 - auc: 0.7005 - recall_at_100: 0.4476 - mrr_at_100: 0.0622 - ndcg_at_100: 0.1304 - map_at_100: 0.0622 - precision_at_100: 0.0045 - recall_at_10: 0.1166 - mrr_at_10: 0.0522 - ndcg_at_10: 0.0672 - map_at_10: 0.0522 - precision_at_10: 0.0117 - regularization_loss: 0.0000e+00 - loss_batch: 6.0938 - val_loss: 7.0584 - val_auc: 0.6218 - val_recall_at_100: 0.2337 - val_mrr_at_100: 0.0135 - val_ndcg_at_100: 0.0508 - val_map_at_100: 0.0135 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0276 - val_mrr_at_10: 0.0079 - val_ndcg_at_10: 0.0123 - val_map_at_10: 0.0079 - val_precision_at_10: 0.0028 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2086
# Epoch 15/30
# 69/69 [==============================] - 5s 56ms/step - loss: 6.1097 - auc: 0.7003 - recall_at_100: 0.4442 - mrr_at_100: 0.0615 - ndcg_at_100: 0.1293 - map_at_100: 0.0615 - precision_at_100: 0.0044 - recall_at_10: 0.1157 - mrr_at_10: 0.0516 - ndcg_at_10: 0.0665 - map_at_10: 0.0516 - precision_at_10: 0.0116 - regularization_loss: 0.0000e+00 - loss_batch: 6.0942 - val_loss: 7.0423 - val_auc: 0.6231 - val_recall_at_100: 0.2429 - val_mrr_at_100: 0.0146 - val_ndcg_at_100: 0.0533 - val_map_at_100: 0.0146 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0275 - val_mrr_at_10: 0.0087 - val_ndcg_at_10: 0.0130 - val_map_at_10: 0.0087 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3101
# Epoch 16/30
# 69/69 [==============================] - 3s 39ms/step - loss: 6.1077 - auc: 0.6952 - recall_at_100: 0.4513 - mrr_at_100: 0.0628 - ndcg_at_100: 0.1317 - map_at_100: 0.0628 - precision_at_100: 0.0045 - recall_at_10: 0.1205 - mrr_at_10: 0.0529 - ndcg_at_10: 0.0686 - map_at_10: 0.0529 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0920 - val_loss: 7.0572 - val_auc: 0.6237 - val_recall_at_100: 0.2353 - val_mrr_at_100: 0.0135 - val_ndcg_at_100: 0.0509 - val_map_at_100: 0.0135 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0255 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0118 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2672
# Epoch 17/30
# 69/69 [==============================] - 3s 39ms/step - loss: 6.1072 - auc: 0.6924 - recall_at_100: 0.4455 - mrr_at_100: 0.0628 - ndcg_at_100: 0.1306 - map_at_100: 0.0628 - precision_at_100: 0.0045 - recall_at_10: 0.1190 - mrr_at_10: 0.0529 - ndcg_at_10: 0.0682 - map_at_10: 0.0529 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0913 - val_loss: 7.0940 - val_auc: 0.6186 - val_recall_at_100: 0.2351 - val_mrr_at_100: 0.0132 - val_ndcg_at_100: 0.0506 - val_map_at_100: 0.0132 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0263 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0119 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2727
# Epoch 18/30
# 69/69 [==============================] - 4s 47ms/step - loss: 6.1042 - auc: 0.6887 - recall_at_100: 0.4505 - mrr_at_100: 0.0625 - ndcg_at_100: 0.1313 - map_at_100: 0.0625 - precision_at_100: 0.0045 - recall_at_10: 0.1182 - mrr_at_10: 0.0524 - ndcg_at_10: 0.0676 - map_at_10: 0.0524 - precision_at_10: 0.0118 - regularization_loss: 0.0000e+00 - loss_batch: 6.0887 - val_loss: 7.1191 - val_auc: 0.6189 - val_recall_at_100: 0.2269 - val_mrr_at_100: 0.0131 - val_ndcg_at_100: 0.0491 - val_map_at_100: 0.0131 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0256 - val_mrr_at_10: 0.0076 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0076 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2575
# Epoch 19/30
# 69/69 [==============================] - 5s 64ms/step - loss: 6.1019 - auc: 0.6861 - recall_at_100: 0.4474 - mrr_at_100: 0.0633 - ndcg_at_100: 0.1315 - map_at_100: 0.0633 - precision_at_100: 0.0045 - recall_at_10: 0.1202 - mrr_at_10: 0.0533 - ndcg_at_10: 0.0688 - map_at_10: 0.0533 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0862 - val_loss: 7.0849 - val_auc: 0.6198 - val_recall_at_100: 0.2297 - val_mrr_at_100: 0.0134 - val_ndcg_at_100: 0.0499 - val_map_at_100: 0.0134 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0271 - val_mrr_at_10: 0.0080 - val_ndcg_at_10: 0.0124 - val_map_at_10: 0.0080 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3487
# Epoch 20/30
# 69/69 [==============================] - 3s 38ms/step - loss: 6.1034 - auc: 0.6821 - recall_at_100: 0.4464 - mrr_at_100: 0.0624 - ndcg_at_100: 0.1306 - map_at_100: 0.0624 - precision_at_100: 0.0045 - recall_at_10: 0.1204 - mrr_at_10: 0.0525 - ndcg_at_10: 0.0683 - map_at_10: 0.0525 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0875 - val_loss: 7.0736 - val_auc: 0.6181 - val_recall_at_100: 0.2363 - val_mrr_at_100: 0.0136 - val_ndcg_at_100: 0.0512 - val_map_at_100: 0.0136 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0253 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3250
# Epoch 21/30
# 69/69 [==============================] - 3s 41ms/step - loss: 6.1005 - auc: 0.6789 - recall_at_100: 0.4444 - mrr_at_100: 0.0629 - ndcg_at_100: 0.1308 - map_at_100: 0.0629 - precision_at_100: 0.0044 - recall_at_10: 0.1200 - mrr_at_10: 0.0529 - ndcg_at_10: 0.0685 - map_at_10: 0.0529 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0849 - val_loss: 7.0704 - val_auc: 0.6187 - val_recall_at_100: 0.2358 - val_mrr_at_100: 0.0136 - val_ndcg_at_100: 0.0511 - val_map_at_100: 0.0136 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0261 - val_mrr_at_10: 0.0078 - val_ndcg_at_10: 0.0120 - val_map_at_10: 0.0078 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3959
# Epoch 22/30
# 69/69 [==============================] - 3s 36ms/step - loss: 6.0987 - auc: 0.6735 - recall_at_100: 0.4472 - mrr_at_100: 0.0627 - ndcg_at_100: 0.1309 - map_at_100: 0.0627 - precision_at_100: 0.0045 - recall_at_10: 0.1192 - mrr_at_10: 0.0528 - ndcg_at_10: 0.0682 - map_at_10: 0.0528 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0828 - val_loss: 7.1085 - val_auc: 0.6144 - val_recall_at_100: 0.2284 - val_mrr_at_100: 0.0132 - val_ndcg_at_100: 0.0495 - val_map_at_100: 0.0132 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0249 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0116 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3156
# Epoch 23/30
# 69/69 [==============================] - 4s 57ms/step - loss: 6.0971 - auc: 0.6716 - recall_at_100: 0.4476 - mrr_at_100: 0.0624 - ndcg_at_100: 0.1307 - map_at_100: 0.0624 - precision_at_100: 0.0045 - recall_at_10: 0.1192 - mrr_at_10: 0.0525 - ndcg_at_10: 0.0680 - map_at_10: 0.0525 - precision_at_10: 0.0119 - regularization_loss: 0.0000e+00 - loss_batch: 6.0812 - val_loss: 7.0421 - val_auc: 0.6156 - val_recall_at_100: 0.2335 - val_mrr_at_100: 0.0132 - val_ndcg_at_100: 0.0504 - val_map_at_100: 0.0132 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0260 - val_mrr_at_10: 0.0075 - val_ndcg_at_10: 0.0117 - val_map_at_10: 0.0075 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.1890
# Epoch 24/30
# 69/69 [==============================] - 4s 50ms/step - loss: 6.0966 - auc: 0.6674 - recall_at_100: 0.4505 - mrr_at_100: 0.0628 - ndcg_at_100: 0.1316 - map_at_100: 0.0628 - precision_at_100: 0.0045 - recall_at_10: 0.1199 - mrr_at_10: 0.0527 - ndcg_at_10: 0.0683 - map_at_10: 0.0527 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0810 - val_loss: 7.1000 - val_auc: 0.6130 - val_recall_at_100: 0.2295 - val_mrr_at_100: 0.0129 - val_ndcg_at_100: 0.0494 - val_map_at_100: 0.0129 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0257 - val_mrr_at_10: 0.0074 - val_ndcg_at_10: 0.0116 - val_map_at_10: 0.0074 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2310
# Epoch 25/30
# 69/69 [==============================] - 3s 38ms/step - loss: 6.0970 - auc: 0.6635 - recall_at_100: 0.4492 - mrr_at_100: 0.0634 - ndcg_at_100: 0.1321 - map_at_100: 0.0634 - precision_at_100: 0.0045 - recall_at_10: 0.1224 - mrr_at_10: 0.0535 - ndcg_at_10: 0.0695 - map_at_10: 0.0535 - precision_at_10: 0.0122 - regularization_loss: 0.0000e+00 - loss_batch: 6.0810 - val_loss: 7.0913 - val_auc: 0.6099 - val_recall_at_100: 0.2336 - val_mrr_at_100: 0.0130 - val_ndcg_at_100: 0.0503 - val_map_at_100: 0.0130 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0251 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0113 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2197
# Epoch 26/30
# 69/69 [==============================] - 3s 38ms/step - loss: 6.0930 - auc: 0.6622 - recall_at_100: 0.4466 - mrr_at_100: 0.0643 - ndcg_at_100: 0.1322 - map_at_100: 0.0643 - precision_at_100: 0.0045 - recall_at_10: 0.1197 - mrr_at_10: 0.0543 - ndcg_at_10: 0.0695 - map_at_10: 0.0543 - precision_at_10: 0.0120 - regularization_loss: 0.0000e+00 - loss_batch: 6.0769 - val_loss: 7.1026 - val_auc: 0.6086 - val_recall_at_100: 0.2288 - val_mrr_at_100: 0.0127 - val_ndcg_at_100: 0.0491 - val_map_at_100: 0.0127 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0250 - val_mrr_at_10: 0.0072 - val_ndcg_at_10: 0.0113 - val_map_at_10: 0.0072 - val_precision_at_10: 0.0025 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3017
# Epoch 27/30
# 69/69 [==============================] - 5s 66ms/step - loss: 6.0918 - auc: 0.6574 - recall_at_100: 0.4493 - mrr_at_100: 0.0647 - ndcg_at_100: 0.1331 - map_at_100: 0.0647 - precision_at_100: 0.0045 - recall_at_10: 0.1218 - mrr_at_10: 0.0547 - ndcg_at_10: 0.0703 - map_at_10: 0.0547 - precision_at_10: 0.0122 - regularization_loss: 0.0000e+00 - loss_batch: 6.0762 - val_loss: 7.0734 - val_auc: 0.6102 - val_recall_at_100: 0.2390 - val_mrr_at_100: 0.0142 - val_ndcg_at_100: 0.0521 - val_map_at_100: 0.0142 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0287 - val_mrr_at_10: 0.0086 - val_ndcg_at_10: 0.0132 - val_map_at_10: 0.0086 - val_precision_at_10: 0.0029 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3635
# Epoch 28/30
# 69/69 [==============================] - 4s 45ms/step - loss: 6.0917 - auc: 0.6544 - recall_at_100: 0.4467 - mrr_at_100: 0.0640 - ndcg_at_100: 0.1320 - map_at_100: 0.0640 - precision_at_100: 0.0045 - recall_at_10: 0.1217 - mrr_at_10: 0.0541 - ndcg_at_10: 0.0698 - map_at_10: 0.0541 - precision_at_10: 0.0122 - regularization_loss: 0.0000e+00 - loss_batch: 6.0758 - val_loss: 7.0863 - val_auc: 0.6121 - val_recall_at_100: 0.2369 - val_mrr_at_100: 0.0139 - val_ndcg_at_100: 0.0516 - val_map_at_100: 0.0139 - val_precision_at_100: 0.0024 - val_recall_at_10: 0.0274 - val_mrr_at_10: 0.0083 - val_ndcg_at_10: 0.0126 - val_map_at_10: 0.0083 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3725
# Epoch 29/30
# 69/69 [==============================] - 3s 40ms/step - loss: 6.0910 - auc: 0.6514 - recall_at_100: 0.4525 - mrr_at_100: 0.0646 - ndcg_at_100: 0.1335 - map_at_100: 0.0646 - precision_at_100: 0.0045 - recall_at_10: 0.1211 - mrr_at_10: 0.0544 - ndcg_at_10: 0.0699 - map_at_10: 0.0544 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0752 - val_loss: 7.0776 - val_auc: 0.6033 - val_recall_at_100: 0.2310 - val_mrr_at_100: 0.0133 - val_ndcg_at_100: 0.0502 - val_map_at_100: 0.0133 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0262 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0119 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0026 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.2201
# Epoch 30/30
# 69/69 [==============================] - 3s 37ms/step - loss: 6.0887 - auc: 0.6456 - recall_at_100: 0.4511 - mrr_at_100: 0.0633 - ndcg_at_100: 0.1322 - map_at_100: 0.0633 - precision_at_100: 0.0045 - recall_at_10: 0.1213 - mrr_at_10: 0.0532 - ndcg_at_10: 0.0690 - map_at_10: 0.0532 - precision_at_10: 0.0121 - regularization_loss: 0.0000e+00 - loss_batch: 6.0730 - val_loss: 7.1026 - val_auc: 0.6018 - val_recall_at_100: 0.2315 - val_mrr_at_100: 0.0133 - val_ndcg_at_100: 0.0502 - val_map_at_100: 0.0133 - val_precision_at_100: 0.0023 - val_recall_at_10: 0.0267 - val_mrr_at_10: 0.0077 - val_ndcg_at_10: 0.0121 - val_map_at_10: 0.0077 - val_precision_at_10: 0.0027 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 7.3087

# %% [markdown]
# #### analysis

# %%
_history = merge_model_history(*history_v6)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
METRIC_AT = {'@'.join([k.split('_')[0].title(), k.split('_')[-1]]):k for k in _history if k.startswith('recall') or k.startswith('ndcg')}
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM, **METRIC_AT})
# {'AUC': AUC_TERM, 'Recall@100': 'recall_at_100','NDCG@10': 'ndcg_at_10',}

# %% [markdown]
# #### eval

# %%
(model_v6.evaluate(train, batch_size=2048, return_dict=True),
 model_v6.evaluate(valid, batch_size=2048, return_dict=True))
# Out:
# 35/35 [==============================] - 3s 56ms/step - loss: 6.7073 - auc: 0.6391 - recall_at_100: 0.3191 - mrr_at_100: 0.0496 - ndcg_at_100: 0.0976 - map_at_100: 0.0496 - precision_at_100: 0.0032 - recall_at_10: 0.0915 - mrr_at_10: 0.0428 - ndcg_at_10: 0.0541 - map_at_10: 0.0428 - precision_at_10: 0.0092 - regularization_loss: 0.0000e+00 - loss_batch: 6.6387
# 8/8 [==============================] - 1s 64ms/step - loss: 7.7783 - auc: 0.5958 - recall_at_100: 0.1142 - mrr_at_100: 0.0164 - ndcg_at_100: 0.0326 - map_at_100: 0.0164 - precision_at_100: 0.0011 - recall_at_10: 0.0201 - mrr_at_10: 0.0140 - ndcg_at_10: 0.0154 - map_at_10: 0.0140 - precision_at_10: 0.0020 - regularization_loss: 0.0000e+00 - loss_batch: 7.6897
# ({'loss': 6.707321643829346,
#   'auc': 0.639060378074646,
#   'recall_at_100': 0.32308197021484375,
#   'mrr_at_100': 0.050441160798072815,
#   'ndcg_at_100': 0.09896378964185715,
#   'map_at_100': 0.050441160798072815,
#   'precision_at_100': 0.0032308197114616632,
#   'recall_at_10': 0.09243326634168625,
#   'mrr_at_10': 0.04344486445188522,
#   'ndcg_at_10': 0.05483837425708771,
#   'map_at_10': 0.04344486445188522,
#   'precision_at_10': 0.009243326261639595,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.272099494934082},
#  {'loss': 7.7782793045043945,
#   'auc': 0.5957744121551514,
#   'recall_at_100': 0.12866123020648956,
#   'mrr_at_100': 0.015090590342879295,
#   'ndcg_at_100': 0.033981774002313614,
#   'map_at_100': 0.015090590342879295,
#   'precision_at_100': 0.0012866122415289283,
#   'recall_at_10': 0.020262137055397034,
#   'mrr_at_10': 0.012304134666919708,
#   'ndcg_at_10': 0.014097444713115692,
#   'map_at_10': 0.012304134666919708,
#   'precision_at_10': 0.002026213565841317,
#   'regularization_loss': 0.0,
#   'loss_batch': 7.30871057510376})

# %%
evaluate_model(model_v6, train, topk=100)
# Out:
# Candidate set rows: 1561
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-c8b816cac68e> in <cell line: 1>()
# ----> 1 evaluate_model(model_v6, train, topk=100)
#
# <ipython-input-55-349a54f40394> in evaluate_model(model, ds, topk, batch_size, target_id, candidate_id)
#      13     candidate_features = get_candidates(ds, candidate_id)
#      14
# ---> 15     topk_model = to_top_k_encoder(model, candidate_features, k=topk, batch_size=batch_size, candidate_id=candidate_id)
#      16     topk_model.compile(run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
#      17                                              mm.TopKMetricsAggregator.default_metrics(top_ks=[topk])
#
# <ipython-input-59-970d316d3ce1> in to_top_k_encoder(model, candidates, candidate_id, strategy, k, batch_size)
#      79
#      80     # https://github.com/NVIDIA-Merlin/models/blob/stable/merlin/models/tf/models/base.py#L2479
# ---> 81     candidates_embeddings = batch_predict(
#      82                 candidate_encoder,
#      83                 candidates,
#
# <ipython-input-59-970d316d3ce1> in batch_predict(self, dataset, batch_size, output_schema, index, **kwargs)
#      33
#      34             if len(index) != 1:
# ---> 35                 raise ValueError("Only one column can be used as index")
#      36             index = index.first.name
#      37
#
# ValueError: Only one column can be used as index

# %%
evaluate_model(model_v6, valid, topk=100)

# %% [markdown]
# ### model_v7

# %%
# _tower_dim = (64, 128) # @param
# _tower_dim = (128, 64) # @param
_tower_dim = (128, 128) # @param

_learning_rate = 0.01 # @param
# _batch_size = 4096 # @param
_batch_size = 64 # @param
_epochs = 20 # @param
_validation_batch_size = 256 # @param

# %%
model_v7 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [10]
model_v7.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)
history_v7 = []

# %% [markdown]
# #### model

# %%
history_v7.append(
    model_v7.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size)
)
# Out:
# Epoch 1/20
# 1097/1097 [==============================] - 37s 29ms/step - loss: 4.0804 - auc_20: 0.5554 - recall_at_10: 0.1913 - mrr_at_10: 0.0585 - ndcg_at_10: 0.0889 - map_at_10: 0.0585 - precision_at_10: 0.0191 - regularization_loss: 0.0000e+00 - loss_batch: 4.0802 - val_loss: 4.0451 - val_auc_20: 0.5428 - val_recall_at_10: 0.2677 - val_mrr_at_10: 0.0858 - val_ndcg_at_10: 0.1276 - val_map_at_10: 0.0858 - val_precision_at_10: 0.0268 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 3.7465
# Epoch 2/20
# 1097/1097 [==============================] - 23s 21ms/step - loss: 3.9007 - auc_20: 0.6016 - recall_at_10: 0.3208 - mrr_at_10: 0.1029 - ndcg_at_10: 0.1530 - map_at_10: 0.1029 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 3.9005 - val_loss: 3.9707 - val_auc_20: 0.5790 - val_recall_at_10: 0.3152 - val_mrr_at_10: 0.1045 - val_ndcg_at_10: 0.1530 - val_map_at_10: 0.1045 - val_precision_at_10: 0.0315 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 3.9322
# Epoch 3/20
# 1097/1097 [==============================] - 28s 26ms/step - loss: 3.8291 - auc_20: 0.6159 - recall_at_10: 0.3645 - mrr_at_10: 0.1198 - ndcg_at_10: 0.1762 - map_at_10: 0.1198 - precision_at_10: 0.0364 - regularization_loss: 0.0000e+00 - loss_batch: 3.8290 - val_loss: 3.9792 - val_auc_20: 0.5837 - val_recall_at_10: 0.3273 - val_mrr_at_10: 0.1094 - val_ndcg_at_10: 0.1597 - val_map_at_10: 0.1094 - val_precision_at_10: 0.0327 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.0290
# Epoch 4/20
# 1097/1097 [==============================] - 23s 21ms/step - loss: 3.8053 - auc_20: 0.6196 - recall_at_10: 0.3692 - mrr_at_10: 0.1242 - ndcg_at_10: 0.1807 - map_at_10: 0.1242 - precision_at_10: 0.0369 - regularization_loss: 0.0000e+00 - loss_batch: 3.8051 - val_loss: 3.9376 - val_auc_20: 0.5664 - val_recall_at_10: 0.3277 - val_mrr_at_10: 0.1099 - val_ndcg_at_10: 0.1601 - val_map_at_10: 0.1099 - val_precision_at_10: 0.0328 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.1404
# Epoch 5/20
# 1097/1097 [==============================] - 27s 23ms/step - loss: 3.7942 - auc_20: 0.6215 - recall_at_10: 0.3745 - mrr_at_10: 0.1269 - ndcg_at_10: 0.1840 - map_at_10: 0.1269 - precision_at_10: 0.0374 - regularization_loss: 0.0000e+00 - loss_batch: 3.7941 - val_loss: 3.9957 - val_auc_20: 0.5923 - val_recall_at_10: 0.3342 - val_mrr_at_10: 0.1118 - val_ndcg_at_10: 0.1631 - val_map_at_10: 0.1118 - val_precision_at_10: 0.0334 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.3350
# Epoch 6/20
# 1097/1097 [==============================] - 29s 26ms/step - loss: 3.7869 - auc_20: 0.6188 - recall_at_10: 0.3802 - mrr_at_10: 0.1283 - ndcg_at_10: 0.1864 - map_at_10: 0.1283 - precision_at_10: 0.0380 - regularization_loss: 0.0000e+00 - loss_batch: 3.7868 - val_loss: 3.9145 - val_auc_20: 0.5785 - val_recall_at_10: 0.3320 - val_mrr_at_10: 0.1073 - val_ndcg_at_10: 0.1591 - val_map_at_10: 0.1073 - val_precision_at_10: 0.0332 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.0850
# Epoch 7/20
# 1097/1097 [==============================] - 26s 23ms/step - loss: 3.7818 - auc_20: 0.6198 - recall_at_10: 0.3825 - mrr_at_10: 0.1305 - ndcg_at_10: 0.1885 - map_at_10: 0.1305 - precision_at_10: 0.0382 - regularization_loss: 0.0000e+00 - loss_batch: 3.7816 - val_loss: 3.9514 - val_auc_20: 0.5880 - val_recall_at_10: 0.3257 - val_mrr_at_10: 0.1087 - val_ndcg_at_10: 0.1587 - val_map_at_10: 0.1087 - val_precision_at_10: 0.0326 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.4395
# Epoch 8/20
# 1097/1097 [==============================] - 26s 23ms/step - loss: 3.7736 - auc_20: 0.6198 - recall_at_10: 0.3847 - mrr_at_10: 0.1323 - ndcg_at_10: 0.1905 - map_at_10: 0.1323 - precision_at_10: 0.0385 - regularization_loss: 0.0000e+00 - loss_batch: 3.7735 - val_loss: 3.9443 - val_auc_20: 0.5799 - val_recall_at_10: 0.3388 - val_mrr_at_10: 0.1153 - val_ndcg_at_10: 0.1669 - val_map_at_10: 0.1153 - val_precision_at_10: 0.0339 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.3219
# Epoch 9/20
# 1097/1097 [==============================] - 25s 23ms/step - loss: 3.7734 - auc_20: 0.6125 - recall_at_10: 0.3820 - mrr_at_10: 0.1327 - ndcg_at_10: 0.1902 - map_at_10: 0.1327 - precision_at_10: 0.0382 - regularization_loss: 0.0000e+00 - loss_batch: 3.7733 - val_loss: 3.9608 - val_auc_20: 0.5540 - val_recall_at_10: 0.3065 - val_mrr_at_10: 0.1015 - val_ndcg_at_10: 0.1487 - val_map_at_10: 0.1015 - val_precision_at_10: 0.0306 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.2821
# Epoch 10/20
# 1097/1097 [==============================] - 27s 24ms/step - loss: 3.7679 - auc_20: 0.6102 - recall_at_10: 0.3853 - mrr_at_10: 0.1326 - ndcg_at_10: 0.1909 - map_at_10: 0.1326 - precision_at_10: 0.0385 - regularization_loss: 0.0000e+00 - loss_batch: 3.7677 - val_loss: 3.9771 - val_auc_20: 0.5575 - val_recall_at_10: 0.3116 - val_mrr_at_10: 0.1029 - val_ndcg_at_10: 0.1509 - val_map_at_10: 0.1029 - val_precision_at_10: 0.0312 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7681
# Epoch 11/20
# 1097/1097 [==============================] - 23s 21ms/step - loss: 3.7792 - auc_20: 0.5935 - recall_at_10: 0.3894 - mrr_at_10: 0.1331 - ndcg_at_10: 0.1922 - map_at_10: 0.1331 - precision_at_10: 0.0389 - regularization_loss: 0.0000e+00 - loss_batch: 3.7791 - val_loss: 4.0027 - val_auc_20: 0.5347 - val_recall_at_10: 0.3108 - val_mrr_at_10: 0.1021 - val_ndcg_at_10: 0.1501 - val_map_at_10: 0.1021 - val_precision_at_10: 0.0311 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.4791
# Epoch 12/20
# 1097/1097 [==============================] - 26s 23ms/step - loss: 3.7742 - auc_20: 0.5851 - recall_at_10: 0.3825 - mrr_at_10: 0.1301 - ndcg_at_10: 0.1883 - map_at_10: 0.1301 - precision_at_10: 0.0382 - regularization_loss: 0.0000e+00 - loss_batch: 3.7740 - val_loss: 3.9820 - val_auc_20: 0.5535 - val_recall_at_10: 0.3218 - val_mrr_at_10: 0.1071 - val_ndcg_at_10: 0.1565 - val_map_at_10: 0.1071 - val_precision_at_10: 0.0322 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.2699
# Epoch 13/20
# 1097/1097 [==============================] - 23s 21ms/step - loss: 3.7622 - auc_20: 0.5874 - recall_at_10: 0.3903 - mrr_at_10: 0.1352 - ndcg_at_10: 0.1940 - map_at_10: 0.1352 - precision_at_10: 0.0390 - regularization_loss: 0.0000e+00 - loss_batch: 3.7623 - val_loss: 4.0129 - val_auc_20: 0.5438 - val_recall_at_10: 0.3074 - val_mrr_at_10: 0.1016 - val_ndcg_at_10: 0.1490 - val_map_at_10: 0.1016 - val_precision_at_10: 0.0307 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7067
# Epoch 14/20
# 1097/1097 [==============================] - 27s 24ms/step - loss: 3.7685 - auc_20: 0.5771 - recall_at_10: 0.3880 - mrr_at_10: 0.1336 - ndcg_at_10: 0.1923 - map_at_10: 0.1336 - precision_at_10: 0.0388 - regularization_loss: 0.0000e+00 - loss_batch: 3.7684 - val_loss: 3.9835 - val_auc_20: 0.5419 - val_recall_at_10: 0.3264 - val_mrr_at_10: 0.1098 - val_ndcg_at_10: 0.1597 - val_map_at_10: 0.1098 - val_precision_at_10: 0.0326 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7219
# Epoch 15/20
# 1097/1097 [==============================] - 26s 23ms/step - loss: 3.7638 - auc_20: 0.5670 - recall_at_10: 0.3836 - mrr_at_10: 0.1339 - ndcg_at_10: 0.1915 - map_at_10: 0.1339 - precision_at_10: 0.0384 - regularization_loss: 0.0000e+00 - loss_batch: 3.7637 - val_loss: 3.9957 - val_auc_20: 0.5324 - val_recall_at_10: 0.3005 - val_mrr_at_10: 0.1008 - val_ndcg_at_10: 0.1468 - val_map_at_10: 0.1008 - val_precision_at_10: 0.0300 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5004
# Epoch 16/20
# 1097/1097 [==============================] - 29s 25ms/step - loss: 3.7569 - auc_20: 0.5713 - recall_at_10: 0.3950 - mrr_at_10: 0.1373 - ndcg_at_10: 0.1968 - map_at_10: 0.1373 - precision_at_10: 0.0395 - regularization_loss: 0.0000e+00 - loss_batch: 3.7568 - val_loss: 4.0216 - val_auc_20: 0.5451 - val_recall_at_10: 0.3102 - val_mrr_at_10: 0.1013 - val_ndcg_at_10: 0.1494 - val_map_at_10: 0.1013 - val_precision_at_10: 0.0310 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.6110
# Epoch 17/20
# 1097/1097 [==============================] - 28s 25ms/step - loss: 3.7537 - auc_20: 0.5717 - recall_at_10: 0.3893 - mrr_at_10: 0.1356 - ndcg_at_10: 0.1941 - map_at_10: 0.1356 - precision_at_10: 0.0389 - regularization_loss: 0.0000e+00 - loss_batch: 3.7536 - val_loss: 3.9677 - val_auc_20: 0.5393 - val_recall_at_10: 0.3151 - val_mrr_at_10: 0.1049 - val_ndcg_at_10: 0.1533 - val_map_at_10: 0.1049 - val_precision_at_10: 0.0315 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.4076
# Epoch 18/20
# 1097/1097 [==============================] - 29s 26ms/step - loss: 3.7641 - auc_20: 0.5677 - recall_at_10: 0.3918 - mrr_at_10: 0.1370 - ndcg_at_10: 0.1958 - map_at_10: 0.1370 - precision_at_10: 0.0392 - regularization_loss: 0.0000e+00 - loss_batch: 3.7639 - val_loss: 3.9772 - val_auc_20: 0.5414 - val_recall_at_10: 0.3312 - val_mrr_at_10: 0.1114 - val_ndcg_at_10: 0.1621 - val_map_at_10: 0.1114 - val_precision_at_10: 0.0331 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7844
# Epoch 19/20
# 1097/1097 [==============================] - 29s 26ms/step - loss: 3.7601 - auc_20: 0.5670 - recall_at_10: 0.3867 - mrr_at_10: 0.1351 - ndcg_at_10: 0.1932 - map_at_10: 0.1351 - precision_at_10: 0.0387 - regularization_loss: 0.0000e+00 - loss_batch: 3.7600 - val_loss: 3.9699 - val_auc_20: 0.5381 - val_recall_at_10: 0.3165 - val_mrr_at_10: 0.1073 - val_ndcg_at_10: 0.1555 - val_map_at_10: 0.1073 - val_precision_at_10: 0.0317 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.1859
# Epoch 20/20
# 1097/1097 [==============================] - 25s 22ms/step - loss: 3.7491 - auc_20: 0.5676 - recall_at_10: 0.3884 - mrr_at_10: 0.1366 - ndcg_at_10: 0.1948 - map_at_10: 0.1366 - precision_at_10: 0.0388 - regularization_loss: 0.0000e+00 - loss_batch: 3.7489 - val_loss: 3.9748 - val_auc_20: 0.5322 - val_recall_at_10: 0.3283 - val_mrr_at_10: 0.1083 - val_ndcg_at_10: 0.1590 - val_map_at_10: 0.1083 - val_precision_at_10: 0.0328 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.2359

# %% [markdown]
# #### eval

# %%
(model_v7.evaluate(train, batch_size=2048, return_dict=True),
 model_v7.evaluate(valid, batch_size=2048, return_dict=True))
# Out:
# 35/35 [==============================] - 2s 34ms/step - loss: 7.1668 - auc_20: 0.5660 - recall_at_10: 0.0272 - mrr_at_10: 0.0093 - ndcg_at_10: 0.0134 - map_at_10: 0.0093 - precision_at_10: 0.0027 - regularization_loss: 0.0000e+00 - loss_batch: 7.1060
# 8/8 [==============================] - 1s 42ms/step - loss: 7.4135 - auc_20: 0.5244 - recall_at_10: 0.0210 - mrr_at_10: 0.0129 - ndcg_at_10: 0.0147 - map_at_10: 0.0129 - precision_at_10: 0.0021 - regularization_loss: 0.0000e+00 - loss_batch: 7.2331
# ({'loss': 7.166760444641113,
#   'auc_20': 0.5659791827201843,
#   'recall_at_10': 0.02707900106906891,
#   'mrr_at_10': 0.00937355775386095,
#   'ndcg_at_10': 0.013441509567201138,
#   'map_at_10': 0.00937355775386095,
#   'precision_at_10': 0.0027079000137746334,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.896761894226074},
#  {'loss': 7.413461685180664,
#   'auc_20': 0.5244063138961792,
#   'recall_at_10': 0.021532699465751648,
#   'mrr_at_10': 0.011950535699725151,
#   'ndcg_at_10': 0.014133432880043983,
#   'map_at_10': 0.011950535699725151,
#   'precision_at_10': 0.0021532701794058084,
#   'regularization_loss': 0.0,
#   'loss_batch': 6.457630634307861})

# %%
evaluate_model(model_v7, train, topk=100)
# Out:
# Candidate set rows: 1561
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:absl:Found untraced functions such as prepare_list_features_61_layer_call_fn, prepare_list_features_61_layer_call_and_return_conditional_losses, model_context_9_layer_call_fn, model_context_9_layer_call_and_return_conditional_losses, concat_features_19_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 69/69 [==============================] - 4s 17ms/step - loss: 0.7721 - auc_21: 0.3655 - recall_at_100: 0.1638 - mrr_at_100: 0.0055 - ndcg_at_100: 0.0312 - map_at_100: 0.0055 - precision_at_100: 0.0016 - regularization_loss: 0.0000e+00 - loss_batch: 0.7705
# {'loss': 0.7720529437065125,
#  'auc_21': 0.3655455410480499,
#  'recall_at_100': 0.16526594758033752,
#  'mrr_at_100': 0.00571011146530509,
#  'ndcg_at_100': 0.03162539005279541,
#  'map_at_100': 0.00571011146530509,
#  'precision_at_100': 0.0016526594990864396,
#  'regularization_loss': 0.0,
#  'loss_batch': 0.6964218020439148}

# %%
evaluate_model(model_v7, valid, topk=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1338
# WARNING:absl:Found untraced functions such as prepare_list_features_61_layer_call_fn, prepare_list_features_61_layer_call_and_return_conditional_losses, model_context_9_layer_call_fn, model_context_9_layer_call_and_return_conditional_losses, concat_features_19_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 15/15 [==============================] - 2s 19ms/step - loss: 0.6503 - auc_22: 0.4368 - recall_at_100: 0.1306 - mrr_at_100: 0.0045 - ndcg_at_100: 0.0249 - map_at_100: 0.0045 - precision_at_100: 0.0013 - regularization_loss: 0.0000e+00 - loss_batch: 0.7078
# {'loss': 0.650290846824646,
#  'auc_22': 0.43683111667633057,
#  'recall_at_100': 0.13902634382247925,
#  'mrr_at_100': 0.004871107637882233,
#  'ndcg_at_100': 0.026663023978471756,
#  'map_at_100': 0.004871107637882233,
#  'precision_at_100': 0.0013902633218094707,
#  'regularization_loss': 0.0,
#  'loss_batch': 1.308848261833191}

# %% [markdown]
# #### analysis

# %%
_history = merge_model_history(*history_v7)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
METRIC_AT = {'@'.join([k.split('_')[0], k.split('_')[-1]]):k for k in _history if k.startswith('recall') or k.startswith('ndcg')}
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM, **METRIC_AT})
# {'AUC': AUC_TERM, 'Recall@100': 'recall_at_100','NDCG@10': 'ndcg_at_10',}

# %% [markdown]
# ### model_v7

# %%
model_v7 = build_towers(tower_dim=64)
TOK_K = [10]
model_v7.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-2),
                 run_eagerly=False, metrics=[mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %%
history_v7_1 = model_v7.fit(train, validation_data=valid, batch_size=32, epochs=15, validation_batch_size=256)
# Out:
# Epoch 1/15
# 2194/2194 [==============================] - 61s 25ms/step - loss: 3.4660 - recall_at_10: 0.3114 - mrr_at_10: 0.0921 - ndcg_at_10: 0.1422 - map_at_10: 0.0921 - precision_at_10: 0.0311 - regularization_loss: 0.0000e+00 - loss_batch: 3.4659 - val_loss: 3.4635 - val_recall_at_10: 0.3161 - val_mrr_at_10: 0.0930 - val_ndcg_at_10: 0.1438 - val_map_at_10: 0.0930 - val_precision_at_10: 0.0316 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 2/15
# 2194/2194 [==============================] - 52s 23ms/step - loss: 3.4637 - recall_at_10: 0.3159 - mrr_at_10: 0.0934 - ndcg_at_10: 0.1441 - map_at_10: 0.0934 - precision_at_10: 0.0316 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4635 - val_recall_at_10: 0.3078 - val_mrr_at_10: 0.0899 - val_ndcg_at_10: 0.1398 - val_map_at_10: 0.0899 - val_precision_at_10: 0.0308 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 3/15
# 2194/2194 [==============================] - 48s 22ms/step - loss: 3.4637 - recall_at_10: 0.3208 - mrr_at_10: 0.0963 - ndcg_at_10: 0.1476 - map_at_10: 0.0963 - precision_at_10: 0.0321 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.3282 - val_mrr_at_10: 0.1069 - val_ndcg_at_10: 0.1575 - val_map_at_10: 0.1069 - val_precision_at_10: 0.0328 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 4/15
# 2194/2194 [==============================] - 54s 24ms/step - loss: 3.4637 - recall_at_10: 0.3186 - mrr_at_10: 0.0972 - ndcg_at_10: 0.1477 - map_at_10: 0.0972 - precision_at_10: 0.0319 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 0.3330 - val_mrr_at_10: 0.1115 - val_ndcg_at_10: 0.1621 - val_map_at_10: 0.1115 - val_precision_at_10: 0.0333 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 5/15
# 2194/2194 [==============================] - 48s 22ms/step - loss: 3.4638 - recall_at_10: 0.3297 - mrr_at_10: 0.1080 - ndcg_at_10: 0.1586 - map_at_10: 0.1080 - precision_at_10: 0.0330 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.3303 - val_mrr_at_10: 0.1066 - val_ndcg_at_10: 0.1577 - val_map_at_10: 0.1066 - val_precision_at_10: 0.0330 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 6/15
# 2194/2194 [==============================] - 51s 23ms/step - loss: 3.4638 - recall_at_10: 0.3429 - mrr_at_10: 0.1213 - ndcg_at_10: 0.1719 - map_at_10: 0.1213 - precision_at_10: 0.0343 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.3485 - val_mrr_at_10: 0.1227 - val_ndcg_at_10: 0.1743 - val_map_at_10: 0.1227 - val_precision_at_10: 0.0349 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 7/15
# 2194/2194 [==============================] - 51s 23ms/step - loss: 3.4637 - recall_at_10: 0.3462 - mrr_at_10: 0.1272 - ndcg_at_10: 0.1772 - map_at_10: 0.1272 - precision_at_10: 0.0346 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.3757 - val_mrr_at_10: 0.1600 - val_ndcg_at_10: 0.2088 - val_map_at_10: 0.1600 - val_precision_at_10: 0.0376 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 8/15
# 2194/2194 [==============================] - 47s 21ms/step - loss: 3.4638 - recall_at_10: 0.3692 - mrr_at_10: 0.1618 - ndcg_at_10: 0.2088 - map_at_10: 0.1618 - precision_at_10: 0.0369 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.3736 - val_mrr_at_10: 0.1615 - val_ndcg_at_10: 0.2097 - val_map_at_10: 0.1615 - val_precision_at_10: 0.0374 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 9/15
# 2194/2194 [==============================] - 47s 21ms/step - loss: 3.4638 - recall_at_10: 0.3842 - mrr_at_10: 0.1833 - ndcg_at_10: 0.2288 - map_at_10: 0.1833 - precision_at_10: 0.0384 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 0.1783 - val_mrr_at_10: 0.0230 - val_ndcg_at_10: 0.0567 - val_map_at_10: 0.0230 - val_precision_at_10: 0.0178 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 10/15
# 2194/2194 [==============================] - 51s 23ms/step - loss: 3.4637 - recall_at_10: 0.5598 - mrr_at_10: 0.3809 - ndcg_at_10: 0.4197 - map_at_10: 0.3809 - precision_at_10: 0.0560 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 0.5464 - val_ndcg_at_10: 0.6602 - val_map_at_10: 0.5464 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 11/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4637 - recall_at_10: 0.7913 - mrr_at_10: 0.5206 - ndcg_at_10: 0.5885 - map_at_10: 0.5206 - precision_at_10: 0.0791 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 12/15
# 2194/2194 [==============================] - 48s 21ms/step - loss: 3.4637 - recall_at_10: 0.7831 - mrr_at_10: 0.5440 - ndcg_at_10: 0.6040 - map_at_10: 0.5440 - precision_at_10: 0.0783 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 0.5505 - val_ndcg_at_10: 0.6633 - val_map_at_10: 0.5505 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 13/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4638 - recall_at_10: 0.7634 - mrr_at_10: 0.5298 - ndcg_at_10: 0.5885 - map_at_10: 0.5298 - precision_at_10: 0.0763 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 14/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4637 - recall_at_10: 0.6472 - mrr_at_10: 0.5344 - ndcg_at_10: 0.5627 - map_at_10: 0.5344 - precision_at_10: 0.0647 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 15/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4637 - recall_at_10: 0.6557 - mrr_at_10: 0.5216 - ndcg_at_10: 0.5552 - map_at_10: 0.5216 - precision_at_10: 0.0656 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 0.5509 - val_ndcg_at_10: 0.6636 - val_map_at_10: 0.5509 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815

# %%
_history = merge_model_history(history_v7_1)
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history)

# %% [markdown]
# ### model_v8

# %%
model_v8 = build_towers(tower_dim=256)
TOK_K = [10]
model_v8.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-2),
                 run_eagerly=False, metrics=[mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %%
history_v8_1 = model_v8.fit(train, validation_data=valid, batch_size=32, epochs=15, validation_batch_size=256)
# Out:
# Epoch 1/15
# 2194/2194 [==============================] - 59s 24ms/step - loss: 3.4654 - recall_at_10: 0.3128 - mrr_at_10: 0.0924 - ndcg_at_10: 0.1427 - map_at_10: 0.0924 - precision_at_10: 0.0313 - regularization_loss: 0.0000e+00 - loss_batch: 3.4652 - val_loss: 3.4636 - val_recall_at_10: 0.3135 - val_mrr_at_10: 0.0924 - val_ndcg_at_10: 0.1429 - val_map_at_10: 0.0924 - val_precision_at_10: 0.0313 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 2/15
# 2194/2194 [==============================] - 53s 24ms/step - loss: 4.6086 - recall_at_10: 0.3304 - mrr_at_10: 0.1152 - ndcg_at_10: 0.1642 - map_at_10: 0.1152 - precision_at_10: 0.0330 - regularization_loss: 0.0000e+00 - loss_batch: 4.6078 - val_loss: 3.4634 - val_recall_at_10: 6.6872e-04 - val_mrr_at_10: 6.8358e-05 - val_ndcg_at_10: 1.9490e-04 - val_map_at_10: 6.8358e-05 - val_precision_at_10: 6.6872e-05 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 3/15
# 2194/2194 [==============================] - 46s 20ms/step - loss: 3.4638 - recall_at_10: 0.4959 - mrr_at_10: 0.4383 - ndcg_at_10: 0.4515 - map_at_10: 0.4383 - precision_at_10: 0.0496 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4634 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 4/15
# 2194/2194 [==============================] - 53s 24ms/step - loss: 3.4637 - recall_at_10: 0.6641 - mrr_at_10: 0.6641 - ndcg_at_10: 0.6641 - map_at_10: 0.6641 - precision_at_10: 0.0664 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4634 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 5/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4637 - recall_at_10: 0.7243 - mrr_at_10: 0.7243 - ndcg_at_10: 0.7243 - map_at_10: 0.7243 - precision_at_10: 0.0724 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4634 - val_recall_at_10: 1.0000 - val_mrr_at_10: 0.9994 - val_ndcg_at_10: 0.9995 - val_map_at_10: 0.9994 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 6/15
# 2194/2194 [==============================] - 51s 23ms/step - loss: 3.4637 - recall_at_10: 0.7628 - mrr_at_10: 0.7628 - ndcg_at_10: 0.7628 - map_at_10: 0.7628 - precision_at_10: 0.0763 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 6.6872e-04 - val_mrr_at_10: 6.8358e-05 - val_ndcg_at_10: 1.9490e-04 - val_map_at_10: 6.8358e-05 - val_precision_at_10: 6.6872e-05 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 7/15
# 2194/2194 [==============================] - 47s 21ms/step - loss: 3.4637 - recall_at_10: 0.7626 - mrr_at_10: 0.7626 - ndcg_at_10: 0.7626 - map_at_10: 0.7626 - precision_at_10: 0.0763 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4637 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 8/15
# 2194/2194 [==============================] - 50s 23ms/step - loss: 3.4638 - recall_at_10: 0.7573 - mrr_at_10: 0.7573 - ndcg_at_10: 0.7573 - map_at_10: 0.7573 - precision_at_10: 0.0757 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 9/15
# 2194/2194 [==============================] - 50s 22ms/step - loss: 3.4637 - recall_at_10: 0.7380 - mrr_at_10: 0.7380 - ndcg_at_10: 0.7380 - map_at_10: 0.7380 - precision_at_10: 0.0738 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 6.6872e-04 - val_mrr_at_10: 6.6872e-04 - val_ndcg_at_10: 6.6872e-04 - val_map_at_10: 6.6872e-04 - val_precision_at_10: 6.6872e-05 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 10/15
# 2194/2194 [==============================] - 50s 22ms/step - loss: 3.4638 - recall_at_10: 0.7247 - mrr_at_10: 0.7247 - ndcg_at_10: 0.7247 - map_at_10: 0.7247 - precision_at_10: 0.0725 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 11/15
# 2194/2194 [==============================] - 47s 21ms/step - loss: 3.4637 - recall_at_10: 0.7337 - mrr_at_10: 0.7337 - ndcg_at_10: 0.7337 - map_at_10: 0.7337 - precision_at_10: 0.0734 - regularization_loss: 0.0000e+00 - loss_batch: 3.4635 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 0.9994 - val_ndcg_at_10: 0.9995 - val_map_at_10: 0.9994 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 12/15
# 2194/2194 [==============================] - 49s 22ms/step - loss: 3.4638 - recall_at_10: 0.7173 - mrr_at_10: 0.7173 - ndcg_at_10: 0.7173 - map_at_10: 0.7173 - precision_at_10: 0.0717 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4636 - val_recall_at_10: 6.6872e-04 - val_mrr_at_10: 6.8358e-05 - val_ndcg_at_10: 1.9490e-04 - val_map_at_10: 6.8358e-05 - val_precision_at_10: 6.6872e-05 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 13/15
# 2194/2194 [==============================] - 44s 20ms/step - loss: 3.4637 - recall_at_10: 0.7267 - mrr_at_10: 0.7267 - ndcg_at_10: 0.7267 - map_at_10: 0.7267 - precision_at_10: 0.0727 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4637 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 14/15
# 2194/2194 [==============================] - 47s 21ms/step - loss: 3.4637 - recall_at_10: 0.7436 - mrr_at_10: 0.7436 - ndcg_at_10: 0.7436 - map_at_10: 0.7436 - precision_at_10: 0.0744 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4637 - val_recall_at_10: 6.6872e-04 - val_mrr_at_10: 6.8358e-05 - val_ndcg_at_10: 1.9490e-04 - val_map_at_10: 6.8358e-05 - val_precision_at_10: 6.6872e-05 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815
# Epoch 15/15
# 2194/2194 [==============================] - 50s 22ms/step - loss: 3.4638 - recall_at_10: 0.6928 - mrr_at_10: 0.6928 - ndcg_at_10: 0.6928 - map_at_10: 0.6928 - precision_at_10: 0.0693 - regularization_loss: 0.0000e+00 - loss_batch: 3.4636 - val_loss: 3.4635 - val_recall_at_10: 1.0000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 1.0000 - val_map_at_10: 1.0000 - val_precision_at_10: 0.1000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 2.2815

# %%
_history = merge_model_history(history_v8_1)
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history)

# %% [markdown]
# ### model_v9

# %%
# _tower_dim = (64, 128) # @param
_tower_dim = (32, 16) # @param
_learning_rate = 0.01 # @param
_batch_size = 512 # @param
_epochs = 15 # @param
_validation_batch_size = 256 # @param

# %%
model_v9 = build_towers(train.schema, tower_dim=_tower_dim)
TOP_K = [10]
model_v9.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[ tf.keras.metrics.AUC(),
                                             mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)
                                            ],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True,
                                                            #  reduction=tf.keras.losses.Reduction.SUM # https://github.com/tensorflow/recommenders/blob/v0.7.3/tensorflow_recommenders/tasks/retrieval.py#L84
                                                             ),
)
history_v9 = []

# %% [markdown]
# #### model

# %%
history_v9.append(model_v9.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size))
# Out:
# Epoch 1/15
# 138/138 [==============================] - 8s 51ms/step - loss: 5.5130 - auc: 0.6830 - recall_at_10: 0.1531 - mrr_at_10: 0.0639 - ndcg_at_10: 0.0846 - map_at_10: 0.0639 - precision_at_10: 0.0153 - regularization_loss: 0.0000e+00 - loss_batch: 5.4698 - val_loss: 6.1776 - val_auc: 0.5917 - val_recall_at_10: 0.0651 - val_mrr_at_10: 0.0197 - val_ndcg_at_10: 0.0301 - val_map_at_10: 0.0197 - val_precision_at_10: 0.0065 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7499
# Epoch 2/15
# 138/138 [==============================] - 4s 23ms/step - loss: 5.5094 - auc: 0.6836 - recall_at_10: 0.1569 - mrr_at_10: 0.0651 - ndcg_at_10: 0.0863 - map_at_10: 0.0651 - precision_at_10: 0.0157 - regularization_loss: 0.0000e+00 - loss_batch: 5.4661 - val_loss: 6.2424 - val_auc: 0.5897 - val_recall_at_10: 0.0659 - val_mrr_at_10: 0.0202 - val_ndcg_at_10: 0.0307 - val_map_at_10: 0.0202 - val_precision_at_10: 0.0066 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.8884
# Epoch 3/15
# 138/138 [==============================] - 5s 31ms/step - loss: 5.5079 - auc: 0.6841 - recall_at_10: 0.1546 - mrr_at_10: 0.0642 - ndcg_at_10: 0.0852 - map_at_10: 0.0642 - precision_at_10: 0.0155 - regularization_loss: 0.0000e+00 - loss_batch: 5.4643 - val_loss: 6.2153 - val_auc: 0.5973 - val_recall_at_10: 0.0627 - val_mrr_at_10: 0.0197 - val_ndcg_at_10: 0.0296 - val_map_at_10: 0.0197 - val_precision_at_10: 0.0063 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7909
# Epoch 4/15
# 138/138 [==============================] - 5s 32ms/step - loss: 5.5079 - auc: 0.6830 - recall_at_10: 0.1568 - mrr_at_10: 0.0669 - ndcg_at_10: 0.0877 - map_at_10: 0.0669 - precision_at_10: 0.0157 - regularization_loss: 0.0000e+00 - loss_batch: 5.4644 - val_loss: 6.2335 - val_auc: 0.5827 - val_recall_at_10: 0.0630 - val_mrr_at_10: 0.0198 - val_ndcg_at_10: 0.0297 - val_map_at_10: 0.0198 - val_precision_at_10: 0.0063 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7419
# Epoch 5/15
# 138/138 [==============================] - 4s 24ms/step - loss: 5.5050 - auc: 0.6831 - recall_at_10: 0.1559 - mrr_at_10: 0.0655 - ndcg_at_10: 0.0865 - map_at_10: 0.0655 - precision_at_10: 0.0156 - regularization_loss: 0.0000e+00 - loss_batch: 5.4613 - val_loss: 6.2147 - val_auc: 0.5932 - val_recall_at_10: 0.0627 - val_mrr_at_10: 0.0195 - val_ndcg_at_10: 0.0294 - val_map_at_10: 0.0195 - val_precision_at_10: 0.0063 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.6846
# Epoch 6/15
# 138/138 [==============================] - 4s 24ms/step - loss: 5.5031 - auc: 0.6802 - recall_at_10: 0.1565 - mrr_at_10: 0.0660 - ndcg_at_10: 0.0869 - map_at_10: 0.0660 - precision_at_10: 0.0156 - regularization_loss: 0.0000e+00 - loss_batch: 5.4592 - val_loss: 6.2518 - val_auc: 0.5983 - val_recall_at_10: 0.0621 - val_mrr_at_10: 0.0193 - val_ndcg_at_10: 0.0291 - val_map_at_10: 0.0193 - val_precision_at_10: 0.0062 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.6771
# Epoch 7/15
# 138/138 [==============================] - 5s 33ms/step - loss: 5.5018 - auc: 0.6825 - recall_at_10: 0.1581 - mrr_at_10: 0.0674 - ndcg_at_10: 0.0884 - map_at_10: 0.0674 - precision_at_10: 0.0158 - regularization_loss: 0.0000e+00 - loss_batch: 5.4583 - val_loss: 6.2349 - val_auc: 0.5929 - val_recall_at_10: 0.0621 - val_mrr_at_10: 0.0183 - val_ndcg_at_10: 0.0283 - val_map_at_10: 0.0183 - val_precision_at_10: 0.0062 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.6560
# Epoch 8/15
# 138/138 [==============================] - 5s 28ms/step - loss: 5.5004 - auc: 0.6820 - recall_at_10: 0.1598 - mrr_at_10: 0.0675 - ndcg_at_10: 0.0889 - map_at_10: 0.0675 - precision_at_10: 0.0160 - regularization_loss: 0.0000e+00 - loss_batch: 5.4563 - val_loss: 6.2612 - val_auc: 0.5862 - val_recall_at_10: 0.0624 - val_mrr_at_10: 0.0191 - val_ndcg_at_10: 0.0290 - val_map_at_10: 0.0191 - val_precision_at_10: 0.0062 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7055
# Epoch 9/15
# 138/138 [==============================] - 4s 23ms/step - loss: 5.4986 - auc: 0.6816 - recall_at_10: 0.1603 - mrr_at_10: 0.0668 - ndcg_at_10: 0.0884 - map_at_10: 0.0668 - precision_at_10: 0.0160 - regularization_loss: 0.0000e+00 - loss_batch: 5.4539 - val_loss: 6.2710 - val_auc: 0.5924 - val_recall_at_10: 0.0639 - val_mrr_at_10: 0.0204 - val_ndcg_at_10: 0.0303 - val_map_at_10: 0.0204 - val_precision_at_10: 0.0064 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7967
# Epoch 10/15
# 138/138 [==============================] - 4s 23ms/step - loss: 5.4976 - auc: 0.6807 - recall_at_10: 0.1577 - mrr_at_10: 0.0664 - ndcg_at_10: 0.0876 - map_at_10: 0.0664 - precision_at_10: 0.0158 - regularization_loss: 0.0000e+00 - loss_batch: 5.4533 - val_loss: 6.2641 - val_auc: 0.5838 - val_recall_at_10: 0.0651 - val_mrr_at_10: 0.0200 - val_ndcg_at_10: 0.0303 - val_map_at_10: 0.0200 - val_precision_at_10: 0.0065 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7938
# Epoch 11/15
# 138/138 [==============================] - 6s 38ms/step - loss: 5.4923 - auc: 0.6803 - recall_at_10: 0.1576 - mrr_at_10: 0.0669 - ndcg_at_10: 0.0879 - map_at_10: 0.0669 - precision_at_10: 0.0158 - regularization_loss: 0.0000e+00 - loss_batch: 5.4483 - val_loss: 6.2531 - val_auc: 0.5813 - val_recall_at_10: 0.0637 - val_mrr_at_10: 0.0197 - val_ndcg_at_10: 0.0298 - val_map_at_10: 0.0197 - val_precision_at_10: 0.0064 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.9579
# Epoch 12/15
# 138/138 [==============================] - 4s 24ms/step - loss: 5.4936 - auc: 0.6795 - recall_at_10: 0.1614 - mrr_at_10: 0.0686 - ndcg_at_10: 0.0901 - map_at_10: 0.0686 - precision_at_10: 0.0161 - regularization_loss: 0.0000e+00 - loss_batch: 5.4499 - val_loss: 6.2687 - val_auc: 0.5835 - val_recall_at_10: 0.0644 - val_mrr_at_10: 0.0189 - val_ndcg_at_10: 0.0293 - val_map_at_10: 0.0189 - val_precision_at_10: 0.0064 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.7713
# Epoch 13/15
# 138/138 [==============================] - 5s 29ms/step - loss: 5.4922 - auc: 0.6797 - recall_at_10: 0.1587 - mrr_at_10: 0.0680 - ndcg_at_10: 0.0890 - map_at_10: 0.0680 - precision_at_10: 0.0159 - regularization_loss: 0.0000e+00 - loss_batch: 5.4476 - val_loss: 6.2527 - val_auc: 0.5884 - val_recall_at_10: 0.0639 - val_mrr_at_10: 0.0195 - val_ndcg_at_10: 0.0296 - val_map_at_10: 0.0195 - val_precision_at_10: 0.0064 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.8024
# Epoch 14/15
# 138/138 [==============================] - 6s 34ms/step - loss: 5.4906 - auc: 0.6776 - recall_at_10: 0.1600 - mrr_at_10: 0.0667 - ndcg_at_10: 0.0883 - map_at_10: 0.0667 - precision_at_10: 0.0160 - regularization_loss: 0.0000e+00 - loss_batch: 5.4461 - val_loss: 6.2559 - val_auc: 0.5888 - val_recall_at_10: 0.0657 - val_mrr_at_10: 0.0203 - val_ndcg_at_10: 0.0307 - val_map_at_10: 0.0203 - val_precision_at_10: 0.0066 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.4245
# Epoch 15/15
# 138/138 [==============================] - 4s 23ms/step - loss: 5.4892 - auc: 0.6805 - recall_at_10: 0.1621 - mrr_at_10: 0.0686 - ndcg_at_10: 0.0903 - map_at_10: 0.0686 - precision_at_10: 0.0162 - regularization_loss: 0.0000e+00 - loss_batch: 5.4449 - val_loss: 6.2629 - val_auc: 0.5835 - val_recall_at_10: 0.0607 - val_mrr_at_10: 0.0175 - val_ndcg_at_10: 0.0274 - val_map_at_10: 0.0175 - val_precision_at_10: 0.0061 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.5530

# %%
model_v9.evaluate(train, batch_size=2048, return_dict=True), model_v9.evaluate(valid, batch_size=2048, return_dict=True)
# Out:
# 35/35 [==============================] - 2s 35ms/step - loss: 6.8109 - auc: 0.6856 - recall_at_10: 0.0760 - mrr_at_10: 0.0342 - ndcg_at_10: 0.0439 - map_at_10: 0.0342 - precision_at_10: 0.0076 - regularization_loss: 0.0000e+00 - loss_batch: 6.7455
# 8/8 [==============================] - 1s 37ms/step - loss: 7.6332 - auc: 0.5752 - recall_at_10: 0.0250 - mrr_at_10: 0.0185 - ndcg_at_10: 0.0200 - map_at_10: 0.0185 - precision_at_10: 0.0025 - regularization_loss: 0.0000e+00 - loss_batch: 7.4959
# ({'loss': 6.810889720916748,
#   'auc': 0.6855550408363342,
#   'recall_at_10': 0.076351098716259,
#   'mrr_at_10': 0.0342133566737175,
#   'ndcg_at_10': 0.04399328678846359,
#   'map_at_10': 0.0342133566737175,
#   'precision_at_10': 0.007635110057890415,
#   'regularization_loss': 0.0,
#   'loss_batch': 5.444518089294434},
#  {'loss': 7.633225440979004,
#   'auc': 0.5752266645431519,
#   'recall_at_10': 0.024675672873854637,
#   'mrr_at_10': 0.01596427522599697,
#   'ndcg_at_10': 0.01793855056166649,
#   'map_at_10': 0.01596427522599697,
#   'precision_at_10': 0.0024675673339515924,
#   'regularization_loss': 0.0,
#   'loss_batch': 6.905421257019043})

# %%
evaluate_model(model_v9, train, topk=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1561
# WARNING:absl:Found untraced functions such as prepare_list_features_1_layer_call_fn, prepare_list_features_1_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_1_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 69/69 [==============================] - 6s 33ms/step - loss: 0.8575 - auc_37: 0.4434 - recall_at_50: 0.2155 - mrr_at_50: 0.0239 - ndcg_at_50: 0.0598 - map_at_50: 0.0239 - precision_at_50: 0.0043 - regularization_loss: 0.0000e+00 - loss_batch: 0.8588
# {'loss': 0.8574756383895874,
#  'auc_37': 0.4434165358543396,
#  'recall_at_50': 0.21393977105617523,
#  'mrr_at_50': 0.02422141842544079,
#  'ndcg_at_50': 0.05979929119348526,
#  'map_at_50': 0.02422141842544079,
#  'precision_at_50': 0.0042787957936525345,
#  'regularization_loss': 0.0,
#  'loss_batch': 0.922325074672699}

# %%
evaluate_model(model_v9, valid, topk=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1338
# WARNING:absl:Found untraced functions such as prepare_list_features_1_layer_call_fn, prepare_list_features_1_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_1_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# 15/15 [==============================] - 3s 22ms/step - loss: 0.3891 - auc_38: 0.4386 - recall_at_50: 0.0875 - mrr_at_50: 0.0055 - ndcg_at_50: 0.0203 - map_at_50: 0.0055 - precision_at_50: 0.0018 - regularization_loss: 0.0000e+00 - loss_batch: 0.4226
# {'loss': 0.3890545070171356,
#  'auc_38': 0.4385528564453125,
#  'recall_at_50': 0.09275110065937042,
#  'mrr_at_50': 0.005984900519251823,
#  'ndcg_at_50': 0.021685531362891197,
#  'map_at_50': 0.005984900519251823,
#  'precision_at_50': 0.0018550221575424075,
#  'regularization_loss': 0.0,
#  'loss_batch': 0.7731633186340332}

# %% [markdown]
# #### result

# %%
_history = merge_model_history(*history_v9)
AUC_TERM = [k for k in _history if k.startswith('auc')][0]
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': AUC_TERM})

# %% [markdown]
# ### model_v10

# %%
_tower_dim = (128, 256) # @param
_learning_rate = 0.02 # @param
_batch_size = 256 # @param
_epochs = 15 # @param
_validation_batch_size = 256 # @param

# %% [markdown]
# #### model

# %%
model_v10 = build_towers(tower_dim=_tower_dim)
TOP_K = [10]
model_v10.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=_learning_rate),
                 run_eagerly=False, metrics=[mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K), tf.keras.metrics.AUC()],
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)
history_v10 = []

# %%
history_v10.append(model_v10.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size))
# Out:
# Epoch 1/15
# 275/275 [==============================] - 27s 70ms/step - loss: 5.4767 - recall_at_10: 0.0536 - mrr_at_10: 0.0172 - ndcg_at_10: 0.0255 - map_at_10: 0.0172 - precision_at_10: 0.0054 - auc_4: 0.5478 - regularization_loss: 0.0000e+00 - loss_batch: 5.4666 - val_loss: 5.4253 - val_recall_at_10: 0.0799 - val_mrr_at_10: 0.0251 - val_ndcg_at_10: 0.0376 - val_map_at_10: 0.0251 - val_precision_at_10: 0.0080 - val_auc_4: 0.5684 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.6923
# Epoch 2/15
# 275/275 [==============================] - 7s 25ms/step - loss: 5.3075 - recall_at_10: 0.0940 - mrr_at_10: 0.0290 - ndcg_at_10: 0.0439 - map_at_10: 0.0290 - precision_at_10: 0.0094 - auc_4: 0.6071 - regularization_loss: 0.0000e+00 - loss_batch: 5.2976 - val_loss: 5.3775 - val_recall_at_10: 0.0865 - val_mrr_at_10: 0.0263 - val_ndcg_at_10: 0.0401 - val_map_at_10: 0.0263 - val_precision_at_10: 0.0087 - val_auc_4: 0.5764 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.6013
# Epoch 3/15
# 275/275 [==============================] - 10s 32ms/step - loss: 5.2550 - recall_at_10: 0.1053 - mrr_at_10: 0.0337 - ndcg_at_10: 0.0501 - map_at_10: 0.0337 - precision_at_10: 0.0105 - auc_4: 0.6175 - regularization_loss: 0.0000e+00 - loss_batch: 5.2454 - val_loss: 5.3534 - val_recall_at_10: 0.0998 - val_mrr_at_10: 0.0310 - val_ndcg_at_10: 0.0467 - val_map_at_10: 0.0310 - val_precision_at_10: 0.0100 - val_auc_4: 0.5791 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7660
# Epoch 4/15
# 275/275 [==============================] - 7s 23ms/step - loss: 5.2381 - recall_at_10: 0.1073 - mrr_at_10: 0.0346 - ndcg_at_10: 0.0513 - map_at_10: 0.0346 - precision_at_10: 0.0107 - auc_4: 0.6205 - regularization_loss: 0.0000e+00 - loss_batch: 5.2292 - val_loss: 5.3343 - val_recall_at_10: 0.1019 - val_mrr_at_10: 0.0310 - val_ndcg_at_10: 0.0473 - val_map_at_10: 0.0310 - val_precision_at_10: 0.0102 - val_auc_4: 0.5819 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.7601
# Epoch 5/15
# 275/275 [==============================] - 9s 28ms/step - loss: 5.2391 - recall_at_10: 0.1132 - mrr_at_10: 0.0373 - ndcg_at_10: 0.0547 - map_at_10: 0.0373 - precision_at_10: 0.0113 - auc_4: 0.6153 - regularization_loss: 0.0000e+00 - loss_batch: 5.2314 - val_loss: 5.5753 - val_recall_at_10: 0.0566 - val_mrr_at_10: 0.0170 - val_ndcg_at_10: 0.0261 - val_map_at_10: 0.0170 - val_precision_at_10: 0.0057 - val_auc_4: 0.5352 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 5.0215
# Epoch 6/15
# 275/275 [==============================] - 6s 20ms/step - loss: 5.5519 - recall_at_10: 0.0986 - mrr_at_10: 0.0785 - ndcg_at_10: 0.0831 - map_at_10: 0.0785 - precision_at_10: 0.0099 - auc_4: 0.5008 - regularization_loss: 0.0000e+00 - loss_batch: 5.5422 - val_loss: 5.5370 - val_recall_at_10: 0.5708 - val_mrr_at_10: 0.5665 - val_ndcg_at_10: 0.5674 - val_map_at_10: 0.5665 - val_precision_at_10: 0.0571 - val_auc_4: 0.5000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 7/15
# 275/275 [==============================] - 15s 51ms/step - loss: 5.5419 - recall_at_10: 0.2970 - mrr_at_10: 0.2914 - ndcg_at_10: 0.2926 - map_at_10: 0.2914 - precision_at_10: 0.0297 - auc_4: 0.5000 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.8665 - val_mrr_at_10: 0.8590 - val_ndcg_at_10: 0.8606 - val_map_at_10: 0.8590 - val_precision_at_10: 0.0866 - val_auc_4: 0.5000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 8/15
# 275/275 [==============================] - 9s 31ms/step - loss: 5.5420 - recall_at_10: 0.4524 - mrr_at_10: 0.3885 - ndcg_at_10: 0.4022 - map_at_10: 0.3885 - precision_at_10: 0.0452 - auc_4: 0.5000 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9189 - val_mrr_at_10: 0.9173 - val_ndcg_at_10: 0.9176 - val_map_at_10: 0.9173 - val_precision_at_10: 0.0919 - val_auc_4: 0.5000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 9/15
# 275/275 [==============================] - 6s 20ms/step - loss: 5.5419 - recall_at_10: 0.7493 - mrr_at_10: 0.7490 - ndcg_at_10: 0.7491 - map_at_10: 0.7490 - precision_at_10: 0.0749 - auc_4: 0.5000 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9234 - val_mrr_at_10: 0.9234 - val_ndcg_at_10: 0.9234 - val_map_at_10: 0.9234 - val_precision_at_10: 0.0923 - val_auc_4: 0.5000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 10/15
# 275/275 [==============================] - 10s 33ms/step - loss: 5.5419 - recall_at_10: 0.7949 - mrr_at_10: 0.7948 - ndcg_at_10: 0.7949 - map_at_10: 0.7948 - precision_at_10: 0.0795 - auc_4: 0.5001 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9004 - val_mrr_at_10: 0.8955 - val_ndcg_at_10: 0.8965 - val_map_at_10: 0.8955 - val_precision_at_10: 0.0900 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 11/15
# 275/275 [==============================] - 6s 21ms/step - loss: 5.5419 - recall_at_10: 0.7683 - mrr_at_10: 0.7639 - ndcg_at_10: 0.7648 - map_at_10: 0.7639 - precision_at_10: 0.0768 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.8950 - val_mrr_at_10: 0.8904 - val_ndcg_at_10: 0.8914 - val_map_at_10: 0.8904 - val_precision_at_10: 0.0895 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 12/15
# 275/275 [==============================] - 7s 25ms/step - loss: 5.5419 - recall_at_10: 0.7412 - mrr_at_10: 0.7368 - ndcg_at_10: 0.7377 - map_at_10: 0.7368 - precision_at_10: 0.0741 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9012 - val_mrr_at_10: 0.8956 - val_ndcg_at_10: 0.8968 - val_map_at_10: 0.8956 - val_precision_at_10: 0.0901 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 13/15
# 275/275 [==============================] - 8s 25ms/step - loss: 5.5419 - recall_at_10: 0.7286 - mrr_at_10: 0.7237 - ndcg_at_10: 0.7247 - map_at_10: 0.7237 - precision_at_10: 0.0729 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9168 - val_mrr_at_10: 0.9128 - val_ndcg_at_10: 0.9137 - val_map_at_10: 0.9128 - val_precision_at_10: 0.0917 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 14/15
# 275/275 [==============================] - 8s 27ms/step - loss: 5.5420 - recall_at_10: 0.7437 - mrr_at_10: 0.7392 - ndcg_at_10: 0.7402 - map_at_10: 0.7392 - precision_at_10: 0.0744 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9006 - val_mrr_at_10: 0.8958 - val_ndcg_at_10: 0.8968 - val_map_at_10: 0.8958 - val_precision_at_10: 0.0901 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 15/15
# 275/275 [==============================] - 6s 22ms/step - loss: 5.5420 - recall_at_10: 0.7355 - mrr_at_10: 0.7304 - ndcg_at_10: 0.7315 - map_at_10: 0.7304 - precision_at_10: 0.0735 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.1518 - val_mrr_at_10: 0.1475 - val_ndcg_at_10: 0.1484 - val_map_at_10: 0.1475 - val_precision_at_10: 0.0152 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984

# %%
history_v10.append(model_v10.fit(train, validation_data=valid, batch_size=_batch_size, epochs=_epochs, validation_batch_size=_validation_batch_size))
# Out:
# Epoch 1/15
# 275/275 [==============================] - 10s 34ms/step - loss: 5.5419 - recall_at_10: 0.6959 - mrr_at_10: 0.6916 - ndcg_at_10: 0.6925 - map_at_10: 0.6916 - precision_at_10: 0.0696 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9126 - val_mrr_at_10: 0.9088 - val_ndcg_at_10: 0.9096 - val_map_at_10: 0.9088 - val_precision_at_10: 0.0913 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 2/15
# 275/275 [==============================] - 6s 20ms/step - loss: 5.5419 - recall_at_10: 0.7043 - mrr_at_10: 0.7004 - ndcg_at_10: 0.7013 - map_at_10: 0.7004 - precision_at_10: 0.0704 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.1511 - val_mrr_at_10: 0.1449 - val_ndcg_at_10: 0.1462 - val_map_at_10: 0.1449 - val_precision_at_10: 0.0151 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 3/15
# 275/275 [==============================] - 9s 31ms/step - loss: 5.5419 - recall_at_10: 0.7261 - mrr_at_10: 0.7225 - ndcg_at_10: 0.7233 - map_at_10: 0.7225 - precision_at_10: 0.0726 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9105 - val_mrr_at_10: 0.9077 - val_ndcg_at_10: 0.9083 - val_map_at_10: 0.9077 - val_precision_at_10: 0.0911 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 4/15
# 275/275 [==============================] - 7s 22ms/step - loss: 5.5420 - recall_at_10: 0.7394 - mrr_at_10: 0.7361 - ndcg_at_10: 0.7368 - map_at_10: 0.7361 - precision_at_10: 0.0739 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9222 - val_mrr_at_10: 0.9184 - val_ndcg_at_10: 0.9192 - val_map_at_10: 0.9184 - val_precision_at_10: 0.0922 - val_auc_4: 0.5002 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 5/15
# 275/275 [==============================] - 9s 30ms/step - loss: 5.5420 - recall_at_10: 0.7682 - mrr_at_10: 0.7640 - ndcg_at_10: 0.7649 - map_at_10: 0.7640 - precision_at_10: 0.0768 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9201 - val_mrr_at_10: 0.9143 - val_ndcg_at_10: 0.9156 - val_map_at_10: 0.9143 - val_precision_at_10: 0.0920 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 6/15
# 275/275 [==============================] - 6s 22ms/step - loss: 5.5419 - recall_at_10: 0.7446 - mrr_at_10: 0.7415 - ndcg_at_10: 0.7421 - map_at_10: 0.7415 - precision_at_10: 0.0745 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9309 - val_mrr_at_10: 0.9281 - val_ndcg_at_10: 0.9287 - val_map_at_10: 0.9281 - val_precision_at_10: 0.0931 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 7/15
# 275/275 [==============================] - 10s 34ms/step - loss: 5.5419 - recall_at_10: 0.7692 - mrr_at_10: 0.7655 - ndcg_at_10: 0.7663 - map_at_10: 0.7655 - precision_at_10: 0.0769 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9316 - val_mrr_at_10: 0.9277 - val_ndcg_at_10: 0.9285 - val_map_at_10: 0.9277 - val_precision_at_10: 0.0932 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 8/15
# 275/275 [==============================] - 6s 20ms/step - loss: 5.5420 - recall_at_10: 0.7232 - mrr_at_10: 0.7198 - ndcg_at_10: 0.7206 - map_at_10: 0.7198 - precision_at_10: 0.0723 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9161 - val_mrr_at_10: 0.9123 - val_ndcg_at_10: 0.9131 - val_map_at_10: 0.9123 - val_precision_at_10: 0.0916 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 9/15
# 275/275 [==============================] - 8s 27ms/step - loss: 5.5419 - recall_at_10: 0.7454 - mrr_at_10: 0.7424 - ndcg_at_10: 0.7430 - map_at_10: 0.7424 - precision_at_10: 0.0745 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.1183 - val_mrr_at_10: 0.1154 - val_ndcg_at_10: 0.1160 - val_map_at_10: 0.1154 - val_precision_at_10: 0.0118 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 10/15
# 275/275 [==============================] - 7s 23ms/step - loss: 5.5419 - recall_at_10: 0.7232 - mrr_at_10: 0.7200 - ndcg_at_10: 0.7207 - map_at_10: 0.7200 - precision_at_10: 0.0723 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9331 - val_mrr_at_10: 0.9298 - val_ndcg_at_10: 0.9305 - val_map_at_10: 0.9298 - val_precision_at_10: 0.0933 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 11/15
# 275/275 [==============================] - 8s 27ms/step - loss: 5.5419 - recall_at_10: 0.6940 - mrr_at_10: 0.6909 - ndcg_at_10: 0.6916 - map_at_10: 0.6909 - precision_at_10: 0.0694 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9256 - val_mrr_at_10: 0.9229 - val_ndcg_at_10: 0.9235 - val_map_at_10: 0.9229 - val_precision_at_10: 0.0926 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 12/15
# 275/275 [==============================] - 7s 24ms/step - loss: 5.5419 - recall_at_10: 0.7514 - mrr_at_10: 0.7489 - ndcg_at_10: 0.7494 - map_at_10: 0.7489 - precision_at_10: 0.0751 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.9261 - val_mrr_at_10: 0.9224 - val_ndcg_at_10: 0.9232 - val_map_at_10: 0.9224 - val_precision_at_10: 0.0926 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 13/15
# 275/275 [==============================] - 7s 22ms/step - loss: 5.5419 - recall_at_10: 0.7202 - mrr_at_10: 0.7173 - ndcg_at_10: 0.7179 - map_at_10: 0.7173 - precision_at_10: 0.0720 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.9282 - val_mrr_at_10: 0.9240 - val_ndcg_at_10: 0.9249 - val_map_at_10: 0.9240 - val_precision_at_10: 0.0928 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 14/15
# 275/275 [==============================] - 7s 22ms/step - loss: 5.5419 - recall_at_10: 0.7054 - mrr_at_10: 0.7019 - ndcg_at_10: 0.7027 - map_at_10: 0.7019 - precision_at_10: 0.0705 - auc_4: 0.5003 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5371 - val_recall_at_10: 0.1042 - val_mrr_at_10: 0.1022 - val_ndcg_at_10: 0.1027 - val_map_at_10: 0.1022 - val_precision_at_10: 0.0104 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984
# Epoch 15/15
# 275/275 [==============================] - 10s 34ms/step - loss: 5.5419 - recall_at_10: 0.6421 - mrr_at_10: 0.6393 - ndcg_at_10: 0.6399 - map_at_10: 0.6393 - precision_at_10: 0.0642 - auc_4: 0.5002 - regularization_loss: 0.0000e+00 - loss_batch: 5.5324 - val_loss: 5.5370 - val_recall_at_10: 0.1105 - val_mrr_at_10: 0.1073 - val_ndcg_at_10: 0.1080 - val_map_at_10: 0.1073 - val_precision_at_10: 0.0111 - val_auc_4: 0.5001 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 4.5984

# %% [markdown]
# #### result

# %%
_history = merge_model_history(*history_v10)
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': 'auc_4'})

# %%
_history = merge_model_history(*history_v10)
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': 'auc_2'})

# %% [markdown]
# ## Evaluate the Model top-k results

# %%
from merlin.models.tf import PopularityBasedSamplerV2

# %%
# Out:
# 1562.0

# %%
sampler = PopularityBasedSamplerV2(max_id=train.schema['movie_id'].properties['embedding_sizes']['cardinality'],
                         min_id=1, max_num_samples=10)
sampler.cal()
# Out:
# PopularityBasedSamplerV2()

# %%
sampler.sample()

# %%
train_df = train.to_ddf().compute()
x,y = None, None
values = train_df[['movie_id']].value_counts().sort_index().values
x = values[0]
for y in values[1:]:
    if y > x:
        print('f')
    x = y

# %%
# Out:
# array([491, 453, 451, ...,   1,   1,   1])

# %%
sampler.sample

# %% [markdown]
# ### generate recommendations

# %%
valid_df = valid.to_ddf().compute()
train_df = train.to_ddf().compute()

# %%
def recommend_for_user_id(uid, data, topk_model):
    prepare_ds = merlin.io.Dataset(data[data['user_id'] == uid])
    # prepare_ds.schema = valid.schema
    eval_loader = mm.Loader(prepare_ds, batch_size=1)

    batch = next(iter(eval_loader))
    recs = topk_model(inputs=batch[0], return_dict=True)[1].numpy()[0]
    return recs

def recommend_for_movie_id(mid, data, topk_model):
    prepare_ds = merlin.io.Dataset(data[data['movie_id'] == mid])
    # prepare_ds.schema = valid.schema
    eval_loader = mm.Loader(prepare_ds, batch_size=1)

    batch = next(iter(eval_loader))
    recs = topk_model(inputs=batch[0], return_dict=True)[1].numpy()[0]
    return recs

# %%
candidate_features = get_candidates(valid)
topk = 100
batch_size=1024
model = model_v6

topk_model = to_top_k_encoder(model, candidate_features, k=topk, batch_size=batch_size)
topk_model.compile(run_eagerly=False, metrics=[
    mm.RecallAt(topk), mm.NDCGAt(topk), mm.MRRAt(topk)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1387
# WARNING:absl:Found untraced functions such as prepare_list_features_1_layer_call_fn, prepare_list_features_1_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_1_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(

# %%
# uids = range(1,10)

# for uid in uids:
#     watched_movies = valid_df[valid_df['user_id'] == uid]['movie_id'].unique()
#     new_movies = set(watched_movies).difference(train_df[train_df['user_id'] == uid]['movie_id'].unique())
#     # print(f'User {uid} watched {len(watched_movies)} movies')
#     recs = recommend_for_user_id(uid, valid_df, topk_model)
#     # if len(set(watched_movies).intersection(set(recs))) > 10:
#     print(f'UID: {uid},Recall', len(set(watched_movies).intersection(set(recs))))

# %%
cold_movies = list(set(valid_df['movie_id'].unique()).difference(set(train_df['movie_id'].unique())))
len(cold_movies)
# Out:
# 50

# %%
cold_movie = cold_movies[2]
cold_movie
# Out:
# 1414

# %%
user_watched_cold_movie = valid_df[valid_df['movie_id'] == cold_movie]['user_id']
user_watched_cold_movie
# Out:
# 14704    1
# Name: user_id, dtype: int64

# %%
user_features = get_candidates(valid, candidate_id=Tags.USER)
topk = 100
batch_size=1024
model = model_v6

topk_user_model = to_top_k_encoder(model, user_features, k=topk, batch_size=batch_size, candidate_id=Tags.USER_ID)
topk_user_model.compile(run_eagerly=False, metrics=[
    mm.RecallAt(topk), mm.NDCGAt(topk), mm.MRRAt(topk)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 943
# WARNING:absl:Found untraced functions such as prepare_list_features_layer_call_fn, prepare_list_features_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_layer_call_fn while saving (showing 5 of 28). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(

# %%
recommend_for_movie_id(cold_movie, valid_df, topk_user_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# array([926, 647, 707, 914, 638, 774, 287, 362, 726, 662, 786, 400, 827,
#        890, 906, 279, 881, 313, 887, 753, 834, 922, 758, 736, 539, 637,
#        679, 731, 743, 367, 925, 357, 508, 428, 272, 177, 791, 533, 588,
#        293, 873, 875,  99, 698, 447, 266, 763, 545, 847, 714, 844, 548,
#        579, 672, 185, 750, 639, 204, 587, 302, 341, 474, 191, 397, 941,
#        190, 412, 210, 134, 577, 634, 304, 571, 507, 390, 489, 394, 555,
#        782, 620, 522, 241, 443, 894, 260, 651, 597, 217, 391, 364, 856,
#        649, 316, 795, 228, 695, 484, 910, 697, 768], dtype=int32)

# %%
# for cmid in cold_movies:
#     recs = recommend_for_movie_id(cmid, valid_df, topk_user_model)
#     uid_who_watched = valid_df[valid_df['movie_id'] == cmid]['user_id']
#     uid_rec = set(recs).intersection(set(uid_who_watched))
#     print(f'MID: {cmid} People who watched {len(uid_who_watched)}, who were recommneded {len(uid_rec)}')

# %%
test = merlin.io.Dataset(
    TEST_PATHS, engine="parquet"
)
test_df = test.to_ddf().compute()
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(

# %%
cold_movies = list(set(test_df['movie_id'].unique()).difference(set(train_df['movie_id'].unique())))
len(cold_movies)
# Out:
# 72

# %%
candidate_features = get_candidates(test)
topk = 100
batch_size=1024
model = model_v6

topk_model = to_top_k_encoder(model, candidate_features, k=topk, batch_size=batch_size)
topk_model.compile(run_eagerly=False, metrics=[
    mm.RecallAt(topk), mm.NDCGAt(topk), mm.MRRAt(topk)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# Candidate set rows: 1432
# WARNING:absl:Found untraced functions such as prepare_list_features_1_layer_call_fn, prepare_list_features_1_layer_call_and_return_conditional_losses, model_context_layer_call_fn, model_context_layer_call_and_return_conditional_losses, concat_features_1_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /usr/local/lib/python3.10/dist-packages/merlin/io/dataset.py:267: UserWarning: Initializing an NVTabular Dataset in CPU mode.This is an experimental feature with extremely limited support!
#   warnings.warn(

# %%
eval_loader = mm.Loader(test, batch_size=2048, shuffle=False)
_iter = iter(eval_loader)

# %%
count_user_recommended = 0
from collections import defaultdict
cold_movie_count = defaultdict(set)
ran = 0

for batch, _ in _iter:
    r = topk_model(batch)[1].numpy()
    for cmid in cold_movies:
        mask = np.any(r == cmid, axis=1)
        cold_movie_count[cmid] |= set(tf.boolean_mask(batch['user_id'], mask).numpy())
    # count_user_recommended += np.sum(np.any(np.isin(r, cold_movies), axis=1))

# %%
for k,v in cold_movie_count.items():
    user_watched = set(test_df[test_df['movie_id'] == k]['user_id'])
    actual_watched = (test_df['movie_id'] == k).sum()
    print(k, len(v), len(user_watched.intersection(v)), actual_watched)
# Out:
# 1664 57 0 1
# 1538 36 0 1
# 1539 118 0 1
# 1414 47 0 2
# 1655 47 0 1
# 1544 145 0 1
# 1547 45 0 1
# 1423 84 0 2
# 1552 43 0 1
# 1553 59 0 1
# 1426 83 0 3
# 1555 48 0 1
# 1558 45 0 1
# 1559 50 0 1
# 1561 98 0 1
# 1563 52 0 1
# 1436 54 0 2
# 1566 57 0 1
# 1569 57 0 1
# 1573 66 0 1
# 1447 96 0 3
# 1576 68 0 1
# 1580 70 0 1
# 1581 51 0 1
# 1582 93 0 1
# 1583 79 0 1
# 1457 56 0 2
# 1590 46 0 1
# 1336 46 0 3
# 1592 62 0 1
# 1594 47 0 1
# 1467 66 0 1
# 1468 48 0 2
# 1469 81 1 1
# 1470 67 0 1
# 1596 93 0 1
# 1602 60 0 1
# 1347 34 0 3
# 1604 118 0 1
# 1349 43 0 2
# 1609 58 0 1
# 1482 91 0 1
# 1611 57 0 1
# 1485 64 0 1
# 1486 50 0 1
# 1615 67 0 1
# 1616 20 0 1
# 1493 43 0 2
# 1497 61 0 2
# 1498 105 0 1
# 1371 164 0 4
# 1626 42 0 1
# 1628 26 0 1
# 1629 65 0 1
# 1380 79 0 2
# 1636 71 0 1
# 1639 81 0 1
# 1642 74 0 1
# 1517 56 0 1
# 1646 54 0 1
# 1647 105 0 1
# 1392 55 0 3
# 1395 96 0 3
# 1396 88 0 3
# 1652 46 0 1
# 1653 33 0 1
# 1654 90 0 1
# 1656 58 0 1
# 1658 37 0 1
# 1659 69 0 1
# 1661 122 0 1
# 1662 43 0 1

# %%
ran
# Out:
# 8

# %%
valid_df['user_id'].nunique()
# Out:
# 943

# %%
array_2d = np.array([[1, 2, 3, 1],
                     [4, 5, 6, 5],
                     [7, 8, 8, 9]])

# Set of values to count occurrences of
values_to_count = [5, 8]

# Count occurrences of the set in each row
np.sum(np.any(np.isin(array_2d, values_to_count), axis=1))
# Out:
# 2

# %%
np.any(np.isin(array_2d, values_to_count), axis=1)
# Out:
# array([False,  True,  True])

# %%
(count_per_row).sum()
# Out:
# 4

# %%
r = topk_model(batch[0])[1].numpy()
for i, u in enumerate(batch[0]['user_id'].numpy()):
    _m = set(valid_df[valid_df['user_id'] == u]['movie_id'])
    _r = set(r[i])

    print(len(_r.intersection(_m))/len(_r), len(_r.intersection(_m))/len(_m))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-255704b07a54> in <cell line: 1>()
# ----> 1 r = topk_model(batch[0])[1].numpy()
#       2 for i, u in enumerate(batch[0]['user_id'].numpy()):
#       3     _m = set(valid_df[valid_df['user_id'] == u]['movie_id'])
#       4     _r = set(r[i])
#       5
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in __call__(self, inputs, **kwargs)
#     187             kwargs.pop("features")
#     188
# --> 189         return super().__call__(inputs, **kwargs)
#     190
#     191     def build(self, input_shape):
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in call(self, inputs, targets, training, testing, **kwargs)
#     171         if isinstance(inputs, tuple):
#     172             inputs, targets = inputs
# --> 173         return combinators.call_sequentially(
#     174             list(self.to_call),
#     175             inputs=inputs,
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call_sequentially(layers, inputs, **kwargs)
#     838     outputs = inputs
#     839     for layer in layers:
# --> 840         outputs = call_layer(layer, outputs, **kwargs)
#     841
#     842     return outputs
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     447             filtered_kwargs = filter_kwargs(filtered_kwargs, call_fn, **_k)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#     451
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in __call__(self, inputs, **kwargs)
#     187             kwargs.pop("features")
#     188
# --> 189         return super().__call__(inputs, **kwargs)
#     190
#     191     def build(self, input_shape):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/encoder.py in call(self, inputs, targets, training, testing, **kwargs)
#     171         if isinstance(inputs, tuple):
#     172             inputs, targets = inputs
# --> 173         return combinators.call_sequentially(
#     174             list(self.to_call),
#     175             inputs=inputs,
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call_sequentially(layers, inputs, **kwargs)
#     838     outputs = inputs
#     839     for layer in layers:
# --> 840         outputs = call_layer(layer, outputs, **kwargs)
#     841
#     842     return outputs
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     447             filtered_kwargs = filter_kwargs(filtered_kwargs, call_fn, **_k)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#     451
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/config/schema.py in __call__(self, *args, **kwargs)
#      56         self.check_schema()
#      57
# ---> 58         return super().__call__(*args, **kwargs)
#      59
#      60     def _maybe_set_schema(self, input, schema):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call(self, inputs, training, **kwargs)
#     267
#     268     def call(self, inputs, training=False, **kwargs):
# --> 269         return call_sequentially(self.layers, inputs, training=training, **kwargs)
#     270
#     271     def compute_loss(self, inputs, targets, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/core/combinators.py in call_sequentially(layers, inputs, **kwargs)
#     838     outputs = inputs
#     839     for layer in layers:
# --> 840         outputs = call_layer(layer, outputs, **kwargs)
#     841
#     842     return outputs
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/utils/tf_utils.py in call_layer(layer, inputs, *args, **kwargs)
#     447             filtered_kwargs = filter_kwargs(filtered_kwargs, call_fn, **_k)
#     448
# --> 449     return layer(inputs, *args, **filtered_kwargs)
#     450
#     451
#
# /usr/local/lib/python3.10/dist-packages/merlin/models/tf/blocks/mlp.py in call(self, inputs, **kwargs)
#     242
#     243         filtered_kwargs = filter_kwargs(kwargs, self.dense)
# --> 244         return self.dense(inputs, **filtered_kwargs)
#     245
#     246     def compute_output_shape(self, input_shape):
#
# ValueError: Exception encountered when calling layer 'private__dense_4' (type _Dense).
#
# Input 0 of layer "dense_4" is incompatible with the layer: expected axis -1 of input shape to have value 32, but received input with shape (8, 16)
#
# Call arguments received by layer 'private__dense_4' (type _Dense):
#   • inputs=tf.Tensor(shape=(8, 16), dtype=float32)
#   • kwargs={'training': 'False', 'features': {'user_id': 'tf.Tensor(shape=(8, 1), dtype=int64)', 'gender': 'tf.Tensor(shape=(8, 1), dtype=int64)', 'occupation': 'tf.Tensor(shape=(8, 1), dtype=int64)', 'movie_id': 'tf.Tensor(shape=(8,), dtype=int64)', 'genres__values': 'tf.Tensor(shape=(22,), dtype=int64)', 'genres__offsets': 'tf.Tensor(shape=(9,), dtype=int64)'}, 'targets': 'None', 'testing': 'False'}

# %% [markdown]
# ## TMP

# %%
# model = mm.DLRMModel(
#     train.schema,
#     embedding_dim=64,
#     bottom_block=mm.MLPBlock([128, 64]),
#     top_block=mm.MLPBlock([128, 64, 32]),
#     prediction_tasks=mm.BinaryOutput(
#         train.schema.select_by_tag(Tags.TARGET).column_names[0]
#     ),
# )
# model.compile(optimizer="adam")
# model.fit(train, batch_size=1024)

# %%
schema
# Out:
# [{'name': 'movie_id', 'tags': {<Tags.ITEM: 'item'>, <Tags.ID: 'id'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'start_index': 0.0, 'cat_path': './/categories/unique.movie_id.parquet', 'max_size': 0.0, 'num_buckets': None, 'freq_threshold': 0.0, 'embedding_sizes': {'cardinality': 1562.0, 'dimension': 98.0}, 'domain': {'min': 0, 'max': 1561, 'name': 'movie_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'user_id', 'tags': {<Tags.USER: 'user'>, <Tags.ID: 'id'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'cat_path': './/categories/unique.user_id.parquet', 'freq_threshold': 0.0, 'embedding_sizes': {'dimension': 74.0, 'cardinality': 944.0}, 'num_buckets': None, 'max_size': 0.0, 'start_index': 0.0, 'domain': {'min': 0, 'max': 943, 'name': 'user_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'gender', 'tags': {<Tags.USER: 'user'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'num_buckets': None, 'max_size': 0.0, 'embedding_sizes': {'cardinality': 3.0, 'dimension': 16.0}, 'cat_path': './/categories/unique.gender.parquet', 'start_index': 0.0, 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 2, 'name': 'gender'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'occupation', 'tags': {<Tags.USER: 'user'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'max_size': 0.0, 'freq_threshold': 0.0, 'cat_path': './/categories/unique.occupation.parquet', 'num_buckets': None, 'embedding_sizes': {'dimension': 16.0, 'cardinality': 22.0}, 'start_index': 0.0, 'domain': {'min': 0, 'max': 21, 'name': 'occupation'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}]

# %%
# Define Model
import tensorflow as tf
QUERY_DROPOUT = 0.1
ITEM_DROPOUT = 0.1

model_v0 = mm.TwoTowerModel(
    schema,
    query_tower=mm.MLPBlock(
        [128,256],
        kernel_regularizer=tf.keras.regularizers.l1(3.9e-06),
        bias_regularizer=tf.keras.regularizers.l1(3.9e-06),
        no_activation_last_layer=True,
        # dropout=QUERY_DROPOUT
     ),
     item_tower=mm.MLPBlock(
         [128,256],
         kernel_regularizer=tf.keras.regularizers.l1(3.9e-06),
         bias_regularizer=tf.keras.regularizers.l1(3.9e-06),
         no_activation_last_layer=True,
        #  dropout=ITEM_DROPOUT
     ),
     samplers=[mm.InBatchSampler()] # default value
)

# %%
TOP_K = [10]

model_v0.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
    run_eagerly=False,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=[
        tf.keras.metrics.AUC(),
        mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K),

            #  tfr.keras.metrics.MRRMetric(topn=4)
             ],
)
model_v0.fit(
    train,
    validation_data=valid,
    schema=schema,
    batch_size=32,
    epochs=10,
    # shuffle = False
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer TruncatedNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <bound method PercentStyle._format of <logging.PercentStyle object at 0x7d8902466f50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'NoneType' object has no attribute '_fields'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PercentStyle._format of <logging.PercentStyle object at 0x7d8902466f50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'NoneType' object has no attribute '_fields'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:merlin_models:The sampler InBatchSampler returned no samples for this batch.
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.Socket(zmq.PUSH) at 0x7d890240a500>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.Socket(zmq.PUSH) at 0x7d890240a500>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 138/138 [==============================] - ETA: 0s - loss: 6.2522 - recall_at_10: 0.0212 - mrr_at_10: 0.0068 - ndcg_at_10: 0.0101 - map_at_10: 0.0068 - precision_at_10: 0.0021 - auc_23: 0.4996 - regularization_loss: 0.0159 - loss_batch: 6.2382
# WARNING:merlin_models:The sampler InBatchSampler returned no samples for this batch.
# 138/138 [==============================] - 34s 171ms/step - loss: 6.2522 - recall_at_10: 0.0212 - mrr_at_10: 0.0068 - ndcg_at_10: 0.0101 - map_at_10: 0.0068 - precision_at_10: 0.0021 - auc_23: 0.4996 - regularization_loss: 0.0158 - loss_batch: 6.2225 - val_loss: 6.2307 - val_recall_at_10: 0.0217 - val_mrr_at_10: 0.0069 - val_ndcg_at_10: 0.0103 - val_map_at_10: 0.0069 - val_precision_at_10: 0.0022 - val_auc_23: 0.5000 - val_regularization_loss: 0.0054 - val_loss_batch: 4.6038
# Epoch 2/10
# 138/138 [==============================] - 7s 47ms/step - loss: 6.2393 - recall_at_10: 0.0214 - mrr_at_10: 0.0069 - ndcg_at_10: 0.0102 - map_at_10: 0.0069 - precision_at_10: 0.0021 - auc_23: 0.5031 - regularization_loss: 0.0044 - loss_batch: 6.2098 - val_loss: 6.2298 - val_recall_at_10: 0.0207 - val_mrr_at_10: 0.0061 - val_ndcg_at_10: 0.0095 - val_map_at_10: 0.0061 - val_precision_at_10: 0.0021 - val_auc_23: 0.5003 - val_regularization_loss: 0.0045 - val_loss_batch: 4.6036
# Epoch 3/10
# 138/138 [==============================] - 4s 26ms/step - loss: 6.2386 - recall_at_10: 0.0204 - mrr_at_10: 0.0064 - ndcg_at_10: 0.0096 - map_at_10: 0.0064 - precision_at_10: 0.0020 - auc_23: 0.5010 - regularization_loss: 0.0036 - loss_batch: 6.2091 - val_loss: 6.2291 - val_recall_at_10: 0.0198 - val_mrr_at_10: 0.0060 - val_ndcg_at_10: 0.0092 - val_map_at_10: 0.0060 - val_precision_at_10: 0.0020 - val_auc_23: 0.5019 - val_regularization_loss: 0.0034 - val_loss_batch: 4.6018
# Epoch 4/10
# 138/138 [==============================] - 8s 56ms/step - loss: 6.2370 - recall_at_10: 0.0210 - mrr_at_10: 0.0065 - ndcg_at_10: 0.0098 - map_at_10: 0.0065 - precision_at_10: 0.0021 - auc_23: 0.5001 - regularization_loss: 0.0025 - loss_batch: 6.2075 - val_loss: 6.2271 - val_recall_at_10: 0.0205 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0097 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0021 - val_auc_23: 0.5000 - val_regularization_loss: 0.0018 - val_loss_batch: 4.6002
# Epoch 5/10
# 138/138 [==============================] - 7s 53ms/step - loss: 6.2360 - recall_at_10: 0.0205 - mrr_at_10: 0.0064 - ndcg_at_10: 0.0096 - map_at_10: 0.0064 - precision_at_10: 0.0021 - auc_23: 0.5002 - regularization_loss: 0.0015 - loss_batch: 6.2065 - val_loss: 6.2265 - val_recall_at_10: 0.0214 - val_mrr_at_10: 0.0064 - val_ndcg_at_10: 0.0098 - val_map_at_10: 0.0064 - val_precision_at_10: 0.0021 - val_auc_23: 0.5000 - val_regularization_loss: 0.0013 - val_loss_batch: 4.5996
# Epoch 6/10
# 138/138 [==============================] - 3s 24ms/step - loss: 6.2356 - recall_at_10: 0.0202 - mrr_at_10: 0.0061 - ndcg_at_10: 0.0093 - map_at_10: 0.0061 - precision_at_10: 0.0020 - auc_23: 0.5001 - regularization_loss: 0.0011 - loss_batch: 6.2061 - val_loss: 6.2263 - val_recall_at_10: 0.0203 - val_mrr_at_10: 0.0065 - val_ndcg_at_10: 0.0097 - val_map_at_10: 0.0065 - val_precision_at_10: 0.0020 - val_auc_23: 0.5000 - val_regularization_loss: 9.7764e-04 - val_loss_batch: 4.5994
# Epoch 7/10
# 138/138 [==============================] - 7s 50ms/step - loss: 6.2354 - recall_at_10: 0.0203 - mrr_at_10: 0.0063 - ndcg_at_10: 0.0095 - map_at_10: 0.0063 - precision_at_10: 0.0020 - auc_23: 0.5000 - regularization_loss: 8.8442e-04 - loss_batch: 6.2058 - val_loss: 6.2261 - val_recall_at_10: 0.0203 - val_mrr_at_10: 0.0062 - val_ndcg_at_10: 0.0094 - val_map_at_10: 0.0062 - val_precision_at_10: 0.0020 - val_auc_23: 0.5000 - val_regularization_loss: 8.0725e-04 - val_loss_batch: 4.5992
# Epoch 8/10
# 138/138 [==============================] - 4s 26ms/step - loss: 6.2353 - recall_at_10: 0.0204 - mrr_at_10: 0.0063 - ndcg_at_10: 0.0095 - map_at_10: 0.0063 - precision_at_10: 0.0020 - auc_23: 0.5000 - regularization_loss: 7.4666e-04 - loss_batch: 6.2057 - val_loss: 6.2260 - val_recall_at_10: 0.0205 - val_mrr_at_10: 0.0063 - val_ndcg_at_10: 0.0096 - val_map_at_10: 0.0063 - val_precision_at_10: 0.0021 - val_auc_23: 0.5000 - val_regularization_loss: 6.9787e-04 - val_loss_batch: 4.5991
# Epoch 9/10
# 138/138 [==============================] - 3s 20ms/step - loss: 6.2352 - recall_at_10: 0.0202 - mrr_at_10: 0.0064 - ndcg_at_10: 0.0095 - map_at_10: 0.0064 - precision_at_10: 0.0020 - auc_23: 0.5000 - regularization_loss: 6.5806e-04 - loss_batch: 6.2056 - val_loss: 6.2259 - val_recall_at_10: 0.0203 - val_mrr_at_10: 0.0064 - val_ndcg_at_10: 0.0095 - val_map_at_10: 0.0064 - val_precision_at_10: 0.0020 - val_auc_23: 0.5000 - val_regularization_loss: 6.2662e-04 - val_loss_batch: 4.5990
# Epoch 10/10
# 138/138 [==============================] - 4s 30ms/step - loss: 6.2351 - recall_at_10: 0.0204 - mrr_at_10: 0.0063 - ndcg_at_10: 0.0095 - map_at_10: 0.0063 - precision_at_10: 0.0020 - auc_23: 0.5000 - regularization_loss: 6.0129e-04 - loss_batch: 6.2056 - val_loss: 6.2259 - val_recall_at_10: 0.0213 - val_mrr_at_10: 0.0066 - val_ndcg_at_10: 0.0099 - val_map_at_10: 0.0066 - val_precision_at_10: 0.0021 - val_auc_23: 0.5000 - val_regularization_loss: 5.8123e-04 - val_loss_batch: 4.5990

# %%
train_df = train.to_ddf().compute()
val_df = valid.to_ddf().compute()

# %%
train_df
# Out:
#        movie_id  user_id  gender  occupation     genres  rating  movie_id_raw
# 0           121       13       1           1        [1]     1.0           134
# 1           196       33       1          18  [1, 4, 8]     1.0            31
# 2           451      901       1           1     [2, 5]     1.0           354
# 3            48       88       2           8     [2, 5]     0.0           202
# 4           330       30       1           4        [1]     0.0           708
# ...         ...      ...     ...         ...        ...     ...           ...
# 70197        60      232       1           1    [1, 13]     0.0           289
# 70198        89       80       1           1  [4, 3, 9]     0.0           273
# 70199       180      253       1          11        [1]     1.0           285
# 70200       507      111       1          15        [1]     1.0           468
# 70201       919      114       2          12        [2]     0.0           335
#
# [70202 rows x 7 columns]

# %%
assert train_df['user_id'].nunique() == val_df['user_id'].nunique()

# %%
train_df['movie_id'].nunique(), val_df['movie_id'].nunique()
# Out:
# (1561, 1387)

# %%
len(set(train_df['movie_id'].unique()).intersection(set(val_df['movie_id'].unique())))
# Out:
# 1337

# %%
# missing
len(set(train_df['movie_id'].unique()).difference(set(val_df['movie_id'].unique())))
# Out:
# 224

# %%
# cold start
len(set(val_df['movie_id'].unique()).difference(set(train_df['movie_id'].unique())))
# Out:
# 50

# %%
train_df['rating'].nunique()
# Out:
# 2

# %%
schema
# Out:
# [{'name': 'movie_id', 'tags': {<Tags.ITEM: 'item'>, <Tags.ID: 'id'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'max_size': 0.0, 'embedding_sizes': {'dimension': 98.0, 'cardinality': 1562.0}, 'freq_threshold': 0.0, 'num_buckets': None, 'cat_path': './/categories/unique.movie_id.parquet', 'start_index': 0.0, 'domain': {'min': 0, 'max': 1561, 'name': 'movie_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'user_id', 'tags': {<Tags.ID: 'id'>, <Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'num_buckets': None, 'embedding_sizes': {'cardinality': 944.0, 'dimension': 74.0}, 'start_index': 0.0, 'max_size': 0.0, 'cat_path': './/categories/unique.user_id.parquet', 'freq_threshold': 0.0, 'domain': {'min': 0, 'max': 943, 'name': 'user_id'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'gender', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'start_index': 0.0, 'num_buckets': None, 'freq_threshold': 0.0, 'max_size': 0.0, 'cat_path': './/categories/unique.gender.parquet', 'embedding_sizes': {'cardinality': 3.0, 'dimension': 16.0}, 'domain': {'min': 0, 'max': 2, 'name': 'gender'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'occupation', 'tags': {<Tags.CATEGORICAL: 'categorical'>, <Tags.USER: 'user'>}, 'properties': {'embedding_sizes': {'cardinality': 22.0, 'dimension': 16.0}, 'start_index': 0.0, 'num_buckets': None, 'max_size': 0.0, 'freq_threshold': 0.0, 'cat_path': './/categories/unique.occupation.parquet', 'domain': {'min': 0, 'max': 21, 'name': 'occupation'}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}, {'name': 'genres', 'tags': {<Tags.ITEM: 'item'>, <Tags.CATEGORICAL: 'categorical'>}, 'properties': {'embedding_sizes': {'dimension': 16.0, 'cardinality': 20.0}, 'cat_path': './/categories/unique.genres.parquet', 'max_size': 0.0, 'start_index': 0.0, 'freq_threshold': 0.0, 'num_buckets': None, 'domain': {'min': 0, 'max': 19, 'name': 'genres'}, 'value_count': {'min': 0, 'max': None}}, 'dtype': DType(name='int64', element_type=<ElementType.Int: 'int'>, element_size=64, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None), Dimension(min=0, max=None)))), 'is_list': True, 'is_ragged': True}, {'name': 'rating', 'tags': {<Tags.TARGET: 'target'>, <Tags.BINARY_CLASSIFICATION: 'binary_classification'>}, 'properties': {}, 'dtype': DType(name='float32', element_type=<ElementType.Float: 'float'>, element_size=32, element_unit=None, signed=True, shape=Shape(dims=(Dimension(min=0, max=None),))), 'is_list': False, 'is_ragged': False}]

# %%
model = mm.DLRMModel(
    train.schema,
    embedding_dim=64,
    bottom_block=mm.MLPBlock([128, 64]),
    top_block=mm.MLPBlock([128, 64, 32]),
    prediction_tasks=mm.BinaryOutput(
        train.schema.select_by_tag(Tags.TARGET).column_names[0]
    ),
)

# %%
batch_size = 1024
LR = 0.03

# %%
opt = tf.keras.optimizers.legacy.Adagrad(learning_rate=LR)
model.compile(optimizer=opt, run_eagerly=False,
              metrics=[tf.keras.metrics.AUC(), mm.TopKMetricsAggregator.default_metrics(top_ks=TOP_K)])

# %%
history = [history]

# %%
history.append(model.fit(train, validation_data=valid, batch_size=batch_size, epochs=50))
# Out:
# Epoch 1/50
# 69/69 [==============================] - 3s 29ms/step - loss: 0.5212 - auc_7: 0.8074 - recall_at_10: 0.9569 - mrr_at_10: 0.9692 - ndcg_at_10: 0.9564 - map_at_10: 0.9281 - precision_at_10: 0.9569 - regularization_loss: 0.0000e+00 - loss_batch: 0.5201 - val_loss: 0.5999 - val_auc_7: 0.7578 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9681 - val_map_at_10: 0.9417 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6320
# Epoch 2/50
# 69/69 [==============================] - 3s 29ms/step - loss: 0.5204 - auc_7: 0.8081 - recall_at_10: 0.9652 - mrr_at_10: 0.9786 - ndcg_at_10: 0.9658 - map_at_10: 0.9421 - precision_at_10: 0.9652 - regularization_loss: 0.0000e+00 - loss_batch: 0.5193 - val_loss: 0.6002 - val_auc_7: 0.7576 - val_recall_at_10: 0.9667 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9729 - val_map_at_10: 0.9510 - val_precision_at_10: 0.9667 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6333
# Epoch 3/50
# 69/69 [==============================] - 2s 18ms/step - loss: 0.5195 - auc_7: 0.8090 - recall_at_10: 0.9708 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9732 - map_at_10: 0.9510 - precision_at_10: 0.9708 - regularization_loss: 0.0000e+00 - loss_batch: 0.5184 - val_loss: 0.6016 - val_auc_7: 0.7572 - val_recall_at_10: 0.9533 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9645 - val_map_at_10: 0.9360 - val_precision_at_10: 0.9533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6357
# Epoch 4/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5186 - auc_7: 0.8098 - recall_at_10: 0.9607 - mrr_at_10: 0.9804 - ndcg_at_10: 0.9630 - map_at_10: 0.9379 - precision_at_10: 0.9607 - regularization_loss: 0.0000e+00 - loss_batch: 0.5176 - val_loss: 0.6024 - val_auc_7: 0.7563 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9716 - val_map_at_10: 0.9505 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6369
# Epoch 5/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5173 - auc_7: 0.8109 - recall_at_10: 0.9742 - mrr_at_10: 0.9962 - ndcg_at_10: 0.9764 - map_at_10: 0.9582 - precision_at_10: 0.9742 - regularization_loss: 0.0000e+00 - loss_batch: 0.5162 - val_loss: 0.6031 - val_auc_7: 0.7561 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9697 - val_map_at_10: 0.9468 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6389
# Epoch 6/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5162 - auc_7: 0.8120 - recall_at_10: 0.9659 - mrr_at_10: 0.9873 - ndcg_at_10: 0.9677 - map_at_10: 0.9471 - precision_at_10: 0.9659 - regularization_loss: 0.0000e+00 - loss_batch: 0.5151 - val_loss: 0.6045 - val_auc_7: 0.7554 - val_recall_at_10: 0.9533 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9645 - val_map_at_10: 0.9381 - val_precision_at_10: 0.9533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6407
# Epoch 7/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5149 - auc_7: 0.8131 - recall_at_10: 0.9749 - mrr_at_10: 0.9953 - ndcg_at_10: 0.9775 - map_at_10: 0.9611 - precision_at_10: 0.9749 - regularization_loss: 0.0000e+00 - loss_batch: 0.5137 - val_loss: 0.6050 - val_auc_7: 0.7552 - val_recall_at_10: 0.9467 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9595 - val_map_at_10: 0.9272 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6423
# Epoch 8/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5134 - auc_7: 0.8145 - recall_at_10: 0.9633 - mrr_at_10: 0.9935 - ndcg_at_10: 0.9680 - map_at_10: 0.9438 - precision_at_10: 0.9633 - regularization_loss: 0.0000e+00 - loss_batch: 0.5123 - val_loss: 0.6071 - val_auc_7: 0.7543 - val_recall_at_10: 0.9467 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9586 - val_map_at_10: 0.9293 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6443
# Epoch 9/50
# 69/69 [==============================] - 2s 21ms/step - loss: 0.5123 - auc_7: 0.8154 - recall_at_10: 0.9757 - mrr_at_10: 0.9711 - ndcg_at_10: 0.9706 - map_at_10: 0.9527 - precision_at_10: 0.9757 - regularization_loss: 0.0000e+00 - loss_batch: 0.5111 - val_loss: 0.6082 - val_auc_7: 0.7539 - val_recall_at_10: 0.9533 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9662 - val_map_at_10: 0.9412 - val_precision_at_10: 0.9533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6470
# Epoch 10/50
# 69/69 [==============================] - 3s 29ms/step - loss: 0.5107 - auc_7: 0.8168 - recall_at_10: 0.9581 - mrr_at_10: 0.9753 - ndcg_at_10: 0.9566 - map_at_10: 0.9263 - precision_at_10: 0.9581 - regularization_loss: 0.0000e+00 - loss_batch: 0.5095 - val_loss: 0.6096 - val_auc_7: 0.7526 - val_recall_at_10: 0.9533 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9616 - val_map_at_10: 0.9296 - val_precision_at_10: 0.9533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6482
# Epoch 11/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5093 - auc_7: 0.8182 - recall_at_10: 0.9628 - mrr_at_10: 0.9902 - ndcg_at_10: 0.9666 - map_at_10: 0.9421 - precision_at_10: 0.9628 - regularization_loss: 0.0000e+00 - loss_batch: 0.5079 - val_loss: 0.6125 - val_auc_7: 0.7519 - val_recall_at_10: 0.9467 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9530 - val_map_at_10: 0.9268 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6522
# Epoch 12/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.5075 - auc_7: 0.8196 - recall_at_10: 0.9558 - mrr_at_10: 0.9951 - ndcg_at_10: 0.9631 - map_at_10: 0.9353 - precision_at_10: 0.9558 - regularization_loss: 0.0000e+00 - loss_batch: 0.5063 - val_loss: 0.6141 - val_auc_7: 0.7506 - val_recall_at_10: 0.9400 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9527 - val_map_at_10: 0.9172 - val_precision_at_10: 0.9400 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6525
# Epoch 13/50
# 69/69 [==============================] - 2s 15ms/step - loss: 0.5062 - auc_7: 0.8207 - recall_at_10: 0.9682 - mrr_at_10: 0.9957 - ndcg_at_10: 0.9728 - map_at_10: 0.9509 - precision_at_10: 0.9682 - regularization_loss: 0.0000e+00 - loss_batch: 0.5050 - val_loss: 0.6158 - val_auc_7: 0.7499 - val_recall_at_10: 0.9600 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9616 - val_map_at_10: 0.9387 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6551
# Epoch 14/50
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5043 - auc_7: 0.8222 - recall_at_10: 0.9651 - mrr_at_10: 0.9911 - ndcg_at_10: 0.9688 - map_at_10: 0.9467 - precision_at_10: 0.9651 - regularization_loss: 0.0000e+00 - loss_batch: 0.5030 - val_loss: 0.6165 - val_auc_7: 0.7495 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9654 - val_map_at_10: 0.9384 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6573
# Epoch 15/50
# 69/69 [==============================] - 3s 30ms/step - loss: 0.5025 - auc_7: 0.8238 - recall_at_10: 0.9756 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9777 - map_at_10: 0.9586 - precision_at_10: 0.9756 - regularization_loss: 0.0000e+00 - loss_batch: 0.5012 - val_loss: 0.6196 - val_auc_7: 0.7484 - val_recall_at_10: 0.9600 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9582 - val_map_at_10: 0.9305 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6594
# Epoch 16/50
# 69/69 [==============================] - 3s 30ms/step - loss: 0.5011 - auc_7: 0.8249 - recall_at_10: 0.9696 - mrr_at_10: 0.9928 - ndcg_at_10: 0.9729 - map_at_10: 0.9522 - precision_at_10: 0.9696 - regularization_loss: 0.0000e+00 - loss_batch: 0.4997 - val_loss: 0.6210 - val_auc_7: 0.7475 - val_recall_at_10: 0.9400 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9528 - val_map_at_10: 0.9172 - val_precision_at_10: 0.9400 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6627
# Epoch 17/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4990 - auc_7: 0.8267 - recall_at_10: 0.9650 - mrr_at_10: 0.9824 - ndcg_at_10: 0.9678 - map_at_10: 0.9445 - precision_at_10: 0.9650 - regularization_loss: 0.0000e+00 - loss_batch: 0.4977 - val_loss: 0.6228 - val_auc_7: 0.7469 - val_recall_at_10: 0.9467 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9511 - val_map_at_10: 0.9200 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6645
# Epoch 18/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4970 - auc_7: 0.8284 - recall_at_10: 0.9732 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9762 - map_at_10: 0.9566 - precision_at_10: 0.9732 - regularization_loss: 0.0000e+00 - loss_batch: 0.4956 - val_loss: 0.6257 - val_auc_7: 0.7460 - val_recall_at_10: 0.9533 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9577 - val_map_at_10: 0.9246 - val_precision_at_10: 0.9533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6690
# Epoch 19/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4956 - auc_7: 0.8296 - recall_at_10: 0.9571 - mrr_at_10: 0.9774 - ndcg_at_10: 0.9603 - map_at_10: 0.9327 - precision_at_10: 0.9571 - regularization_loss: 0.0000e+00 - loss_batch: 0.4940 - val_loss: 0.6273 - val_auc_7: 0.7447 - val_recall_at_10: 0.9467 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9485 - val_map_at_10: 0.9132 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6708
# Epoch 20/50
# 69/69 [==============================] - 2s 15ms/step - loss: 0.4935 - auc_7: 0.8312 - recall_at_10: 0.9707 - mrr_at_10: 0.9736 - ndcg_at_10: 0.9697 - map_at_10: 0.9511 - precision_at_10: 0.9707 - regularization_loss: 0.0000e+00 - loss_batch: 0.4920 - val_loss: 0.6301 - val_auc_7: 0.7439 - val_recall_at_10: 0.9600 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9523 - val_map_at_10: 0.9192 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6728
# Epoch 21/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4916 - auc_7: 0.8327 - recall_at_10: 0.9696 - mrr_at_10: 0.9797 - ndcg_at_10: 0.9696 - map_at_10: 0.9484 - precision_at_10: 0.9696 - regularization_loss: 0.0000e+00 - loss_batch: 0.4901 - val_loss: 0.6331 - val_auc_7: 0.7432 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9606 - val_map_at_10: 0.9280 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6767
# Epoch 22/50
# 69/69 [==============================] - 2s 17ms/step - loss: 0.4898 - auc_7: 0.8340 - recall_at_10: 0.9810 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9827 - map_at_10: 0.9683 - precision_at_10: 0.9810 - regularization_loss: 0.0000e+00 - loss_batch: 0.4885 - val_loss: 0.6365 - val_auc_7: 0.7418 - val_recall_at_10: 0.9333 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9480 - val_map_at_10: 0.9089 - val_precision_at_10: 0.9333 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6798
# Epoch 23/50
# 69/69 [==============================] - 3s 25ms/step - loss: 0.4873 - auc_7: 0.8361 - recall_at_10: 0.9748 - mrr_at_10: 0.9975 - ndcg_at_10: 0.9773 - map_at_10: 0.9585 - precision_at_10: 0.9748 - regularization_loss: 0.0000e+00 - loss_batch: 0.4857 - val_loss: 0.6372 - val_auc_7: 0.7408 - val_recall_at_10: 0.9600 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9617 - val_map_at_10: 0.9333 - val_precision_at_10: 0.9600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6818
# Epoch 24/50
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4857 - auc_7: 0.8374 - recall_at_10: 0.9844 - mrr_at_10: 0.9864 - ndcg_at_10: 0.9836 - map_at_10: 0.9738 - precision_at_10: 0.9844 - regularization_loss: 0.0000e+00 - loss_batch: 0.4840 - val_loss: 0.6402 - val_auc_7: 0.7398 - val_recall_at_10: 0.9467 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9543 - val_map_at_10: 0.9181 - val_precision_at_10: 0.9467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6853
# Epoch 25/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4834 - auc_7: 0.8392 - recall_at_10: 0.9659 - mrr_at_10: 0.9821 - ndcg_at_10: 0.9679 - map_at_10: 0.9451 - precision_at_10: 0.9659 - regularization_loss: 0.0000e+00 - loss_batch: 0.4818 - val_loss: 0.6443 - val_auc_7: 0.7384 - val_recall_at_10: 0.9400 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9485 - val_map_at_10: 0.9088 - val_precision_at_10: 0.9400 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6882
# Epoch 26/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4810 - auc_7: 0.8411 - recall_at_10: 0.9720 - mrr_at_10: 0.9806 - ndcg_at_10: 0.9738 - map_at_10: 0.9573 - precision_at_10: 0.9720 - regularization_loss: 0.0000e+00 - loss_batch: 0.4792 - val_loss: 0.6456 - val_auc_7: 0.7377 - val_recall_at_10: 0.9400 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9473 - val_map_at_10: 0.9056 - val_precision_at_10: 0.9400 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6905
# Epoch 27/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4787 - auc_7: 0.8428 - recall_at_10: 0.9759 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9784 - map_at_10: 0.9602 - precision_at_10: 0.9759 - regularization_loss: 0.0000e+00 - loss_batch: 0.4769 - val_loss: 0.6503 - val_auc_7: 0.7367 - val_recall_at_10: 0.9333 - val_mrr_at_10: 0.9556 - val_ndcg_at_10: 0.9339 - val_map_at_10: 0.8983 - val_precision_at_10: 0.9333 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6953
# Epoch 28/50
# 69/69 [==============================] - 2s 15ms/step - loss: 0.4762 - auc_7: 0.8446 - recall_at_10: 0.9759 - mrr_at_10: 0.9917 - ndcg_at_10: 0.9772 - map_at_10: 0.9602 - precision_at_10: 0.9759 - regularization_loss: 0.0000e+00 - loss_batch: 0.4745 - val_loss: 0.6534 - val_auc_7: 0.7354 - val_recall_at_10: 0.9133 - val_mrr_at_10: 0.9556 - val_ndcg_at_10: 0.9209 - val_map_at_10: 0.8744 - val_precision_at_10: 0.9133 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.6982
# Epoch 29/50
# 69/69 [==============================] - 2s 27ms/step - loss: 0.4740 - auc_7: 0.8463 - recall_at_10: 0.9700 - mrr_at_10: 0.9900 - ndcg_at_10: 0.9730 - map_at_10: 0.9525 - precision_at_10: 0.9700 - regularization_loss: 0.0000e+00 - loss_batch: 0.4722 - val_loss: 0.6559 - val_auc_7: 0.7344 - val_recall_at_10: 0.9400 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9442 - val_map_at_10: 0.9016 - val_precision_at_10: 0.9400 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7013
# Epoch 30/50
# 69/69 [==============================] - 3s 29ms/step - loss: 0.4716 - auc_7: 0.8482 - recall_at_10: 0.9905 - mrr_at_10: 0.9927 - ndcg_at_10: 0.9905 - map_at_10: 0.9841 - precision_at_10: 0.9905 - regularization_loss: 0.0000e+00 - loss_batch: 0.4698 - val_loss: 0.6610 - val_auc_7: 0.7335 - val_recall_at_10: 0.9200 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9239 - val_map_at_10: 0.8756 - val_precision_at_10: 0.9200 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7057
# Epoch 31/50
# 69/69 [==============================] - 2s 21ms/step - loss: 0.4690 - auc_7: 0.8500 - recall_at_10: 0.9699 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9736 - map_at_10: 0.9540 - precision_at_10: 0.9699 - regularization_loss: 0.0000e+00 - loss_batch: 0.4672 - val_loss: 0.6676 - val_auc_7: 0.7319 - val_recall_at_10: 0.9333 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9432 - val_map_at_10: 0.8961 - val_precision_at_10: 0.9333 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7112
# Epoch 32/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4661 - auc_7: 0.8521 - recall_at_10: 0.9710 - mrr_at_10: 0.9930 - ndcg_at_10: 0.9754 - map_at_10: 0.9594 - precision_at_10: 0.9710 - regularization_loss: 0.0000e+00 - loss_batch: 0.4643 - val_loss: 0.6700 - val_auc_7: 0.7317 - val_recall_at_10: 0.9267 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9354 - val_map_at_10: 0.8838 - val_precision_at_10: 0.9267 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7144
# Epoch 33/50
# 69/69 [==============================] - 2s 15ms/step - loss: 0.4639 - auc_7: 0.8536 - recall_at_10: 0.9826 - mrr_at_10: 0.9991 - ndcg_at_10: 0.9852 - map_at_10: 0.9735 - precision_at_10: 0.9826 - regularization_loss: 0.0000e+00 - loss_batch: 0.4619 - val_loss: 0.6705 - val_auc_7: 0.7299 - val_recall_at_10: 0.9133 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9258 - val_map_at_10: 0.8660 - val_precision_at_10: 0.9133 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7157
# Epoch 34/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4604 - auc_7: 0.8562 - recall_at_10: 0.9841 - mrr_at_10: 0.9962 - ndcg_at_10: 0.9871 - map_at_10: 0.9782 - precision_at_10: 0.9841 - regularization_loss: 0.0000e+00 - loss_batch: 0.4585 - val_loss: 0.6760 - val_auc_7: 0.7288 - val_recall_at_10: 0.9200 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9276 - val_map_at_10: 0.8772 - val_precision_at_10: 0.9200 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7237
# Epoch 35/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4573 - auc_7: 0.8584 - recall_at_10: 0.9760 - mrr_at_10: 0.9608 - ndcg_at_10: 0.9693 - map_at_10: 0.9531 - precision_at_10: 0.9760 - regularization_loss: 0.0000e+00 - loss_batch: 0.4554 - val_loss: 0.6823 - val_auc_7: 0.7278 - val_recall_at_10: 0.9200 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9293 - val_map_at_10: 0.8745 - val_precision_at_10: 0.9200 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7281
# Epoch 36/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4551 - auc_7: 0.8599 - recall_at_10: 0.9810 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9832 - map_at_10: 0.9683 - precision_at_10: 0.9810 - regularization_loss: 0.0000e+00 - loss_batch: 0.4532 - val_loss: 0.6855 - val_auc_7: 0.7274 - val_recall_at_10: 0.9067 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9143 - val_map_at_10: 0.8547 - val_precision_at_10: 0.9067 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7319
# Epoch 37/50
# 69/69 [==============================] - 3s 28ms/step - loss: 0.4509 - auc_7: 0.8629 - recall_at_10: 0.9858 - mrr_at_10: 0.9994 - ndcg_at_10: 0.9890 - map_at_10: 0.9805 - precision_at_10: 0.9858 - regularization_loss: 0.0000e+00 - loss_batch: 0.4488 - val_loss: 0.6889 - val_auc_7: 0.7258 - val_recall_at_10: 0.9133 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9201 - val_map_at_10: 0.8573 - val_precision_at_10: 0.9133 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7374
# Epoch 38/50
# 69/69 [==============================] - 3s 26ms/step - loss: 0.4480 - auc_7: 0.8648 - recall_at_10: 0.9882 - mrr_at_10: 0.9915 - ndcg_at_10: 0.9885 - map_at_10: 0.9811 - precision_at_10: 0.9882 - regularization_loss: 0.0000e+00 - loss_batch: 0.4460 - val_loss: 0.6950 - val_auc_7: 0.7247 - val_recall_at_10: 0.9067 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.9123 - val_map_at_10: 0.8512 - val_precision_at_10: 0.9067 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7428
# Epoch 39/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4435 - auc_7: 0.8679 - recall_at_10: 0.9855 - mrr_at_10: 0.9857 - ndcg_at_10: 0.9845 - map_at_10: 0.9756 - precision_at_10: 0.9855 - regularization_loss: 0.0000e+00 - loss_batch: 0.4414 - val_loss: 0.6992 - val_auc_7: 0.7230 - val_recall_at_10: 0.8933 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9045 - val_map_at_10: 0.8343 - val_precision_at_10: 0.8933 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7477
# Epoch 40/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4389 - auc_7: 0.8711 - recall_at_10: 0.9791 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9825 - map_at_10: 0.9699 - precision_at_10: 0.9791 - regularization_loss: 0.0000e+00 - loss_batch: 0.4367 - val_loss: 0.7011 - val_auc_7: 0.7222 - val_recall_at_10: 0.9000 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9100 - val_map_at_10: 0.8438 - val_precision_at_10: 0.9000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7535
# Epoch 41/50
# 69/69 [==============================] - 2s 17ms/step - loss: 0.4351 - auc_7: 0.8736 - recall_at_10: 0.9923 - mrr_at_10: 0.9972 - ndcg_at_10: 0.9929 - map_at_10: 0.9878 - precision_at_10: 0.9923 - regularization_loss: 0.0000e+00 - loss_batch: 0.4331 - val_loss: 0.7171 - val_auc_7: 0.7214 - val_recall_at_10: 0.8800 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.8900 - val_map_at_10: 0.8202 - val_precision_at_10: 0.8800 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7650
# Epoch 42/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4297 - auc_7: 0.8771 - recall_at_10: 0.9914 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9926 - map_at_10: 0.9866 - precision_at_10: 0.9914 - regularization_loss: 0.0000e+00 - loss_batch: 0.4275 - val_loss: 0.7185 - val_auc_7: 0.7199 - val_recall_at_10: 0.8933 - val_mrr_at_10: 1.0000 - val_ndcg_at_10: 0.9090 - val_map_at_10: 0.8372 - val_precision_at_10: 0.8933 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7698
# Epoch 43/50
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4242 - auc_7: 0.8807 - recall_at_10: 0.9793 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9844 - map_at_10: 0.9719 - precision_at_10: 0.9793 - regularization_loss: 0.0000e+00 - loss_batch: 0.4220 - val_loss: 0.7208 - val_auc_7: 0.7183 - val_recall_at_10: 0.8733 - val_mrr_at_10: 0.9167 - val_ndcg_at_10: 0.8718 - val_map_at_10: 0.7957 - val_precision_at_10: 0.8733 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7760
# Epoch 44/50
# 69/69 [==============================] - 3s 27ms/step - loss: 0.4170 - auc_7: 0.8853 - recall_at_10: 0.9875 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9907 - map_at_10: 0.9839 - precision_at_10: 0.9875 - regularization_loss: 0.0000e+00 - loss_batch: 0.4148 - val_loss: 0.7297 - val_auc_7: 0.7174 - val_recall_at_10: 0.9000 - val_mrr_at_10: 0.9667 - val_ndcg_at_10: 0.8964 - val_map_at_10: 0.8247 - val_precision_at_10: 0.9000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7839
# Epoch 45/50
# 69/69 [==============================] - 3s 25ms/step - loss: 0.4089 - auc_7: 0.8904 - recall_at_10: 0.9924 - mrr_at_10: 0.9985 - ndcg_at_10: 0.9940 - map_at_10: 0.9896 - precision_at_10: 0.9924 - regularization_loss: 0.0000e+00 - loss_batch: 0.4067 - val_loss: 0.7358 - val_auc_7: 0.7150 - val_recall_at_10: 0.8533 - val_mrr_at_10: 0.9000 - val_ndcg_at_10: 0.8527 - val_map_at_10: 0.7647 - val_precision_at_10: 0.8533 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.7917
# Epoch 46/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.4028 - auc_7: 0.8940 - recall_at_10: 0.9904 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9907 - map_at_10: 0.9840 - precision_at_10: 0.9904 - regularization_loss: 0.0000e+00 - loss_batch: 0.4003 - val_loss: 0.7495 - val_auc_7: 0.7136 - val_recall_at_10: 0.9000 - val_mrr_at_10: 0.8889 - val_ndcg_at_10: 0.8815 - val_map_at_10: 0.8118 - val_precision_at_10: 0.9000 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.8050
# Epoch 47/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.3913 - auc_7: 0.9009 - recall_at_10: 0.9895 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9918 - map_at_10: 0.9848 - precision_at_10: 0.9895 - regularization_loss: 0.0000e+00 - loss_batch: 0.3891 - val_loss: 0.7816 - val_auc_7: 0.7127 - val_recall_at_10: 0.8600 - val_mrr_at_10: 0.9000 - val_ndcg_at_10: 0.8577 - val_map_at_10: 0.7723 - val_precision_at_10: 0.8600 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.8334
# Epoch 48/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.3813 - auc_7: 0.9064 - recall_at_10: 0.9928 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9936 - map_at_10: 0.9885 - precision_at_10: 0.9928 - regularization_loss: 0.0000e+00 - loss_batch: 0.3790 - val_loss: 0.7885 - val_auc_7: 0.7110 - val_recall_at_10: 0.8467 - val_mrr_at_10: 0.8667 - val_ndcg_at_10: 0.8353 - val_map_at_10: 0.7417 - val_precision_at_10: 0.8467 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.8428
# Epoch 49/50
# 69/69 [==============================] - 2s 17ms/step - loss: 0.3734 - auc_7: 0.9103 - recall_at_10: 0.9954 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9956 - map_at_10: 0.9922 - precision_at_10: 0.9954 - regularization_loss: 0.0000e+00 - loss_batch: 0.3707 - val_loss: 0.7885 - val_auc_7: 0.7095 - val_recall_at_10: 0.8733 - val_mrr_at_10: 0.8556 - val_ndcg_at_10: 0.8587 - val_map_at_10: 0.7888 - val_precision_at_10: 0.8733 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.8467
# Epoch 50/50
# 69/69 [==============================] - 2s 16ms/step - loss: 0.3548 - auc_7: 0.9205 - recall_at_10: 0.9923 - mrr_at_10: 1.0000 - ndcg_at_10: 0.9942 - map_at_10: 0.9897 - precision_at_10: 0.9923 - regularization_loss: 0.0000e+00 - loss_batch: 0.3525 - val_loss: 0.8234 - val_auc_7: 0.7074 - val_recall_at_10: 0.8733 - val_mrr_at_10: 0.9333 - val_ndcg_at_10: 0.8718 - val_map_at_10: 0.7947 - val_precision_at_10: 0.8733 - val_regularization_loss: 0.0000e+00 - val_loss_batch: 0.8769

# %%
_history = merge_model_history(*history)
val_history = { k[4:]:v for k,v in _history.items() if k.startswith('val')}
plot_metrics(_history, val_history, default_plot_metrics | {'AUC': 'auc_7'})

# %%
model_v9.candidate_embedding
